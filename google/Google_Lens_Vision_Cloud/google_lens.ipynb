# %% [markdown]
# # What is Google Lens?
# Google Lens is a set of vision-based computing capabilities that can understand what you’re looking at and use that information to copy or translate text, identify plants and animals, explore locales or menus, discover products, find visually similar images and take other useful actions.
# # How Google Lens works
# Lens compares objects in your picture to other images, and ranks those images based on their similarity and relevance to the objects in the original picture. Lens also uses its understanding of the objects in your picture to find other relevant results from the web. Lens may also use other helpful signals, such as words, language and other metadata on the image’s host site, to determine ranking and relevance.
#
# # Cloud Vision API
# Cloud Vision API allows developers to easily integrate vision detection features within applications, including image labeling, face and landmark detection, optical character recognition (OCR), and tagging of explicit content.
#
# https://cloud.google.com/vision?hl=en#extract-insights-from-images-documents-and-videos

# %%
from google.cloud import vision_v1
import os

# Set environment variable for Google Cloud credentials
# You can download the JSON key file from your service account and set the path.
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "keys/complete-tube-421007-208a4862c992.json"

def detect_text(image_path):
    """Detects text in an image using the Google Cloud Vision API."""

    client = vision_v1.ImageAnnotatorClient()

    with open(image_path, 'rb') as image_file:
        content = image_file.read()

    image = vision_v1.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations

    # Print detected text and bounding boxes (optional)
    if texts:
        print("Detected Text:")
        for text in texts:
            print(f'"{text.description}"')  # The detected text
            # Print bounding box vertices (optional)
            # vertices = [(vertex.x, vertex.y) for vertex in text.bounding_poly.vertices]
            # print(f"  Bounding Box: {vertices}")

        return texts  # Return the list of text annotations
    else:
        print("No text detected.")
        return None



def detect_labels(image_path):
    """Detects labels in an image using the Google Cloud Vision API."""
    client = vision_v1.ImageAnnotatorClient()

    with open(image_path, 'rb') as image_file:
        content = image_file.read()

    image = vision_v1.Image(content=content)

    response = client.label_detection(image=image)
    labels = response.label_annotations

    if labels:
        print("\nDetected Labels:")
        for label in labels:
            print(f"{label.description} (Confidence: {label.score:.2f})")
        return labels # Return the list of label annotations
    else:
        print("No labels detected.")
        return None



def detect_objects(image_path):
    """Detects objects in an image using the Google Cloud Vision API."""
    client = vision_v1.ImageAnnotatorClient()

    with open(image_path, 'rb') as image_file:
        content = image_file.read()

    image = vision_v1.Image(content=content)

    response = client.object_localization(image=image)
    objects = response.localized_object_annotations

    if objects:
        print("\nDetected Objects:")
        for object_ in objects:
            print(f"{object_.name} (Confidence: {object_.score:.2f})")
            # Print bounding box vertices (optional)
            vertices = [(vertex.x, vertex.y) for vertex in object_.bounding_poly.vertices]
            print(f"  Bounding Box: {vertices}")
        return objects # Return the list of object annotations
    else:
        print("No objects detected.")
        return None





image_path = "desk.png"  # Replace with the path to your image

detected_texts = detect_text(image_path)
detected_labels = detect_labels(image_path)
detected_objects = detect_objects(image_path)
# Out:
# No text detected.
#
# Detected Labels:
# Blue (Confidence: 0.99)
# Water (Confidence: 0.99)
# Body of water (Confidence: 0.98)
# Building (Confidence: 0.98)
# City (Confidence: 0.96)
# Waterway (Confidence: 0.96)
# Architecture (Confidence: 0.94)
# Watercourse (Confidence: 0.93)
# Reflection (Confidence: 0.92)
# Channel (Confidence: 0.91)
#
# Detected Objects:
# Building (Confidence: 0.51)
#   Bounding Box: []

# %%
client = vision_v1.ImageAnnotatorClient()

# %%
with open(image_path, 'rb') as image_file:
        content = image_file.read()

image = vision_v1.Image(content=content)

# %%
response = client.landmark_detection(image=image)
landmarks = response.landmark_annotations
if landmarks:
    for landmark in landmarks:
        print(f"Landmark: {landmark.description}, Lat/Lng: {landmark.locations}")
# Out:
# Landmark: Chapel Bridge, Lat/Lng: [lat_lng {
#   latitude: 47.051648899999989
#   longitude: 8.3075350999999973
# }
# ]
# Landmark: Brasserie Bodu, Lat/Lng: [lat_lng {
#   latitude: 47.0519132
#   longitude: 8.3057106
# }
# ]
# Landmark: Mcdonald’s, Lat/Lng: [lat_lng {
#   latitude: 47.054548999999994
#   longitude: 8.3086636
# }
# ]
# Landmark: Luzerner Theater, Lat/Lng: [lat_lng {
#   latitude: 47.0505906
#   longitude: 8.3059906
# }
# ]

# %%
from google.cloud import vision_v1
import os
import os
from google.cloud import vision_v1
from PIL import Image  # Pillow library for image manipulation
import fitz  # PyMuPDF (fitz) library for PDF handling
import io
# Set environment variable for Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] ="keys/complete-tube-421007-208a4862c992.json"



def pdf_to_images(pdf_path):
    """Converts a PDF to a list of PIL Image objects."""
    doc = fitz.open(pdf_path)  # Open the PDF
    images = []
    for page_num in range(doc.page_count):
        page = doc[page_num]
        pix = page.get_pixmap(matrix=fitz.Matrix(3, 3)) # Increase resolution for better OCR
        img = Image.open(io.BytesIO(pix.tobytes())) # Convert to PIL Image
        images.append(img)
    return images

def detect_text_from_image(image):
    """Detects text in a PIL Image using the Vision API."""
    client = vision_v1.ImageAnnotatorClient()
    buffered = io.BytesIO()
    image.save(buffered, format="PNG") # Use PNG for better OCR quality
    content = buffered.getvalue()

    image = vision_v1.Image(content=content)
    response = client.text_detection(image=image)
    texts = response.text_annotations

    extracted_text = ""
    if texts:
        for text in texts:
            extracted_text += text.description + " "  # Add extracted text to the string
    return extracted_text

def ocr_pdf(pdf_path):
    """Performs OCR on a PDF file."""
    images = pdf_to_images(pdf_path)
    all_text = ""
    for image in images:
        page_text = detect_text_from_image(image)
        all_text += page_text + "\n\n"  # Add page break between pages
    return all_text



pdf_path = "9190014302.PDF" # Replace with your PDF file path

try:
    extracted_text = ocr_pdf(pdf_path)
    print(extracted_text)

    # Save to a text file:
    with open("extracted_text.txt", "w", encoding="utf-8") as f:
        f.write(extracted_text)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# GESVALT Sociedad de Tasación S.A. Inscrita en el registro especial de sociedades de tasación del Banco de España con el nº 4455 el día 27 de mayo de 1994.
# Gesvalt
# Sociedad de
# Tasación S.A.
# Motivo:
# Visado Digital
# Fecha:
# gesvaltⓇ
# Consultoría y
# Valoración
# Exp Nº:
# GV190004182V2
# 04/07/2019 16:53:49
# Advisory &
# Valuation
# INFORME DE VALORACIÓN:
# Finca rústica de labor secano con edificaciones. en PARAJE CERRO GORDO,
# Polígono 17, Parcela 19.
# 06225 - Ribera del Fresno (Badajoz - Extremadura. España)
# SOLICITANTE: BUILDINGCENTER, S.A.U.
# FINALIDAD: Circular 4/2017 (Adjudicados/Activos Propios)
# FECHA DEL INFORME: 24/06/2019
# Ref Cliente: 9190014302 GESVALT Sociedad de Tasación S.A. Inscrita en el registro especial de sociedades de tasación del Banco de España con el nº 4455 el día 27 de mayo de 1994 . Gesvalt Sociedad de Tasación S.A. Motivo : Visado Digital Fecha : gesvaltⓇ Consultoría y Valoración Exp Nº : GV190004182V2 04/07/2019 16:53:49 Advisory & Valuation INFORME DE VALORACIÓN : Finca rústica de labor secano con edificaciones . en PARAJE CERRO GORDO , Polígono 17 , Parcela 19 . 06225 - Ribera del Fresno ( Badajoz - Extremadura . España ) SOLICITANTE : BUILDINGCENTER , S.A.U. FINALIDAD : Circular 4/2017 ( Adjudicados / Activos Propios ) FECHA DEL INFORME : 24/06/2019 Ref Cliente : 9190014302
#
# Consultoría y
# Página C1 de C3
# gesvalt valoración
# Advisory &
# Valuation
# Gesvalt Sociedad de Tasación S.A.
# Inscrita en el registro especial de sociedades de tasación
# del Banco de España con el nº 4455 el día 27 de mayo de 1994
# CERTIFICADO DE TASACIÓN
# SANCHEZ MOVILLA, JAVIER, INGENIERO AGRONOMO en calidad de Tasador de Gesvalt Sociedad de Tasación S.A.
# ha realizado con fecha 24/06/2019 el informe de tasación con el nº de expediente abajo indicado.
# La visita se ha realizado el día 02/06/2019 por SANCHEZ MOVILLA, JAVIER, y los datos del bien son:
# TIPO DE BIEN TASADO:
# SITUACIÓN DEL BIEN:
# ESTADO DEL BIEN:
# SITUACIÓN DE OCUPACIÓN:
# ENTIDAD FINANCIERA:
# SOLICITANTE:
# NIF/CIF:
# DOMICILIO SOLICITANTE:
# FINALIDAD:
# Rústicas
# PARAJE CERRO GORDO, Polígono 17, Parcela 19. 06225 - Ribera
# del Fresno, Badajoz - Extremadura
# Terminado
# Se desconoce
# SERVIHABITAT SERVICIOS INMOBILIARIOS, S.L.
# BUILDINGCENTER, S.A.U.
# A63106157
# -
# PASEO RECOLETOS Nº 37, Planta 6. Madrid Madrid, Comunidad
# de (ESP)
# Circular 4/2017 (Adjudicados/Activos Propios)
# Esta valoración se ha realizado de acuerdo con la Orden ECO/805/2003, de 27 de Marzo, sobre normas de
# valoración de bienes inmuebles y de determinados derechos para ciertas finalidades financieras, (excepto en lo
# relativo a las comprobaciones derivadas de la visita al interior del inmueble). La finalidad no se encuentra entre
# las definidas en el artículo 2 de dicha normativa (ámbito de aplicación).
# VALOR DE TASACIÓN: 85.822,47 €
# ( OCHENTA Y CINCO MIL OCHOCIENTOS VEINTIDOS EUROS CON CUARENTA Y SIETE
# CÉNTIMOS)
# REGISTRO DE LA PROPIEDAD: ALMENDRALEJO-1
# UNIDAD
# 001
# Construcciones no
# vinculadas
# N° FINCA
# 10586
# NOMBRE
# 002
# Secano
# 10586
# IDUFIR
# SECC. TOMO LIBRO
# FOLIO
# INSC. REF. CATASTRAL
# 06002000647968
# 1
# 1892
# 204
# 193
# 2
# 06113A017000190000ZO
# 06113A017000190001XP
113A017000190001XP 06002000647968 1 1892 204 193 2 06113A017000190000ZO 06113A017000190001XP OBSERVACIONES REGISTRALES : Finca rústica ubicada en el Término Municipal de Ribera del Fresno provincia de Badajoz , registral nº 10586 del Registro de la Propiedad de Almendralejo . Correspondencia catastral : poligono 17 parcela 19 . Se comprueban las siguientes coincidencias : - Lindero norte , carretera de Hinojosa del Valle . - Existe similitud de superficies registral - catastral . - Es la única fábrica de quesos existente en esa carretera . - Se ha dispuesto de dos informes antecedentes ( Tinsa n ° exp . BA - 01645 / 09-6 y Global nº exp . 2005-000096 / 03 ) . OBSERVACIONES CATASTRALES : No existen CERTIFICADO Este certificado consta de 3 páginas y su validez es de seis meses a contar desde la fecha de emisión . Fecha límite de validez : 24/12/2019 El presente informe de tasación figura en los archivos sociales con el nº de referencia GV190004182V2 Insc . Reg . Mercantil de Madrid , Tomo 7992 , Libro 0 , Folio 82 , Sección 8 , Hoja M - 129105 , Inscripción 1ª - C.I.F. A80884372 REF .: 9190014302
#
# DATOS DE TENENCIA
# Consultoría y
# gesvalt valoración
# Advisory &
# Valuation
# N°FR
# 10586
# 10586
# 10586
# Titular registral
# Jose Cruz Pavón
# Isidro Cruz Pavón
# Jose Cruz Pavón y Catalina Rodriguez Pizarro
# OBSERVACIONES:
# Rég. gananciales.
# CUADRO DE SUPERFICIES
# Página C2 de C3
# NIF
# Propiedad
# %
# 76209350T
# Pleno dominio
# 33,33
# 09181019V
# 76209350T
# Pleno dominio
# 50,00
# Pleno dominio
# 16,67
# S. CONSTRUIDAS
# S. DE SUELO
# S. REG.
# UNIDAD
# N°F
# NOMBRE
# Construcciones no
# FC L
# (m²)
# S. CAT.
# (m²)
# S. COMP.
# (m²)
# S. REG.
# (Ha)
# S. CAT.
# (Ha)
# S. COMP.
# (Ha)
# ADOPT C. ADOPT S.
# (m²) (Ha)
# R
# 001
# C.no vincu 10586
# vinculadas
# 0
# 3
# 601,48
# 618,00
# 0,00
# 0,00
# 0,00
# 002
# Secano 10586
# Labor secano
# 0
# 3
# 0,00
# 0,00
# TOTAL SUP:
# 601,48
# 618,00
# 0,00 0,6440
# 0,00 0,6440
# 0,6605
# 0,00
# 0,0000
# 601,48
# 0,00
# 0,00
# 0,6605
# 0,0000
# 0,00 0,6440
# 601,48 0,6440
# 0,00
# OBSERVACIONES SUPERFICIES:
# Se ha adoptado la superficie menor entre la registral y la catastral, no se ha realizado la medición de las tierras.
# F.C.: Forma de comprobar
# 1. Croquis realizado por el tasador in situ
# 2. Medición sobre plano catastral
# 3. Medición sobre plano parcelario
# 4. No se ha tenido acceso al inmueble
# 5. Otros
# 6. Plano aportado por la propiedad con medidas realizadas in situ
# 7. Plano aportado por la propiedad sin medidas
# L: Comprobación de linderos
# 1. Sí, los linderos Coinciden con los reflejados en la doc. Registral
# 2. No, no existe descripción de linderos en la doc. Registral
# 3. No, alguno de los linderos está referidos a particulares
# 4. No, alguno de los linderos no coinciden con los comprobados
# 5. No, no coinciden ninguno de los linderos registrales
# 6. No, no se ha tenido acceso al inmueble
# 7. No, los linderos están referidos a la finca matriz
# MÉTODOS Y VALORES
# UNIDAD
# N°F
# 001
# 002
# C.no vincu
# Secano
# 10586
# 10586
# NOMBRE
# Construcciones
# no vinculadas
# CT (€)
# CMP (€)
# SCN (€)
# SRD (€)
# AE Rus (€)
# 78.589,38
# 0,00
# 202.097,28
# 78.589,38
# 0,00
# Labor secano
# 0,00
# TOTALES:
# 78.589,38
# 9.057,53
# 9.057,53
# 0,00
# 0,00
# 7.233,09
# 202.097,28
# 78.589,38
# 7.233,09
# MÉTODOS UTILIZADOS PARA OBTENER EL VALOR CERTIFICADO: CT, CMP, AE Rus
# Codificación:
# CT - Método del Coste
# CTEA - Método del Coste-Estado Actual
# CTHET- Método del Coste- Hipótesis de Edificio
# Terminado.
# CMP - Método de Comparación
# CMP AJUST - Método de Comparación Ajustado
# VML - Valor Máximo Legal
# ACA - Método de Actualización de Contrato de
# Alquiler
# AMA - Método de Actualización de Rentas de
# Mercado de Alquileres
# RE- Método Residual Estático
# RD-Método Residual Dinámico
# AEE - Actualización de Rentas de Explotación
# Económica
# O - Otros métodos
# VLIQ- Valor Liquidativo
# VVR Valor de Venta Rápida
# S-Suelo
# SCN- Seguro de Construcción a Nuevo
# SRD- Seguro Real Decreto 716/2009
# VALORES DE TASACIÓN
# UNIDAD
# N°FINCA
# NOMBRE
# Construccio
# ΜΕΤΟ
# ADOP.
# SUPERFICIE
# CONS.(m²) SUELO(Ha) UNITARIO
# SUPERFICIE
# V.
# V.
# LIQUIDATIVO
# (€)
# V. UNIDAD
# (€)
# V.
# AGRUPACIÓN
# (€)
# 001
# C.no vincu
# 10586
# 002
# Secano
# 10586
# nes no
# vinculadas
# Labor
# secano
# CT
# 601,48
# 0,00
# 130,66
# AERus
# TOTALES:
# 0,00
# 601,48
# 0,6440
# 0,6440
# 11.231,51
# VALOR DE TASACIÓN:
# 0,00
# 0,00
# 78.589,38
# 7.233,09
# 85.822,47
# 85.822,47
# 0,00
# 85.822,47
# 85.822,47
# CONDICIONANTES
# CERTIFICADO
# Este certificado consta de 3 páginas y su validez es de seis meses a contar desde la fecha de emisión.
# Fecha límite de validez: 24/12/2019
# El presente informe de tasación figura en los archivos sociales con el nº de referencia GV190004182V2
# Insc. Reg. Mercantil de Madrid, Tomo 7992, Libro 0, Folio 82, Sección 8, Hoja M-129105, Inscripción 1ª - C.I.F. A80884372
# REF.: 9190014302 DATOS DE TENENCIA Consultoría y gesvalt valoración Advisory & Valuation N ° FR 10586 10586 10586 Titular registral Jose Cruz Pavón Isidro Cruz Pavón Jose Cruz Pavón y Catalina Rodriguez Pizarro OBSERVACIONES : Rég . gananciales . CUADRO DE SUPERFICIES Página C2 de C3 NIF Propiedad % 76209350T Pleno dominio 33,33 09181019V 76209350T Pleno dominio 50,00 Pleno dominio 16,67 S. CONSTRUIDAS S. DE SUELO S. REG . UNIDAD N ° F NOMBRE Construcciones no FC L ( m² ) S. CAT . ( m² ) S.
#
# CC01b
# Unidades:
# gesvalt valoración
# Consultoría y
# Advisory &
# Valuation
# Página C3 de C3
# La presente valoración queda condicionada a que se realice el acceso al interior del inmueble y se compruebe que su
# descripción y superficies coinciden con las utilizadas en el presente informe.
# Afecta a todas Unidades de valor
# ADVERTENCIAS
# ADV
# Unidades:
# El inmueble ha sido destinado a fábrica de quesos y vaquería, si bien no se ha dispuesto de documentación que acredite la
# legalidad de la actividad industrial que se ha venido desarrollando sobre suelo rústico. A falta de documentacion no aportada
# (calificación urbanística, autorizaciones ambientales, licencias urbanísticas, etc) que garanticen la reactivacion del uso
# industrial del inmueble, no se valora como tal, en su lugar se valora el conjunto edificatorio para un uso agrícola/ganadero.
# No se ha podido inspeccionar interiormente las edificaciones existentes por lo que se ha considerado que están libres de
# ocupantes y que tienen unas calidades y estado de conservación equivalentes a su aspecto exterior.
# Afecta a todas Unidades de valor
# AV31
# Unidades:
# AV33
# Unidades:
# Se advierte de que no ha sido posible corroborar sobre el terreno alguno de los linderos reflejados en nota simple (no se ha
# dispuesto de certificado de linderos), de manera que permita relacionar sin ninguna duda la realidad física con la descripción
# registral, a pesar de lo cual no existen dudas de identificación, (se comprueba la coincidencia del lindero norte, carretera de
# Hinojosa del Valle y similitud de superficies). Aconsejamos incluir en la escritura la identificación concretas de polígono/s y
# parcela/s, protocolizando el plano y la cédula catastral.
# Afecta a todas Unidades de valor
# Se advierte de que en cumplimento de la orden ECO 805/2003 de 27 de marzo, el valor del suelo se ha obtenido mediante la
# aplicación de dos métodos: método de comparación y método de actualización de rentas agrarias. A efectos de certificado, y
# atendiendo a la exigible prudencia valorativa, se adopta el menor de ambos valores.
# Afecta a todas Unidades de valor
# OBSERVACIONES
# Se ha detectado que en el articulo 5 de la la Ordenanza de Punto Limpio (publicada en el BOP n° 134 de 16 de julio de 2012, anuncio n°
# 4906/2012) se indica que la ubicación del mismo se corresponde con la finca valorada (poligono 17 parcela 19) si bien se aporta Certficado
# del Ayuntamiento donde se indica que esta informacion es incorrecta, encontrándose la ubicación del mismo es otra finca distinta (poligono
# 17 parcela 58 y no la parcela 19 del mismo polígono que indica la Ordenanza).
# IDENTIFICACIÓN
# Se comprueban las siguientes coincidencias:
# - Lindero norte, carretera de Hinojosa del Valle.
# - Existe similitud de superficies registral - catastral.
# - Es la única fábrica de quesos existente en esa carretera.
# - Se ha dispuesto de dos informes antecedentes (Tinsa n° exp. BA-01645/09-6 y Global n° exp. 2005-000096/03).
# Gesvalt, S.A., no se hace responsable de los posibles vicios ocultos de la edificación. Del valor de tasación
# habría que deducir, en su caso, las posibles cargas y gravámenes que no estén contempladas en este informe.
# Fecha de la última visita
# Fecha de emisión del informe
# 02/06/2019
# 24/06/2019
# Fecha límite de validez
# 24/12/2019
# Técnico Tasador
# Gesvalt Sociedad de Tasacion, S.A.
# Blongs
# SANCHEZ MOVILLA, JAVIER
# INGENIERO AGRONOMO
# Col. No: 565
# MONGE MENDEZ, MARIA BEGOÑA
# Representante de la Sociedad
# CERTIFICADO
# Este certificado consta de 3 páginas y su validez es de seis meses a contar desde la fecha de emisión.
# Fecha límite de validez: 24/12/2019
# El presente informe de tasación figura en los archivos sociales con el nº de referencia GV190004182V2
# Insc. Reg. Mercantil de Madrid, Tomo 7992, Libro 0, Folio 82, Sección 8, Hoja M-129105, Inscripción 1ª - C.I.F. A80884372
# REF.: 9190014302 CC01b Unidades : gesvalt valoración Consultoría y Advisory & Valuation Página C3 de C3 La presente valoración queda condicionada a que se realice el acceso al interior del inmueble y se compruebe que su descripción y superficies coinciden con las utilizadas en el presente informe . Afecta a todas Unidades de valor ADVERTENCIAS ADV Unidades : El inmueble ha sido destinado a fábrica de quesos y vaquería , si bien no se ha dispuesto de documentación que acredite la legalidad de la actividad industrial que se ha venido desarrollando sobre suelo rústico . A falta de documentacion no aportada ( calificación urbanística , autorizaciones ambientales , licencias urbanísticas , etc ) que garanticen la reactivacion del uso industrial del inmueble , no se valora como tal , en su lugar se valora el conjunto edificatorio para un uso agrícola / ganadero . No se ha podido inspeccionar interiormente las edificaciones existentes por lo que se ha considerado que están libres de ocupantes y que tienen unas calidades y estado de conservación equivalentes a su aspecto exterior . Afecta a todas Unidades de valor AV31 Unidades : AV33 Unidades : Se advierte de que no ha sido posible corroborar sobre el terreno alguno de los linderos reflejados en nota simple ( no se ha dispuesto de certificado de linderos ) , de manera que permita relacionar sin ninguna duda la realidad física con la descripción registral , a pesar de lo cual no existen dudas de identificación , ( se comprueba la coincidencia del lindero norte , carretera de Hinojosa del Valle y similitud de superficies ) . Aconsejamos incluir en la escritura la identificación concretas de polígono / s y parcela / s , protocolizando el plano y la cédula catastral . Afecta a todas Unidades de valor Se advierte de que en cumplimento de la orden ECO 805/2003 de 27 de marzo , el valor del suelo se ha obtenido mediante la aplicación de dos métodos : método de comparación y método de actualización de rentas agrarias . A efectos de certificado , y atendiendo a la exigible prudencia valorativa , se adopta el menor de ambos valores . Afecta a todas Unidades de valor OBSERVACIONES Se ha detectado que en el articulo 5 de la la Ordenanza de Punto Limpio ( publicada en el BOP n ° 134 de 16 de julio de 2012 , anuncio n ° 4906/2012 ) se indica que la ubicación del mismo se corresponde con la finca valorada ( poligono 17 parcela 19 ) si bien se aporta Certficado del Ayuntamiento donde se indica que esta informacion es incorrecta , encontrándose la ubicación del mismo es otra finca distinta ( poligono 17 parcela 58 y no la parcela 19 del mismo polígono que indica la Ordenanza ) . IDENTIFICACIÓN Se comprueban las siguientes coincidencias : - Lindero norte , carretera de Hinojosa del Valle . - Existe similitud de superficies registral - catastral . - Es la única fábrica de quesos existente en esa carretera . - Se ha dispuesto de dos informes antecedentes ( Tinsa n ° exp . BA - 01645 / 09-6 y Global n ° exp . 2005-000096 / 03 ) . Gesvalt , S.A. , no se hace responsable de los posibles vicios ocultos de la edificación . Del valor de tasación habría que deducir , en su caso , las posibles cargas y gravámenes que no estén contempladas en este informe . Fecha de la última visita Fecha de emisión del informe 02/06/2019 24/06/2019 Fecha límite de validez 24/12/2019 Técnico Tasador Gesvalt Sociedad de Tasacion , S.A. Blongs SANCHEZ MOVILLA , JAVIER INGENIERO AGRONOMO Col. No : 565 MONGE MENDEZ , MARIA BEGOÑA Representante de la Sociedad CERTIFICADO Este certificado consta de 3 páginas y su validez es de seis meses a contar desde la fecha de emisión . Fecha límite de validez : 24/12/2019 El presente informe de tasación figura en los archivos sociales con el nº de referencia GV190004182V2 Insc . Reg . Mercantil de Madrid , Tomo 7992 , Libro 0 , Folio 82 , Sección 8 , Hoja M - 129105 , Inscripción 1ª - C.I.F. A80884372 REF .: 9190014302
#
# Exp. n° GV190004182V2
# Pág. P1/P2
# APARTADO PREVIO
# El presente documento ha sido realizado por Gesvalt Sociedad de Tasación, S.A., inscrita con el nº 4.455 en el registro de entidades
# especializadas en tasaciones en el Banco de España con fecha 27 de mayo de 1.994
# DATOS DEL INMUEBLE OBJETO DEL PRESENTE INFORME
# TIPO DE BIEN TASADO:
# ENTIDAD FINANCIERA:
# SOLICITANTE:
# NIF/CIF:
# DOMICILIO SOLICITANTE:
# FINALIDAD DE LA TASACIÓN
# Rústicas
# SERVIHABITAT SERVICIOS INMOBILIARIOS, S.L.
# BUILDINGCENTER, S.A.U.
# A63106157
# -
# PASEO RECOLETOS Nº 37, Planta 6. Madrid Madrid, Comunidad de
# (ESP)
# La finalidad de la tasación es determinar el valor de mercado del bien inmueble a efectos de lo establecido en
# el Anejo 9 de la Circular 4/2017 de 27 de noviembre, del Banco de España, a entidades de crédito, sobre normas
# de información financiera pública y reservada y modelos de estados financieros, para inmuebles adjudicados o
# recibidos en pago de deudas.
# Esta valoración se ha realizado de acuerdo con la Orden ECO/805/2003, de 27 de Marzo, sobre normas de
# valoración de bienes inmuebles y de determinados derechos para ciertas finalidades financieras, (excepto en lo
# relativo a las comprobaciones derivadas de la visita al interior del inmueble). La finalidad no se encuentra entre
# las definidas en el artículo 2 de dicha normativa (ámbito de aplicación).
# EMPLAZAMIENTO:
# PARAJE CERRO GORDO, Polígono 17, Parcela 19.
# TÉRMINO MUNICIPAL:
# 06225 Ribera del Fresno
# PROVINCIA:
# Badajoz Extremadura
# PAÍS:
# ESP
# -
# DATOS DE TENENCIA
# N°FR
# 10586
# 10586
# 10586
# Titular registral
# Jose Cruz Pavón
# Isidro Cruz Pavón
# Jose Cruz Pavón y Catalina Rodriguez Pizarro
# OBSERVACIONES:
# Rég. gananciales.
# NIF
# Propiedad
# %
# 76209350T
# 09181019V
# 76209350T
# Pleno dominio
# 33,33
# Pleno dominio
# 50,00
# Pleno dominio
# 16,67
# gesvaltⓇ
# Consultoría y
# Valoración
# Advisory &
# Valuation
# Gesvalt Sociedad de Tasación, S.A.. Inscrita en el registro de sociedades de tasación
# del Banco de España con el nº 4455 el día 27 de mayo de 1994
# MÉTODOS UTILIZADOS PARA OBTENER EL VALOR CERTIFICADO: CT, CMP, AE Rus
# Codificación:
# CT - Método del Coste
# CTEA - Método del Coste-Estado Actual
# CTHET- Método del Coste- Hipótesis de Edificio
# Terminado.
# CMP - Método de Comparación
# CMP AJUST - Método de Comparación Ajustado
# VML - Valor Máximo Legal
# ACA - Método de Actualización de Contrato de
# Alquiler
# AMA - Método de Actualización de Rentas de
# Mercado de Alquileres
# RE- Método Residual Estático
# RD-Método Residual Dinámico
# AEE - Actualización de Rentas de Explotación
# Económica
# O-Otros métodos
# VLIQ- Valor Liquidativo
# VVR Valor de Venta Rápida
# S- Suelo
# SCN- Seguro de Construcción a Nuevo
# SRD- Seguro Real Decreto 716/2009
# VALORES DE TASACIÓN
# UNIDAD
# N°FINCA
# NOMBRE
# Construccio
# METO
# ADOP.
# SUPERFICIE
# CONS.(m²)
# SUPERFICIE
# SUELO(Ha) UNITARIO
# V.
# V.
# LIQUIDATIVO
# (€)
# V. UNIDAD
# (€)
# V.
# AGRUPACIÓN
# (€)
# 001
# C.no vincu
# 10586
# 002
# Secano
# 10586
# nes no
# vinculadas
# Labor
# secano
# CT
# 601,48
# 0,00
# 130,66
# AERus
# TOTALES:
# 0,00
# 601,48
# 0,6440
# 0,6440
# 11.231,51
# VALOR DE TASACIÓN:
# 0,00
# 78.589,38
# 85.822,47
# 0,00
# 7.233,09
# 85.822,47
# 0,00
# 85.822,47
# 85.822,47
# VALOR DE TASACIÓN: 85.822,47 €
# (OCHENTA Y CINCO MIL OCHOCIENTOS VEINTIDOS EUROS CON CUARENTA Y SIETE CÉNTIMOS )
# gesvaltⓇ
# Consultoría y
# Valoración
# Advisory &
# Valuation
# Gesvalt Sociedad de Tasación, S.A.. Inscrita en el registro de sociedades de tasación
# del Banco de España con el nº 4455 el día 27 de mayo de 1994
# REF.:9190014302 REGISTRO DE LA PROPIEDAD : ALMENDRALEJO - 1 Exp . n ° GV190004182V2 Pág . P2 / P2 UNIDAD 001 C.no vincu N ° FINCA 10586 IDUFIR SECC . TOMO LIBRO FOLIO INSC . REF . CATASTRAL 06002000647968 1 1892 204 193 2 06113A017000190000ZO 002 Secano 10586 06002000647968 1 1892 204 193 2 06113A017000190001XP 06113A017000190000ZO 06113A017000190001XP MÉTODOS Y VALORES UNIDAD N ° F 001 002 C.no vincu Secano 10586 10586 NOMBRE Construcciones no vinculadas CT ( € ) CMP ( € ) SCN ( € ) SRD ( € ) AE Rus ( € ) 78.589,38 0,00 202.097,28 78.589,38 Labor secano 0,00 9.057,53 0,00 0,00 TOTALES : 78.589,38 9.057,53 202.097,28 78.589,38 0,00 7.233,09 7.233,09 MÉTODOS UTILIZADOS PARA OBTENER EL VALOR CERTIFICADO : CT , CMP , AE Rus Codificación : CT - Método del Coste CTEA - Método del Coste - Estado Actual CTHET- Método del Coste- Hipótesis de Edificio Terminado . CMP - Método de Comparación CMP AJUST - Método de Comparación Ajustado VML - Valor Máximo Legal ACA - Método de Actualización de Contrato de Alquiler AMA - Método de Actualización de Rentas de Mercado de Alquileres RE- Método Residual Estático RD - Método Residual Dinámico AEE - Actualización de Rentas de Explotación Económica O - Otros métodos VLIQ- Valor Liquidativo VVR Valor de Venta Rápida S- Suelo SCN- Seguro de Construcción a Nuevo SRD- Seguro Real Decreto 716/2009 VALORES DE TASACIÓN UNIDAD N ° FINCA NOMBRE Construccio METO ADOP . SUPERFICIE CONS . ( m² ) SUPERFICIE SUELO ( Ha ) UNITARIO V. V. LIQUIDATIVO ( € ) V. UNIDAD ( € ) V. AGRUPACIÓN ( € ) 001 C.no vincu 10586 002 Secano 10586 nes no vinculadas Labor secano CT 601,48 0,00 130,66 AERus TOTALES : 0,00 601,48 0,6440 0,6440 11.231,51 VALOR DE TASACIÓN : 0,00 78.589,38 85.822,47 0,00 7.233,09 85.822,47 0,00 85.822,47 85.822,47 VALOR DE TASACIÓN : 85.822,47 € ( OCHENTA Y CINCO MIL OCHOCIENTOS VEINTIDOS EUROS CON CUARENTA Y SIETE CÉNTIMOS ) gesvaltⓇ Consultoría y Valoración Advisory & Valuation Gesvalt Sociedad de Tasación , S.A .. Inscrita en el registro de sociedades de tasación del Banco de España con el nº 4455 el día 27 de mayo de 1994 REF.:9190014302
#
# INFORME DE TASACIÓN
# 1. SOLICITANTE DE LA TASACIÓN Y FINALIDAD
# Exp. n° GV190004182V2 Pág. 1 / 14
# ENTIDAD FINANCIERA
# SERVIHABITAT SERVICIOS INMOBILIARIOS, S.L.
# SOLICITANTE/S
# BUILDINGCENTER, S.A.U.
# FINALIDAD
# La finalidad de la tasación es determinar el valor de mercado del bien inmueble a efectos de lo establecido en
# el Anejo 9 de la Circular 4/2017 de 27 de noviembre, del Banco de España, a entidades de crédito, sobre normas
# de información financiera pública y reservada y modelos de estados financieros, para inmuebles adjudicados o
# recibidos en pago de deudas.
# Esta valoración se ha realizado de acuerdo con la Orden ECO/805/2003, de 27 de Marzo, sobre normas de
# valoración de bienes inmuebles y de determinados derechos para ciertas finalidades financieras, (excepto en lo
# relativo a las comprobaciones derivadas de la visita al interior del inmueble). La finalidad no se encuentra entre
# las definidas en el artículo 2 de dicha normativa (ámbito de aplicación).
# 2. IDENTIFICACIÓN Y LOCALIZACIÓN
# DESCRIPCIÓN
# Finca rústica de labor secano con edificaciones.
# LOCALIZACIÓN
# Dirección: PARAJE CERRO GORDO, Polígono 17, Parcela 19.
# Municipio: 06225 - Ribera del Fresno, Badajoz - Extremadura. España
# FOTOGRAFÍAS EXTERIORES
# IDENTIFICACIÓN REGISTRAL Y CATASTRAL
# gesvaltⓇ
# Consultoría y
# Valoración
# Advisory &
# Valuation
# Gesvalt Sociedad de Tasación, S.A.. Inscrita en el registro de sociedades de tasación
# del Banco de España con el nº 4455 el día 27 de mayo de 1994
# REF.: 9190014302 INFORME DE TASACIÓN 1. SOLICITANTE DE LA TASACIÓN Y FINALIDAD Exp . n ° GV190004182V2 Pág . 1 / 14 ENTIDAD FINANCIERA SERVIHABITAT SERVICIOS INMOBILIARIOS , S.L. SOLICITANTE / S BUILDINGCENTER , S.A.U. FINALIDAD La finalidad de la tasación es determinar el valor de mercado del bien inmueble a efectos de lo establecido en el Anejo 9 de la Circular 4/2017 de 27 de noviembre , del Banco de España , a entidades de crédito , sobre normas de información financiera pública y reservada y modelos de estados financieros , para inmuebles adjudicados o recibidos en pago de deudas . Esta valoración se ha realizado de acuerdo con la Orden ECO / 805 / 2003 , de 27 de Marzo , sobre normas de valoración de bienes inmuebles y de determinados derechos para ciertas finalidades financieras , ( excepto en lo relativo a las comprobaciones derivadas de la visita al interior del inmueble ) . La finalidad no se encuentra entre las definidas en el artículo 2 de dicha normativa ( ámbito de aplicación ) . 2. IDENTIFICACIÓN Y LOCALIZACIÓN DESCRIPCIÓN Finca rústica de labor secano con edificaciones . LOCALIZACIÓN Dirección : PARAJE CERRO GORDO , Polígono 17 , Parcela 19 . Municipio : 06225 - Ribera del Fresno , Badajoz - Extremadura . España FOTOGRAFÍAS EXTERIORES IDENTIFICACIÓN REGISTRAL Y CATASTRAL gesvaltⓇ Consultoría y Valoración Advisory & Valuation Gesvalt Sociedad de Tasación , S.A .. Inscrita en el registro de sociedades de tasación del Banco de España con el nº 4455 el día 27 de mayo de 1994 REF .: 9190014302
#
# DATOS DE TENENCIA
# Titular registral
# Jose Cruz Pavón
# Isidro Cruz Pavón
# N°FR
# 10586
# 10586
# 10586
# OBSERVACIONES:
# Rég. gananciales.
# Jose Cruz Pavón y Catalina Rodriguez Pizarro
# REGISTRO DE LA PROPIEDAD: ALMENDRALEJO-1
# UNIDAD
# 001
# Construcciones no
# vinculadas
# N° FINCA
# 10586
# NOMBRE
# 002
# Secano
# 10586
# Exp. n° GV190004182V2 Pág. 2/14
# NIF
# Propiedad
# %
# 76209350T
# Pleno dominio
# 33,33
# 09181019V
# 76209350T
# Pleno dominio
# 50,00
# Pleno dominio
# 16,67
# IDUFIR
# 06002000647968
# 1
# SECC. TOMO LIBRO
# 1892
# FOLIO
# INSC.
# REF. CATASTRAL
# 204
# 193
# 2
# 06113A017000190000ZO
# 06113A017000190001XP
# 06002000647968
# 1
# 1892
# 204
# 193
# 2
# 06113A017000190000ZO
# 06113A017000190001XP
# OBSERVACIONES REGISTRALES:
# Finca rústica ubicada en el Término Municipal de Ribera del Fresno provincia de Badajoz, registral nº 10586 del Registro de la Propiedad de
# Almendralejo. Correspondencia catastral: poligono 17 parcela 19.
# Se comprueban las siguientes coincidencias:
# - Lindero norte, carretera de Hinojosa del Valle.
# - Existe similitud de superficies registral - catastral.
# - Es la única fábrica de quesos existente en esa carretera.
# - Se ha dispuesto de dos informes antecedentes (Tinsa n° exp. BA-01645/09-6 y Global n° exp. 2005-000096/03).
# OBSERVACIONES CATASTRALES:
# No existen
# 3. COMPROBACIONES Y DOCUMENTACIÓN
# COMPROBACIONES REALIZADAS
# Adecuación Planeamiento Urbanístico: No
# Régimen de Protección del Patrimonio Arquitectónico: No
# Si cumple la Normativa Urbanística Actual: No
# Topografía:
# Grado de consolidación (%):
# EQUIPAMIENTOS
# Atractivo comercial:
# Exp. n° GV190004182V2 Pág. 4 / 14
# Agrícola
# Municipio autónomo
# Según el padrón del Instituto Nacional de Estadística de 2017:
# 3.394 habitantes de derecho.
# Ligero desnivel
# 100,00
# Bajo
# Tránsito peatonal:
# Aparcamientos:
# Escolar:
# Sanitario:
# Lúdico:
# COMUNICACIONES
# Aeropuerto:
# Tipo de carreteras:
# Ferrocarril:
# Autobuses:
# Metropolitano:
# Estación de metro más cercana:
# Puerto:
# INFORMACIÓN AMBIENTAL
# Impacto medioambiental:
# Normativa especial de protección
# ambiental:
# Otros datos:
# ¿Existen factores ambientales que
# afectan al valor?:
# Escaso
# Suficiente
# No existe en la zona, pero sí en el casoc urbano.
# Asistencia sanitaria básica
# Escaso
# Sí, a mas de 50 km
# Nacional, comarcal y local
# No dispone de este servicio
# Interurbanos de línea regular
# No dispone de este servicio
# No procede.
# Sí a más de 50 km
# 4.4 PROVINCIA Y UBICACIÓN
# Consultoría y
# gesvalt valoración
# Advisory &
# Valuation
# Gesvalt Sociedad de Tasación, S.A.. Inscrita en el registro de sociedades de tasación
# del Banco de España con el nº 4455 el día 27 de mayo de 1994
# REF.: 9190014302 MUNICIPIO TIPO DE NÚCLEO ACTIVIDAD DOMINANTE NIVEL DE RENTA DE LA ZONA OCUPACIÓN LABORAL CRECIMIENTO DE LA POBLACIÓN Ribera del Fresno Municipio autónomo Agricola Medio Agrícola Nulo 4.3 ENTORNO LOCALIDAD Actividad dominante : Crecimiento de la población : Nivel de renta de la zona : Ocupación laboral : Tipo de núcleo : Población : Agricola Nulo Medio ENTORNO PRÓXIMO Grado de ocupación de las parcelas : Infraestructura exterior : Producción agraria predominante : Dimensión media de las fincas : Explotaciones ganaderas : Proximidad al casco urbano : Topografía : Grado de consolidación ( % ) : EQUIPAMIENTOS Atractivo comercial : Exp . n ° GV190004182V2 Pág . 4 / 14 Agrícola Municipio autónomo Según el padrón del Instituto Nacional de Estadística de 2017 : 3.394 habitantes de derecho . Ligero desnivel 100,00 Bajo Tránsito peatonal : Aparcamientos : Escolar : Sanitario : Lúdico : COMUNICACIONES Aeropuerto : Tipo de carreteras : Ferrocarril : Autobuses : Metropolitano : Estación de metro más cercana : Puerto : INFORMACIÓN AMBIENTAL Impacto medioambiental : Normativa especial de protección ambiental : Otros datos : ¿ Existen factores ambientales que afectan al valor ?: Escaso Suficiente No existe en la zona , pero sí en el casoc urbano . Asistencia sanitaria básica Escaso Sí , a mas de 50 km Nacional , comarcal y local No dispone de este servicio Interurbanos de línea regular No dispone de este servicio No procede . Sí a más de 50 km 4.4 PROVINCIA Y UBICACIÓN Consultoría y gesvalt valoración Advisory & Valuation Gesvalt Sociedad de Tasación , S.A .. Inscrita en el registro de sociedades de tasación del Banco de España con el nº 4455 el día 27 de mayo de 1994 REF .: 9190014302
#
# Exp. n° GV190004182V2 Pág. 5/14
# Alcara
# Gamovilla
# Brozas
# Monroy
# Casar de
# ámbito domiciliario.
# Diputación de Badajoz - B.O.P. n°. 134 - Anuncio 4906/2012 - lunes, 16 de julio de 2012
# Ofrecer una forma sencilla de deshacerse de residuos que por sus características no pueden o no deben ser
# gestionados a través de los sistemas tradicionales de recogida.
# - Evitar el vertido incontrolado de residuos voluminosos que no pueden ser eliminados a través de los servicios
# convencionales de recogida de basuras.
# -
# · Conseguir la separación en origen de los residuos, que serán recibidos, en distintos compartimentos diferenciados
# entre sí.
# - Buscar la mejor solución para cada tipo de residuos con el objetivo de conseguir la máxima valorización de los
# materiales y el mínimo coste en la gestión global.
# - Fomentar programas de sensibilización y formación ambiental entre los ciudadanos, procurando su participación e
# implicación en una gestión de los residuos respetuosa con el medio ambiente.
# Artículo 5. Ubicación.
# El punto limpio del municipio de Ribera del Fresno (Badajoz) está situado en el vertedero municipal, sito en el polígono
# 17, parcela 19, de este término municipal.
# Artículo 6. Responsabilidad.
# El Ayuntamiento de Ribera del Fresno adquiere la titularidad de los residuos entregados por el proveedor, que destinará
# a su eliminación, valoración y/o reciclado.
# Artículo 7. Prestación del servicio.
# Para la prestación del servicio se tendrá en cuenta que:
# - Sólo se admiten residuos generados por particulares, así como los pequeños comercios y oficinas.
# - Cada usuario sólo podrá hacer una entrega diaria de residuos.
# - El servicio es para uso exclusivo para los habitantes del municipio y el personal designado por el Ayuntamiento, podrá
# comprobar este extremo, a través de los siguientes medios:
# 1. Presentación del Documento Nacional de Identidad o pasaporte.
# 2. Empadronados en el municipio.
# 3. Con vivienda en propiedad o alquilada, o en usufructo en el municipio.
# - Se prohíbe la entrada de residuos de origen industrial. Las actividades industriales deberán gestionar sus propios
# residuos a través de gestores autorizados por la Comunidad Autónoma de Extremadura.
# TÍTULO II. IDENTIFICACIÓN DE RESIDUOS Y GESTIÓN
# Artículo 8. Tipología de los residuos.
# En el punto limpio se admiten los siguientes residuos:
# RESIDUO
# Metales (aluminio, chatarra, somieres)
# Maderas
# Voluminosos (muebles, colchones, enseres
# Residuos de construcción y demolición
# procedentes de obras menores
# Restos de poda y otros residuos vegetales
# Papel y cartón
# Envases (plásticos, metálicos, bricks)
# Textiles (ropa y calzado)
# Vidrios
# Electrodomésticos frío (frigoríficos, AA.CC, etc.)
# Electrodomésticos no frío (TV, lavadoras, etc.)
# Electrónicos (CPU, monitores, ofimática, etc.)
# Artículo 9. Formas de presentación de los residuos.
# CANTIDAD MÁXIMA
# 50 kg, entrega y día
# 50 kg, entrega y día
# 50 kg o un mueble de peso superior
# por entrega y día
# Normal producción doméstica
# Normal producción doméstica
# Normal producción doméstica
# 50 kg, entrega y día
# OBSERVACIONES
# Somieres, tubos, etc.
# Carpintería
# Embalaje, carpintería,
# muebles y enseres
# Normal producción doméstica
# Normal producción doméstica
# Normal producción doméstica
# De producción doméstica
# De producción doméstica
# De producción doméstica
# De producción doméstica
# De producción doméstica
# De producción doméstica
# De producción doméstica
# Para la recogida de los residuos anteriormente mencionados, estos deberán entregarse de acuerdo a unas normas de
# Documento firmado electrónicamente desde la plataforma esPublico Gestiona | Página 1 de 1 Ayuntamiento de Ribera del Fresno Expediente n.º : 1143/2019 Certificado Procedimiento : Certificados o Informes Urbanísticos Interesado : JAVIER SÁNCHEZ MOVILLA Fecha de iniciación : 06/06/2019 13:49 2019 - E - RC - 2302 Da Mª José Guillén , Secretaria - Interventora del Ayuntamiento de Ribera del Fresno , CERTIFICO : " Que de acuerdo con el informe del arquitecto técnico de 06/06/2019 consultada la información de la que se dispone en estas oficinas se hace saber que la finca sita en el polígono 17 parcela 58 , es propiedad del Ayuntamiento de Ribera del Fresno , y es en esta finca donde se ubica el PUNTO LIMPIO de esta localidad . Y no en la parcela 19 del mismo polígono , ya que esta es una parcela privada , y con acceso directo a la carretera de Ribera del Fresno a Hinojosa del Valle . " Y para que así conste y surta los efectos oportunos , expido , sello y firmo el presente de orden y con el visto bueno de la Sra . Alcaldesa en funciones en Ribera del Fresno en fecha a firma en el margen . DOCUMENTO FIRMADO ELECTRÓNICAMENTE C / Ayuntamiento , 1. Teléfonos 924 53 60 11 924 53 65 11 . RIBERA DEL FRESNO ( Badajoz ) . E - mail : ayuntamiento@riberadelfresno.es gesvaltⓇ Consultoría y Valoración Advisory & Valuation Gestión de Valoraciones y Tasaciones , S.A. Inscrita en el registro de sociedades de tasación del Banco de España con el nº 4455 el día 27 de mayo de 1994 REF.:9190014302 Exp . n ° GV190004182V2 Pág . A14 / A15 Cód . Validación : 6FRZEXFR7FSGKAYJFERSQJSLH | Verificación : http://riberadelfresno.sedelectronica.es/ Documento firmado electrónicamente desde la plataforma esPublico Gestiona | Página 1 de 1
#
# Exp. n° GV190004182V2 Pág. A15/A15
# A.5 FLUJO DE CAJA MÉTODO DE ACTUALIZACIÓN DE EXPLOTACIONES AGRARIAS
# AERus_Secano
# DATOS GENERALES
# Unidad de valor:
# Finca Registral:
# 002. Labor secano
# 10586
# Superficie: 0,6440 ha
# Total
# Total
# Periodo
# Amort.
# Tasa Imp.
# CAPEX
# Flujo de
# Flujo
# asociado al
# VAN
# Ingresos
# Gastos
# Caja
# inmueble
# 2019
# 518,03
# 393,19
# 0,00
# 0,00
# 0,00
# 124,85
# 124,85
# 121,07
# 2020
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 140,13
# 2021
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 135,89
# 2022
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 131,79
# 2023
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 127,80
# 2024
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 123,94
# 2025
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 120,20
# 2026
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 116,57
# 2027
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 113,04
# 2028
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 109,63
# 2029
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 106,31
# 2030
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 103,10
# 2031
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 99,99
# 2032
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 96,97
# 2033
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 94,04
# 2034
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 91,19
# 2035
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 88,44
# 2036
# 618,24
# 469,24
# 0,00
# 0,00
# 0,00
# 149,00
# 149,00
# 85,77
# 2037
# 100,21
# 76,06
# 0,00
# 0,00
# 0,00
# 24,15
# 24,15
# 13,48
# Total:
# 2.019,34
# gesvaltⓇ
# Consultoría y
# Valoración
# Advisory &
# Valuation
# Gestión de Valoraciones y Tasaciones, S.A. Inscrita en el registro de sociedades de tasación
# del Banco de España con el nº 4455 el día 27 de mayo de 1994
# REF.:9190014302 Exp . n ° GV190004182V2 Pág . A15 / A15 A.5 FLUJO DE CAJA MÉTODO DE ACTUALIZACIÓN DE EXPLOTACIONES AGRARIAS AERus_Secano DATOS GENERALES Unidad de valor : Finca Registral : 002. Labor secano 10586 Superficie : 0,6440 ha Total Total Periodo Amort . Tasa Imp . CAPEX Flujo de Flujo asociado al VAN Ingresos Gastos Caja inmueble 2019 518,03 393,19 0,00 0,00 0,00 124,85 124,85 121,07 2020 618,24 469,24 0,00 0,00 0,00 149,00 149,00 140,13 2021 618,24 469,24 0,00 0,00 0,00 149,00 149,00 135,89 2022 618,24 469,24 0,00 0,00 0,00 149,00 149,00 131,79 2023 618,24 469,24 0,00 0,00 0,00 149,00 149,00 127,80 2024 618,24 469,24 0,00 0,00 0,00 149,00 149,00 123,94 2025 618,24 469,24 0,00 0,00 0,00 149,00 149,00 120,20 2026 618,24 469,24 0,00 0,00 0,00 149,00 149,00 116,57 2027 618,24 469,24 0,00 0,00 0,00 149,00 149,00 113,04 2028 618,24 469,24 0,00 0,00 0,00 149,00 149,00 109,63 2029 618,24 469,24 0,00 0,00 0,00 149,00 149,00 106,31 2030 618,24 469,24 0,00 0,00 0,00 149,00 149,00 103,10 2031 618,24 469,24 0,00 0,00 0,00 149,00 149,00 99,99 2032 618,24 469,24 0,00 0,00 0,00 149,00 149,00 96,97 2033 618,24 469,24 0,00 0,00 0,00 149,00 149,00 94,04 2034 618,24 469,24 0,00 0,00 0,00 149,00 149,00 91,19 2035 618,24 469,24 0,00 0,00 0,00 149,00 149,00 88,44 2036 618,24 469,24 0,00 0,00 0,00 149,00 149,00 85,77 2037 100,21 76,06 0,00 0,00 0,00 24,15 24,15 13,48 Total : 2.019,34 gesvaltⓇ Consultoría y Valoración Advisory & Valuation Gestión de Valoraciones y Tasaciones , S.A. Inscrita en el registro de sociedades de tasación del Banco de España con el nº 4455 el día 27 de mayo de 1994 REF.:9190014302
