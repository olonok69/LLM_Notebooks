# %%
#!pip install --upgrade google-cloud-storage

# %%
# https://cloud.google.com/vision/docs/pdf

# %%
import json
import re
from google.cloud import storage
# Imports the Google Cloud client library
from google.cloud import vision
from google.oauth2 import service_account

# %%
key_path = "keys/electric-clone-238012-47cdb0d3319b.json"  
credentials = service_account.Credentials.from_service_account_file(
    key_path,
)

# %%
client = vision.ImageAnnotatorClient(credentials=credentials)

feature = vision.Feature(type_=vision.Feature.Type.DOCUMENT_TEXT_DETECTION)

# %%
#https://developers.google.com/resources/api-libraries/documentation/vision/v1/csharp/latest/classGoogle_1_1Apis_1_1Vision_1_1v1_1_1Data_1_1InputConfig.html

# %%
help(vision.InputConfig())
# Out:
# Help on InputConfig in module google.cloud.vision_v1.types.image_annotator object:
#
# class InputConfig(proto.message.Message)
#  |  InputConfig(mapping=None, *, ignore_unknown_fields=False, **kwargs)
#  |
#  |  The desired input location and metadata.
#  |
#  |  Attributes:
#  |      gcs_source (google.cloud.vision_v1.types.GcsSource):
#  |          The Google Cloud Storage location to read the
#  |          input from.
#  |      content (bytes):
#  |          File content, represented as a stream of bytes. Note: As
#  |          with all ``bytes`` fields, protobuffers use a pure binary
#  |          representation, whereas JSON representations use base64.
#  |
#  |          Currently, this field only works for BatchAnnotateFiles
#  |          requests. It does not work for AsyncBatchAnnotateFiles
#  |          requests.
#  |      mime_type (str):
#  |          The type of the file. Currently only
#  |          "application/pdf", "image/tiff" and "image/gif"
#  |          are supported. Wildcards are not supported.
#  |
#  |  Method resolution order:
#  |      InputConfig
#  |      proto.message.Message
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {'content': 'bytes', 'gcs_source': "'GcsSource'", 'm...
#  |
#  |  __base__ = <class 'proto.message.Message'>
#  |      The abstract base class for a message.
#  |
#  |      Args:
#  |          mapping (Union[dict, ~.Message]): A dictionary or message to be
#  |              used to determine the values for this message.
#  |          ignore_unknown_fields (Optional(bool)): If True, do not raise errors for
#  |              unknown fields. Only applied if `mapping` is a mapping type or there
#  |              are keyword parameters.
#  |          kwargs (dict): Keys and values corresponding to the fields of the
#  |              message.
#  |
#  |
#  |  __bases__ = (<class 'proto.message.Message'>,)
#  |
#  |  __mro__ = (<class 'google.cloud.vision_v1.types.image_annotator.InputC...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from proto.message.Message:
#  |
#  |  __delattr__(self, key)
#  |      Delete the value on the given field.
#  |
#  |      This is generally equivalent to setting a falsy value.
#  |
#  |  __dir__(self)
#  |      Default dir() implementation.
#  |
#  |  __eq__(self, other)
#  |      Return True if the messages are equal, False otherwise.
#  |
#  |  __getstate__(self)
#  |      Serialize for pickling.
#  |
#  |  __init__(self, mapping=None, *, ignore_unknown_fields=False, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ne__(self, other)
#  |      Return True if the messages are unequal, False otherwise.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, key, value)
#  |      Set the value on the given field.
#  |
#  |      For well-known protocol buffer types which are marshalled, either
#  |      the protocol buffer object or the Python equivalent is accepted.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from proto.message.Message:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from proto.message.Message:
#  |
#  |  __basicsize__ = 24
#  |
#  |  __hash__ = None
#  |
#  |  __text_signature__ = None
#  |
#  |  __weakrefoffset__ = 16
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from proto.message.MessageMeta:
#  |
#  |  copy_from(instance, other) from proto.message.MessageMeta
#  |      Equivalent for protobuf.Message.CopyFrom
#  |
#  |      Args:
#  |          instance: An instance of this message type
#  |          other: (Union[dict, ~.Message):
#  |              A dictionary or message to reinitialize the values for this message.
#  |
#  |  deserialize(payload: bytes) -> 'Message' from proto.message.MessageMeta
#  |      Given a serialized proto, deserialize it into a Message instance.
#  |
#  |      Args:
#  |          payload (bytes): The serialized proto.
#  |
#  |      Returns:
#  |          ~.Message: An instance of the message class against which this
#  |          method was called.
#  |
#  |  from_json(payload, *, ignore_unknown_fields=False) -> 'Message' from proto.message.MessageMeta
#  |      Given a json string representing an instance,
#  |      parse it into a message.
#  |
#  |      Args:
#  |          paylod: A json string representing a message.
#  |          ignore_unknown_fields (Optional(bool)): If True, do not raise errors
#  |              for unknown fields.
#  |
#  |      Returns:
#  |          ~.Message: An instance of the message class against which this
#  |          method was called.
#  |
#  |  pb(obj=None, *, coerce: bool = False) from proto.message.MessageMeta
#  |      Return the underlying protobuf Message class or instance.
#  |
#  |      Args:
#  |          obj: If provided, and an instance of ``cls``, return the
#  |              underlying protobuf instance.
#  |          coerce (bool): If provided, will attempt to coerce ``obj`` to
#  |              ``cls`` if it is not already an instance.
#  |
#  |  serialize(instance) -> bytes from proto.message.MessageMeta
#  |      Return the serialized proto.
#  |
#  |      Args:
#  |          instance: An instance of this message type, or something
#  |              compatible (accepted by the type's constructor).
#  |
#  |      Returns:
#  |          bytes: The serialized representation of the protocol buffer.
#  |
#  |  to_dict(instance, *, use_integers_for_enums=True, preserving_proto_field_name=True, including_default_value_fields=True, float_precision=None) -> 'Message' from proto.message.MessageMeta
#  |      Given a message instance, return its representation as a python dict.
#  |
#  |      Args:
#  |          instance: An instance of this message type, or something
#  |                    compatible (accepted by the type's constructor).
#  |          use_integers_for_enums (Optional(bool)): An option that determines whether enum
#  |              values should be represented by strings (False) or integers (True).
#  |              Default is True.
#  |          preserving_proto_field_name (Optional(bool)): An option that
#  |              determines whether field name representations preserve
#  |              proto case (snake_case) or use lowerCamelCase. Default is True.
#  |          including_default_value_fields (Optional(bool)): An option that
#  |              determines whether the default field values should be included in the results.
#  |              Default is True.
#  |          float_precision (Optional(int)): If set, use this to specify float field valid digits.
#  |              Default is None.
#  |
#  |      Returns:
#  |          dict: A representation of the protocol buffer using pythonic data structures.
#  |                Messages and map fields are represented as dicts,
#  |                repeated fields are represented as lists.
#  |
#  |  to_json(instance, *, use_integers_for_enums=True, including_default_value_fields=True, preserving_proto_field_name=False, sort_keys=False, indent=2, float_precision=None) -> str from proto.message.MessageMeta
#  |      Given a message instance, serialize it to json
#  |
#  |      Args:
#  |          instance: An instance of this message type, or something
#  |              compatible (accepted by the type's constructor).
#  |          use_integers_for_enums (Optional(bool)): An option that determines whether enum
#  |              values should be represented by strings (False) or integers (True).
#  |              Default is True.
#  |          preserving_proto_field_name (Optional(bool)): An option that
#  |              determines whether field name representations preserve
#  |              proto case (snake_case) or use lowerCamelCase. Default is False.
#  |          sort_keys (Optional(bool)): If True, then the output will be sorted by field names.
#  |              Default is False.
#  |          indent (Optional(int)): The JSON object will be pretty-printed with this indent level.
#  |              An indent level of 0 or negative will only insert newlines.
#  |              Pass None for the most compact representation without newlines.
#  |          float_precision (Optional(int)): If set, use this to specify float field valid digits.
#  |              Default is None.
#  |      Returns:
#  |          str: The json string representation of the protocol buffer.
#  |
#  |  wrap(pb) from proto.message.MessageMeta
#  |      Return a Message object that shallowly wraps the descriptor.
#  |
#  |      Args:
#  |          pb: A protocol buffer object, such as would be returned by
#  |              :meth:`pb`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from proto.message.MessageMeta:
#  |
#  |  __prepare__(name, bases, **kwargs) from builtins.type
#  |      __prepare__() -> dict
#  |      used to create the namespace for the class statement
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from proto.message.MessageMeta:
#  |
#  |  meta

# %%
mime_type = "application/pdf"
gcs_source_uri = "gs://pdf_extraction_iwm/input/pdf_test.pdf"
batch_size = 2

# %%
#input_config = vision.InputConfig(content=content_pdf, mime_type= mime_type)

# %%
gcs_source = vision.GcsSource(uri=gcs_source_uri)
input_config = vision.InputConfig(gcs_source=gcs_source, mime_type=mime_type)

# %%
help(vision.OutputConfig())
# Out:
# Help on OutputConfig in module google.cloud.vision_v1.types.image_annotator object:
#
# class OutputConfig(proto.message.Message)
#  |  OutputConfig(mapping=None, *, ignore_unknown_fields=False, **kwargs)
#  |
#  |  The desired output location and metadata.
#  |
#  |  Attributes:
#  |      gcs_destination (google.cloud.vision_v1.types.GcsDestination):
#  |          The Google Cloud Storage location to write
#  |          the output(s) to.
#  |      batch_size (int):
#  |          The max number of response protos to put into each output
#  |          JSON file on Google Cloud Storage. The valid range is [1,
#  |          100]. If not specified, the default value is 20.
#  |
#  |          For example, for one pdf file with 100 pages, 100 response
#  |          protos will be generated. If ``batch_size`` = 20, then 5
#  |          json files each containing 20 response protos will be
#  |          written under the prefix ``gcs_destination``.\ ``uri``.
#  |
#  |          Currently, batch_size only applies to GcsDestination, with
#  |          potential future support for other output configurations.
#  |
#  |  Method resolution order:
#  |      OutputConfig
#  |      proto.message.Message
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {'batch_size': 'int', 'gcs_destination': "'GcsDestin...
#  |
#  |  __base__ = <class 'proto.message.Message'>
#  |      The abstract base class for a message.
#  |
#  |      Args:
#  |          mapping (Union[dict, ~.Message]): A dictionary or message to be
#  |              used to determine the values for this message.
#  |          ignore_unknown_fields (Optional(bool)): If True, do not raise errors for
#  |              unknown fields. Only applied if `mapping` is a mapping type or there
#  |              are keyword parameters.
#  |          kwargs (dict): Keys and values corresponding to the fields of the
#  |              message.
#  |
#  |
#  |  __bases__ = (<class 'proto.message.Message'>,)
#  |
#  |  __mro__ = (<class 'google.cloud.vision_v1.types.image_annotator.Output...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from proto.message.Message:
#  |
#  |  __delattr__(self, key)
#  |      Delete the value on the given field.
#  |
#  |      This is generally equivalent to setting a falsy value.
#  |
#  |  __dir__(self)
#  |      Default dir() implementation.
#  |
#  |  __eq__(self, other)
#  |      Return True if the messages are equal, False otherwise.
#  |
#  |  __getstate__(self)
#  |      Serialize for pickling.
#  |
#  |  __init__(self, mapping=None, *, ignore_unknown_fields=False, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ne__(self, other)
#  |      Return True if the messages are unequal, False otherwise.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, key, value)
#  |      Set the value on the given field.
#  |
#  |      For well-known protocol buffer types which are marshalled, either
#  |      the protocol buffer object or the Python equivalent is accepted.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from proto.message.Message:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from proto.message.Message:
#  |
#  |  __basicsize__ = 24
#  |
#  |  __hash__ = None
#  |
#  |  __text_signature__ = None
#  |
#  |  __weakrefoffset__ = 16
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from proto.message.MessageMeta:
#  |
#  |  copy_from(instance, other) from proto.message.MessageMeta
#  |      Equivalent for protobuf.Message.CopyFrom
#  |
#  |      Args:
#  |          instance: An instance of this message type
#  |          other: (Union[dict, ~.Message):
#  |              A dictionary or message to reinitialize the values for this message.
#  |
#  |  deserialize(payload: bytes) -> 'Message' from proto.message.MessageMeta
#  |      Given a serialized proto, deserialize it into a Message instance.
#  |
#  |      Args:
#  |          payload (bytes): The serialized proto.
#  |
#  |      Returns:
#  |          ~.Message: An instance of the message class against which this
#  |          method was called.
#  |
#  |  from_json(payload, *, ignore_unknown_fields=False) -> 'Message' from proto.message.MessageMeta
#  |      Given a json string representing an instance,
#  |      parse it into a message.
#  |
#  |      Args:
#  |          paylod: A json string representing a message.
#  |          ignore_unknown_fields (Optional(bool)): If True, do not raise errors
#  |              for unknown fields.
#  |
#  |      Returns:
#  |          ~.Message: An instance of the message class against which this
#  |          method was called.
#  |
#  |  pb(obj=None, *, coerce: bool = False) from proto.message.MessageMeta
#  |      Return the underlying protobuf Message class or instance.
#  |
#  |      Args:
#  |          obj: If provided, and an instance of ``cls``, return the
#  |              underlying protobuf instance.
#  |          coerce (bool): If provided, will attempt to coerce ``obj`` to
#  |              ``cls`` if it is not already an instance.
#  |
#  |  serialize(instance) -> bytes from proto.message.MessageMeta
#  |      Return the serialized proto.
#  |
#  |      Args:
#  |          instance: An instance of this message type, or something
#  |              compatible (accepted by the type's constructor).
#  |
#  |      Returns:
#  |          bytes: The serialized representation of the protocol buffer.
#  |
#  |  to_dict(instance, *, use_integers_for_enums=True, preserving_proto_field_name=True, including_default_value_fields=True, float_precision=None) -> 'Message' from proto.message.MessageMeta
#  |      Given a message instance, return its representation as a python dict.
#  |
#  |      Args:
#  |          instance: An instance of this message type, or something
#  |                    compatible (accepted by the type's constructor).
#  |          use_integers_for_enums (Optional(bool)): An option that determines whether enum
#  |              values should be represented by strings (False) or integers (True).
#  |              Default is True.
#  |          preserving_proto_field_name (Optional(bool)): An option that
#  |              determines whether field name representations preserve
#  |              proto case (snake_case) or use lowerCamelCase. Default is True.
#  |          including_default_value_fields (Optional(bool)): An option that
#  |              determines whether the default field values should be included in the results.
#  |              Default is True.
#  |          float_precision (Optional(int)): If set, use this to specify float field valid digits.
#  |              Default is None.
#  |
#  |      Returns:
#  |          dict: A representation of the protocol buffer using pythonic data structures.
#  |                Messages and map fields are represented as dicts,
#  |                repeated fields are represented as lists.
#  |
#  |  to_json(instance, *, use_integers_for_enums=True, including_default_value_fields=True, preserving_proto_field_name=False, sort_keys=False, indent=2, float_precision=None) -> str from proto.message.MessageMeta
#  |      Given a message instance, serialize it to json
#  |
#  |      Args:
#  |          instance: An instance of this message type, or something
#  |              compatible (accepted by the type's constructor).
#  |          use_integers_for_enums (Optional(bool)): An option that determines whether enum
#  |              values should be represented by strings (False) or integers (True).
#  |              Default is True.
#  |          preserving_proto_field_name (Optional(bool)): An option that
#  |              determines whether field name representations preserve
#  |              proto case (snake_case) or use lowerCamelCase. Default is False.
#  |          sort_keys (Optional(bool)): If True, then the output will be sorted by field names.
#  |              Default is False.
#  |          indent (Optional(int)): The JSON object will be pretty-printed with this indent level.
#  |              An indent level of 0 or negative will only insert newlines.
#  |              Pass None for the most compact representation without newlines.
#  |          float_precision (Optional(int)): If set, use this to specify float field valid digits.
#  |              Default is None.
#  |      Returns:
#  |          str: The json string representation of the protocol buffer.
#  |
#  |  wrap(pb) from proto.message.MessageMeta
#  |      Return a Message object that shallowly wraps the descriptor.
#  |
#  |      Args:
#  |          pb: A protocol buffer object, such as would be returned by
#  |              :meth:`pb`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from proto.message.MessageMeta:
#  |
#  |  __prepare__(name, bases, **kwargs) from builtins.type
#  |      __prepare__() -> dict
#  |      used to create the namespace for the class statement
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from proto.message.MessageMeta:
#  |
#  |  meta

# %%
gcs_destination_uri = "gs://pdf_extraction_iwm/output/pdf_test.json"
gcs_destination = vision.GcsDestination(uri=gcs_destination_uri)
output_config = vision.OutputConfig(
        gcs_destination=gcs_destination, batch_size=batch_size
    )

# %%
async_request = vision.AsyncAnnotateFileRequest(
        features=[feature], input_config=input_config, output_config=output_config
    )

operation = client.async_batch_annotate_files(requests=[async_request])

print("Waiting for the operation to finish.")
operation.result(timeout=420)
# Out:
# Waiting for the operation to finish.
# responses {
#   output_config {
#     gcs_destination {
#       uri: "gs://pdf_extraction_iwm/output/pdf_test.json"
#     }
#     batch_size: 2
#   }
# }

# %%
# Once the request has completed and the output has been
    # written to GCS, we can list all the output files.
storage_client = storage.Client(credentials=credentials)

match = re.match(r"gs://([^/]+)/(.+)", gcs_destination_uri)
bucket_name = match.group(1)
prefix = match.group(2)

bucket = storage_client.get_bucket(bucket_name)

# %%
# List objects with the given prefix, filtering out folders.
blob_list = [
    blob
    for blob in list(bucket.list_blobs(prefix=prefix))
    if not blob.name.endswith("/")
]
print("Output files:")
for blob in blob_list:
    print(blob.name)
# Out:
# Output files:
# output/pdf_test.jsonoutput-1-to-2.json

# %%
# Process the first output file from GCS.
# Since we specified batch_size=2, the first response contains
# the first two pages of the input file.
output = blob_list[0]

json_string = output.download_as_bytes().decode("utf-8")
response = json.loads(json_string)

# The actual response for the first page of the input file.
first_page_response = response["responses"][0]
annotation = first_page_response["fullTextAnnotation"]

# Here we print the full text from the first page.
# The response contains more information:
# annotation/pages/blocks/paragraphs/words/symbols
# including confidence scores and bounding boxes
print("Full text:\n")
print(annotation["text"])
# Out:
# Full text:
#
# THE PII PROBLEM:
# PRIVACY AND A NEW CONCEPT OF
# PERSONALLY IDENTIFIABLE
# INFORMATION
# PAUL M. SCHWARTZ† & DANIEL J. SOLOVE
# Personally identifiable information (PII) is one of the most central concepts in
# information privacy regulation. The scope of privacy laws typically turns on
# whether PII is involved. The basic assumption behind the applicable laws is that if
# PII is not involved, then there can be no privacy harm. At the same time, there is no
# uniform definition of PII in information privacy law. Moreover, computer science
# has shown that in many circumstances non-PII can be linked to individuals, and
# that de-identified data can be re-identified. PII and non-PII are thus not immutable
# categories, and there is a risk that information deemed non-PII at one time can be
# transformed into PII at a later juncture. Due to the malleable nature of what consti-
# tutes PII, some commentators have even suggested that PII be abandoned as the
# mechanism by which to define the boundaries of privacy law.
# In this Article, we argue that although the current approaches to PII are flawed, the
# concept of PII should not be abandoned. We develop a new approach called "PII
# 2.0," which accounts for PII's malleability. Based upon a standard rather than a
# rule, PII 2.0 utilizes a continuum of risk of identification. PII 2.0 regulates informa-
# tion that relates to either an "identified" or "identifiable" individual, and it estab-
# lishes different requirements for each category. To illustrate this theory, we use the
# example of regulating behavioral marketing to adults and children. We show how
# existing approaches to PII impede the effective regulation of behavioral marketing,
# and how PII 2.0 would resolve these problems.
# INTRODUCTION
# I. PII'S CENTRAL ROLE AND UNEASY STATUS
# A. The Rise of PII and Its Significance
# B. The Current Typology of PII ….
# 1. The Tautological Approach.
# 2. The Non-Public Approach
# 1815
# 1819
# 1819
# 1828
# 1829
# 1829
# † Professor, University of California, Berkeley, School of Law; Director, Berkeley
# Center for Law & Technology.
# John Marshall Harlan Research Professor of Law, George Washington University
# Law School. We wish to thank the National Policy and Legal Analysis Network to Prevent
# Childhood Obesity (NPLAN) for its support for this project. We also wish to thank Shawn
# Curtis, Melissa DeJesus, Leah Duranti, Yan Fang, Bill Friedman, Matthew Galati, and
# Brian St. John, who provided research assistance. Marty Abrams, Fred Cate, Jeff Chester,
# Chris Hoofnagle, Paul Ohm, Jules Polonetsky, Ira Rubinstein, Peter Swire, and partici-
# pants at the Fourth Annual Privacy Law Scholars Conference, Berkeley, California, pro-
# vided helpful suggestions on this paper. Copyright © 2011 by Paul M. Schwartz and Daniel
# J. Solove.
# 1814

# %%
type(response)
# Out:
# dict

# %%
response.keys()
# Out:
# dict_keys(['inputConfig', 'responses'])

# %%
type(response['responses'])
# Out:
# list

# %%
response['responses'][0].keys()
# Out:
# dict_keys(['fullTextAnnotation', 'context'])

# %%
response['responses'][1]['context']
# Out:
# {'uri': 'gs://pdf_extraction_iwm/input/pdf_test.pdf', 'pageNumber': 2}

# %%
response
# Out:
# {'inputConfig': {'gcsSource': {'uri': 'gs://pdf_extraction_iwm/input/pdf_test.pdf'},
#   'mimeType': 'application/pdf'},
#  'responses': [{'fullTextAnnotation': {'pages': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#          'confidence': 0.91798544},
#         {'languageCode': 'af', 'confidence': 0.032324255},
#         {'languageCode': 'sk', 'confidence': 0.016187862}]},
#       'width': 612,
#       'height': 792,
#       'blocks': [{'boundingBox': {'normalizedVertices': [{'x': 0.21895425,
#            'y': 0.060606062},
#           {'x': 0.78104573, 'y': 0.060606062},
#           {'x': 0.78104573, 'y': 0.12626262},
#           {'x': 0.21895425, 'y': 0.12626262}]},
#         'paragraphs': [{'boundingBox': {'normalizedVertices': [{'x': 0.3529412,
#              'y': 0.060606062},
#             {'x': 0.64705884, 'y': 0.060606062},
#             {'x': 0.64705884, 'y': 0.077020206},
#             {'x': 0.3529412, 'y': 0.077020206}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.3529412,
#                'y': 0.060606062},
#               {'x': 0.41666666, 'y': 0.060606062},
#               {'x': 0.41666666, 'y': 0.077020206},
#               {'x': 0.3529412, 'y': 0.077020206}]},
#             'symbols': [{'text': 'T', 'confidence': 0.9727104},
#              {'text': 'H', 'confidence': 0.979613},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'E',
#               'confidence': 0.9880796}],
#             'confidence': 0.9801343},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.42973855,
#                'y': 0.060606062},
#               {'x': 0.47058824, 'y': 0.060606062},
#               {'x': 0.47058824, 'y': 0.077020206},
#               {'x': 0.42973855, 'y': 0.077020206}]},
#             'symbols': [{'text': 'P', 'confidence': 0.94191253},
#              {'text': 'I', 'confidence': 0.9155906},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'I',
#               'confidence': 0.9205871}],
#             'confidence': 0.9260301},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.48202613,
#                'y': 0.060606062},
#               {'x': 0.6372549, 'y': 0.060606062},
#               {'x': 0.6372549, 'y': 0.077020206},
#               {'x': 0.48202613, 'y': 0.077020206}]},
#             'symbols': [{'text': 'P', 'confidence': 0.97897387},
#              {'text': 'R', 'confidence': 0.9742707},
#              {'text': 'O', 'confidence': 0.9543988},
#              {'text': 'B', 'confidence': 0.94759554},
#              {'text': 'L', 'confidence': 0.9678874},
#              {'text': 'E', 'confidence': 0.97931516},
#              {'text': 'M', 'confidence': 0.98082465}],
#             'confidence': 0.969038},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6388889,
#                'y': 0.060606062},
#               {'x': 0.64705884, 'y': 0.060606062},
#               {'x': 0.64705884, 'y': 0.077020206},
#               {'x': 0.6388889, 'y': 0.077020206}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': ':',
#               'confidence': 0.9566342}],
#             'confidence': 0.9566342}],
#           'confidence': 0.96131384},
#          {'boundingBox': {'normalizedVertices': [{'x': 0.21895425,
#              'y': 0.084595956},
#             {'x': 0.78104573, 'y': 0.084595956},
#             {'x': 0.78104573, 'y': 0.12626262},
#             {'x': 0.21895425, 'y': 0.12626262}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.21895425,
#                'y': 0.084595956},
#               {'x': 0.36437908, 'y': 0.084595956},
#               {'x': 0.36437908, 'y': 0.10227273},
#               {'x': 0.21895425, 'y': 0.10227273}]},
#             'symbols': [{'text': 'P', 'confidence': 0.97319984},
#              {'text': 'R', 'confidence': 0.9692829},
#              {'text': 'I', 'confidence': 0.97881365},
#              {'text': 'V', 'confidence': 0.9667661},
#              {'text': 'A', 'confidence': 0.9828176},
#              {'text': 'C', 'confidence': 0.9796109},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'Y',
#               'confidence': 0.98934966}],
#             'confidence': 0.9771201},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.375817,
#                'y': 0.084595956},
#               {'x': 0.44607842, 'y': 0.084595956},
#               {'x': 0.44607842, 'y': 0.10227273},
#               {'x': 0.375817, 'y': 0.10227273}]},
#             'symbols': [{'text': 'A', 'confidence': 0.9878358},
#              {'text': 'N', 'confidence': 0.994721},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'D',
#               'confidence': 0.9954133}],
#             'confidence': 0.9926567},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.4591503,
#                'y': 0.084595956},
#               {'x': 0.48202613, 'y': 0.084595956},
#               {'x': 0.48202613, 'y': 0.10227273},
#               {'x': 0.4591503, 'y': 0.10227273}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'A',
#               'confidence': 0.9955084}],
#             'confidence': 0.9955084},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.49183005,
#                'y': 0.084595956},
#               {'x': 0.5653595, 'y': 0.084595956},
#               {'x': 0.5653595, 'y': 0.10227273},
#               {'x': 0.49183005, 'y': 0.10227273}]},
#             'symbols': [{'text': 'N', 'confidence': 0.99415404},
#              {'text': 'E', 'confidence': 0.98855007},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'W',
#               'confidence': 0.98966813}],
#             'confidence': 0.9907907},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.57843137,
#                'y': 0.084595956},
#               {'x': 0.72712415, 'y': 0.084595956},
#               {'x': 0.72712415, 'y': 0.10227273},
#               {'x': 0.57843137, 'y': 0.10227273}]},
#             'symbols': [{'text': 'C', 'confidence': 0.9732923},
#              {'text': 'O', 'confidence': 0.9409219},
#              {'text': 'N', 'confidence': 0.9034359},
#              {'text': 'C', 'confidence': 0.8891643},
#              {'text': 'E', 'confidence': 0.9296328},
#              {'text': 'P', 'confidence': 0.95972216},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'T',
#               'confidence': 0.9817178}],
#             'confidence': 0.93969816},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.7385621,
#                'y': 0.084595956},
#               {'x': 0.78104573, 'y': 0.084595956},
#               {'x': 0.78104573, 'y': 0.10227273},
#               {'x': 0.7385621, 'y': 0.10227273}]},
#             'symbols': [{'text': 'O', 'confidence': 0.9727341},
#              {'property': {'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'text': 'F',
#               'confidence': 0.9737326}],
#             'confidence': 0.97323334},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.27287582,
#                'y': 0.109848484},
#               {'x': 0.49019608, 'y': 0.109848484},
#               {'x': 0.49019608, 'y': 0.12626262},
#               {'x': 0.27287582, 'y': 0.12626262}]},
#             'symbols': [{'text': 'P', 'confidence': 0.9795991},
#              {'text': 'E', 'confidence': 0.95692396},
#              {'text': 'R', 'confidence': 0.9107558},
#              {'text': 'S', 'confidence': 0.87068486},
#              {'text': 'O', 'confidence': 0.90097374},
#              {'text': 'N', 'confidence': 0.95625484},
#              {'text': 'A', 'confidence': 0.9840821},
#              {'text': 'L', 'confidence': 0.9971148},
#              {'text': 'L', 'confidence': 0.99408007},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'Y',
#               'confidence': 0.9940755}],
#             'confidence': 0.9544545},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.49673203,
#                'y': 0.109848484},
#               {'x': 0.7254902, 'y': 0.109848484},
#               {'x': 0.7254902, 'y': 0.12626262},
#               {'x': 0.49673203, 'y': 0.12626262}]},
#             'symbols': [{'text': 'I', 'confidence': 0.9747646},
#              {'text': 'D', 'confidence': 0.9544677},
#              {'text': 'E', 'confidence': 0.90500134},
#              {'text': 'N', 'confidence': 0.9614975},
#              {'text': 'T', 'confidence': 0.9710857},
#              {'text': 'I', 'confidence': 0.9885162},
#              {'text': 'F', 'confidence': 0.98537284},
#              {'text': 'I', 'confidence': 0.9791677},
#              {'text': 'A', 'confidence': 0.9568513},
#              {'text': 'B', 'confidence': 0.9391063},
#              {'text': 'L', 'confidence': 0.9563809},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': 'E',
#               'confidence': 0.96956295}],
#             'confidence': 0.9618146}],
#           'confidence': 0.9643637}],
#         'blockType': 'TEXT',
#         'confidence': 0.96364},
#        {'boundingBox': {'normalizedVertices': [{'x': 0.38398692,
#            'y': 0.135101},
#           {'x': 0.6143791, 'y': 0.135101},
#           {'x': 0.6143791, 'y': 0.15151516},
#           {'x': 0.38398692, 'y': 0.15151516}]},
#         'paragraphs': [{'boundingBox': {'normalizedVertices': [{'x': 0.38398692,
#              'y': 0.135101},
#             {'x': 0.6143791, 'y': 0.135101},
#             {'x': 0.6143791, 'y': 0.15151516},
#             {'x': 0.38398692, 'y': 0.15151516}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.38398692,
#                'y': 0.135101},
#               {'x': 0.6143791, 'y': 0.135101},
#               {'x': 0.6143791, 'y': 0.15151516},
#               {'x': 0.38398692, 'y': 0.15151516}]},
#             'symbols': [{'text': 'I', 'confidence': 0.9696567},
#              {'text': 'N', 'confidence': 0.9561833},
#              {'text': 'F', 'confidence': 0.930322},
#              {'text': 'O', 'confidence': 0.94657284},
#              {'text': 'R', 'confidence': 0.9426549},
#              {'text': 'M', 'confidence': 0.9658469},
#              {'text': 'A', 'confidence': 0.9859168},
#              {'text': 'T', 'confidence': 0.9914895},
#              {'text': 'I', 'confidence': 0.99403036},
#              {'text': 'O', 'confidence': 0.98864174},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': 'N',
#               'confidence': 0.9816281}],
#             'confidence': 0.96844935}],
#           'confidence': 0.96844935}],
#         'blockType': 'TEXT',
#         'confidence': 0.96844935},
#        {'boundingBox': {'normalizedVertices': [{'x': 0.19607843,
#            'y': 0.18055555},
#           {'x': 0.8039216, 'y': 0.18055555},
#           {'x': 0.8039216, 'y': 0.38762626},
#           {'x': 0.19607843, 'y': 0.38762626}]},
#         'paragraphs': [{'boundingBox': {'normalizedVertices': [{'x': 0.2777778,
#              'y': 0.18055555},
#             {'x': 0.7107843, 'y': 0.18055555},
#             {'x': 0.7107843, 'y': 0.19444445},
#             {'x': 0.2777778, 'y': 0.19444445}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'sk',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.2777778,
#                'y': 0.18055555},
#               {'x': 0.33169934, 'y': 0.18055555},
#               {'x': 0.33169934, 'y': 0.19444445},
#               {'x': 0.2777778, 'y': 0.19444445}]},
#             'symbols': [{'text': 'P', 'confidence': 0.8739951},
#              {'text': 'A', 'confidence': 0.9018773},
#              {'text': 'U', 'confidence': 0.96265346},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'L',
#               'confidence': 0.9872848}],
#             'confidence': 0.93145263},
#            {'property': {'detectedLanguages': [{'languageCode': 'sk',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.3382353,
#                'y': 0.18055555},
#               {'x': 0.36601308, 'y': 0.18055555},
#               {'x': 0.36601308, 'y': 0.19444445},
#               {'x': 0.3382353, 'y': 0.19444445}]},
#             'symbols': [{'text': 'M', 'confidence': 0.9881325},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': '.',
#               'confidence': 0.96792626}],
#             'confidence': 0.9780294},
#            {'property': {'detectedLanguages': [{'languageCode': 'sk',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.37254903,
#                'y': 0.18055555},
#               {'x': 0.48039216, 'y': 0.18055555},
#               {'x': 0.48039216, 'y': 0.19444445},
#               {'x': 0.37254903, 'y': 0.19444445}]},
#             'symbols': [{'text': 'S', 'confidence': 0.9823291},
#              {'text': 'C', 'confidence': 0.97504604},
#              {'text': 'H', 'confidence': 0.9825254},
#              {'text': 'W', 'confidence': 0.9843163},
#              {'text': 'A', 'confidence': 0.99175996},
#              {'text': 'R', 'confidence': 0.9834607},
#              {'text': 'T', 'confidence': 0.96535665},
#              {'text': 'Z', 'confidence': 0.88368726}],
#             'confidence': 0.96856016},
#            {'property': {'detectedLanguages': [{'languageCode': 'sk',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.48202613,
#                'y': 0.18055555},
#               {'x': 0.49019608, 'y': 0.18055555},
#               {'x': 0.49019608, 'y': 0.19444445},
#               {'x': 0.48202613, 'y': 0.19444445}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': '†',
#               'confidence': 0.35124418}],
#             'confidence': 0.35124418},
#            {'property': {'detectedLanguages': [{'languageCode': 'sk',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.501634,
#                'y': 0.18055555},
#               {'x': 0.5163399, 'y': 0.18055555},
#               {'x': 0.5163399, 'y': 0.19444445},
#               {'x': 0.501634, 'y': 0.19444445}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': '&',
#               'confidence': 0.9469817}],
#             'confidence': 0.9469817},
#            {'property': {'detectedLanguages': [{'languageCode': 'sk',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5261438,
#                'y': 0.18055555},
#               {'x': 0.60294116, 'y': 0.18055555},
#               {'x': 0.60294116, 'y': 0.19444445},
#               {'x': 0.5261438, 'y': 0.19444445}]},
#             'symbols': [{'text': 'D', 'confidence': 0.98898417},
#              {'text': 'A', 'confidence': 0.9832189},
#              {'text': 'N', 'confidence': 0.9617829},
#              {'text': 'I', 'confidence': 0.9243303},
#              {'text': 'E', 'confidence': 0.9144557},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'L',
#               'confidence': 0.95257497}],
#             'confidence': 0.95422447},
#            {'property': {'detectedLanguages': [{'languageCode': 'sk',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6094771,
#                'y': 0.18055555},
#               {'x': 0.624183, 'y': 0.18055555},
#               {'x': 0.624183, 'y': 0.19444445},
#               {'x': 0.6094771, 'y': 0.19444445}]},
#             'symbols': [{'text': 'J', 'confidence': 0.9797572},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': '.',
#               'confidence': 0.97579896}],
#             'confidence': 0.9777781},
#            {'property': {'detectedLanguages': [{'languageCode': 'sk',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.63398695,
#                'y': 0.18055555},
#               {'x': 0.7107843, 'y': 0.18055555},
#               {'x': 0.7107843, 'y': 0.19444445},
#               {'x': 0.63398695, 'y': 0.19444445}]},
#             'symbols': [{'text': 'S', 'confidence': 0.9695687},
#              {'text': 'O', 'confidence': 0.86589205},
#              {'text': 'L', 'confidence': 0.8842166},
#              {'text': 'O', 'confidence': 0.9169265},
#              {'text': 'V', 'confidence': 0.94084144},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': 'E',
#               'confidence': 0.9725044}],
#             'confidence': 0.9249916}],
#           'confidence': 0.93198097},
#          {'boundingBox': {'normalizedVertices': [{'x': 0.19607843,
#              'y': 0.21969697},
#             {'x': 0.8039216, 'y': 0.21969697},
#             {'x': 0.8039216, 'y': 0.38762626},
#             {'x': 0.19607843, 'y': 0.38762626}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.19771242,
#                'y': 0.21969697},
#               {'x': 0.2761438, 'y': 0.21969697},
#               {'x': 0.2761438, 'y': 0.23232323},
#               {'x': 0.19771242, 'y': 0.23232323}]},
#             'symbols': [{'text': 'P', 'confidence': 0.98924685},
#              {'text': 'e', 'confidence': 0.99058366},
#              {'text': 'r', 'confidence': 0.9937566},
#              {'text': 's', 'confidence': 0.99437433},
#              {'text': 'o', 'confidence': 0.99438506},
#              {'text': 'n', 'confidence': 0.99643195},
#              {'text': 'a', 'confidence': 0.9946682},
#              {'text': 'l', 'confidence': 0.9951471},
#              {'text': 'l', 'confidence': 0.98837066},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'y',
#               'confidence': 0.9882521}],
#             'confidence': 0.99252164},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.28267974,
#                'y': 0.21969697},
#               {'x': 0.36437908, 'y': 0.21969697},
#               {'x': 0.36437908, 'y': 0.23232323},
#               {'x': 0.28267974, 'y': 0.23232323}]},
#             'symbols': [{'text': 'i', 'confidence': 0.98919445},
#              {'text': 'd', 'confidence': 0.99547845},
#              {'text': 'e', 'confidence': 0.9945284},
#              {'text': 'n', 'confidence': 0.9957126},
#              {'text': 't', 'confidence': 0.9964284},
#              {'text': 'i', 'confidence': 0.99670553},
#              {'text': 'f', 'confidence': 0.9957043},
#              {'text': 'i', 'confidence': 0.99601096},
#              {'text': 'a', 'confidence': 0.99436224},
#              {'text': 'b', 'confidence': 0.9923413},
#              {'text': 'l', 'confidence': 0.99524885},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.99563026}],
#             'confidence': 0.9947788},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.37254903,
#                'y': 0.21969697},
#               {'x': 0.45751634, 'y': 0.21969697},
#               {'x': 0.45751634, 'y': 0.23232323},
#               {'x': 0.37254903, 'y': 0.23232323}]},
#             'symbols': [{'text': 'i', 'confidence': 0.98959786},
#              {'text': 'n', 'confidence': 0.99288285},
#              {'text': 'f', 'confidence': 0.99113643},
#              {'text': 'o', 'confidence': 0.9937842},
#              {'text': 'r', 'confidence': 0.9946649},
#              {'text': 'm', 'confidence': 0.9959927},
#              {'text': 'a', 'confidence': 0.99374235},
#              {'text': 't', 'confidence': 0.99207854},
#              {'text': 'i', 'confidence': 0.9941225},
#              {'text': 'o', 'confidence': 0.9869587},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'n',
#               'confidence': 0.9874313}],
#             'confidence': 0.9920357},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.46732026,
#                'y': 0.21969697},
#               {'x': 0.4738562, 'y': 0.21969697},
#               {'x': 0.4738562, 'y': 0.23232323},
#               {'x': 0.46732026, 'y': 0.23232323}]},
#             'symbols': [{'text': '(', 'confidence': 0.94306874}],
#             'confidence': 0.94306874},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.4738562,
#                'y': 0.21969697},
#               {'x': 0.5, 'y': 0.21969697},
#               {'x': 0.5, 'y': 0.23232323},
#               {'x': 0.4738562, 'y': 0.23232323}]},
#             'symbols': [{'text': 'P', 'confidence': 0.9626893},
#              {'text': 'I', 'confidence': 0.9335684},
#              {'text': 'I', 'confidence': 0.890682}],
#             'confidence': 0.9289799},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.49673203,
#                'y': 0.21969697},
#               {'x': 0.503268, 'y': 0.21969697},
#               {'x': 0.503268, 'y': 0.23232323},
#               {'x': 0.49673203, 'y': 0.23232323}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': ')',
#               'confidence': 0.9628335}],
#             'confidence': 0.9628335},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5130719,
#                'y': 0.21969697},
#               {'x': 0.52287585, 'y': 0.21969697},
#               {'x': 0.52287585, 'y': 0.23232323},
#               {'x': 0.5130719, 'y': 0.23232323}]},
#             'symbols': [{'text': 'i', 'confidence': 0.9896141},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 's',
#               'confidence': 0.99235445}],
#             'confidence': 0.9909843},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.53104573,
#                'y': 0.21969697},
#               {'x': 0.5571895, 'y': 0.21969697},
#               {'x': 0.5571895, 'y': 0.23232323},
#               {'x': 0.53104573, 'y': 0.23232323}]},
#             'symbols': [{'text': 'o', 'confidence': 0.98822814},
#              {'text': 'n', 'confidence': 0.9931291},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.9955683}],
#             'confidence': 0.9923085},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5653595,
#                'y': 0.21969697},
#               {'x': 0.5833333, 'y': 0.21969697},
#               {'x': 0.5833333, 'y': 0.23232323},
#               {'x': 0.5653595, 'y': 0.23232323}]},
#             'symbols': [{'text': 'o', 'confidence': 0.9937448},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'f',
#               'confidence': 0.99339986}],
#             'confidence': 0.99357235},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5882353,
#                'y': 0.21969697},
#               {'x': 0.6094771, 'y': 0.21969697},
#               {'x': 0.6094771, 'y': 0.23232323},
#               {'x': 0.5882353, 'y': 0.23232323}]},
#             'symbols': [{'text': 't', 'confidence': 0.9774767},
#              {'text': 'h', 'confidence': 0.99433833},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.9959154}],
#             'confidence': 0.9892435},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.61764705,
#                'y': 0.21969697},
#               {'x': 0.6535948, 'y': 0.21969697},
#               {'x': 0.6535948, 'y': 0.23232323},
#               {'x': 0.61764705, 'y': 0.23232323}]},
#             'symbols': [{'text': 'm', 'confidence': 0.9901578},
#              {'text': 'o', 'confidence': 0.99004567},
#              {'text': 's', 'confidence': 0.98753506},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 't',
#               'confidence': 0.99102426}],
#             'confidence': 0.98969066},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.66013074,
#                'y': 0.21969697},
#               {'x': 0.7107843, 'y': 0.21969697},
#               {'x': 0.7107843, 'y': 0.23232323},
#               {'x': 0.66013074, 'y': 0.23232323}]},
#             'symbols': [{'text': 'c', 'confidence': 0.99060225},
#              {'text': 'e', 'confidence': 0.99392045},
#              {'text': 'n', 'confidence': 0.9934618},
#              {'text': 't', 'confidence': 0.99574697},
#              {'text': 'r', 'confidence': 0.9962436},
#              {'text': 'a', 'confidence': 0.99513036},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'l',
#               'confidence': 0.99102974}],
#             'confidence': 0.9937336},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.71732026,
#                'y': 0.21969697},
#               {'x': 0.7794118, 'y': 0.21969697},
#               {'x': 0.7794118, 'y': 0.23232323},
#               {'x': 0.71732026, 'y': 0.23232323}]},
#             'symbols': [{'text': 'c', 'confidence': 0.9676096},
#              {'text': 'o', 'confidence': 0.98699564},
#              {'text': 'n', 'confidence': 0.99223375},
#              {'text': 'c', 'confidence': 0.99491525},
#              {'text': 'e', 'confidence': 0.99553734},
#              {'text': 'p', 'confidence': 0.99542505},
#              {'text': 't', 'confidence': 0.9928602},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 's',
#               'confidence': 0.9901661}],
#             'confidence': 0.98946786},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.7875817,
#                'y': 0.21969697},
#               {'x': 0.8022876, 'y': 0.21969697},
#               {'x': 0.8022876, 'y': 0.23232323},
#               {'x': 0.7875817, 'y': 0.23232323}]},
#             'symbols': [{'text': 'i', 'confidence': 0.99347293},
#              {'property': {'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'text': 'n',
#               'confidence': 0.99199426}],
#             'confidence': 0.9927336},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.19771242,
#                'y': 0.23484848},
#               {'x': 0.28431374, 'y': 0.23484848},
#               {'x': 0.28431374, 'y': 0.24873738},
#               {'x': 0.19771242, 'y': 0.24873738}]},
#             'symbols': [{'text': 'i', 'confidence': 0.9918395},
#              {'text': 'n', 'confidence': 0.9928972},
#              {'text': 'f', 'confidence': 0.9924213},
#              {'text': 'o', 'confidence': 0.9921458},
#              {'text': 'r', 'confidence': 0.9923184},
#              {'text': 'm', 'confidence': 0.99157876},
#              {'text': 'a', 'confidence': 0.9901218},
#              {'text': 't', 'confidence': 0.9891414},
#              {'text': 'i', 'confidence': 0.9940263},
#              {'text': 'o', 'confidence': 0.99115044},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'n',
#               'confidence': 0.99338365}],
#             'confidence': 0.99191135},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.29248366,
#                'y': 0.23484848},
#               {'x': 0.3480392, 'y': 0.23484848},
#               {'x': 0.3480392, 'y': 0.24873738},
#               {'x': 0.29248366, 'y': 0.24873738}]},
#             'symbols': [{'text': 'p', 'confidence': 0.9909839},
#              {'text': 'r', 'confidence': 0.99378324},
#              {'text': 'i', 'confidence': 0.9953845},
#              {'text': 'v', 'confidence': 0.9954526},
#              {'text': 'a', 'confidence': 0.99450594},
#              {'text': 'c', 'confidence': 0.9907596},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'y',
#               'confidence': 0.99372005}],
#             'confidence': 0.9935128},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.35947713,
#                'y': 0.23484848},
#               {'x': 0.43137255, 'y': 0.23484848},
#               {'x': 0.43137255, 'y': 0.24873738},
#               {'x': 0.35947713, 'y': 0.24873738}]},
#             'symbols': [{'text': 'r', 'confidence': 0.9954159},
#              {'text': 'e', 'confidence': 0.99799687},
#              {'text': 'g', 'confidence': 0.98402035},
#              {'text': 'u', 'confidence': 0.98138124},
#              {'text': 'l', 'confidence': 0.9736071},
#              {'text': 'a', 'confidence': 0.9851873},
#              {'text': 't', 'confidence': 0.9930235},
#              {'text': 'i', 'confidence': 0.9933594},
#              {'text': 'o', 'confidence': 0.9918982},
#              {'text': 'n', 'confidence': 0.9908204}],
#             'confidence': 0.988671},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.43137255,
#                'y': 0.23484848},
#               {'x': 0.43464053, 'y': 0.23484848},
#               {'x': 0.43464053, 'y': 0.24873738},
#               {'x': 0.43137255, 'y': 0.24873738}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': '.',
#               'confidence': 0.98520505}],
#             'confidence': 0.98520505},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.44607842,
#                'y': 0.23484848},
#               {'x': 0.4738562, 'y': 0.23484848},
#               {'x': 0.4738562, 'y': 0.24873738},
#               {'x': 0.44607842, 'y': 0.24873738}]},
#             'symbols': [{'text': 'T', 'confidence': 0.9887127},
#              {'text': 'h', 'confidence': 0.99716794},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.9979469}],
#             'confidence': 0.9946092},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.48366013,
#                'y': 0.23484848},
#               {'x': 0.5245098, 'y': 0.23484848},
#               {'x': 0.5245098, 'y': 0.24873738},
#               {'x': 0.48366013, 'y': 0.24873738}]},
#             'symbols': [{'text': 's', 'confidence': 0.99280226},
#              {'text': 'c', 'confidence': 0.9942232},
#              {'text': 'o', 'confidence': 0.99349684},
#              {'text': 'p', 'confidence': 0.9946338},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.99579567}],
#             'confidence': 0.99419034},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.53431374,
#                'y': 0.23484848},
#               {'x': 0.5522876, 'y': 0.23484848},
#               {'x': 0.5522876, 'y': 0.24873738},
#               {'x': 0.53431374, 'y': 0.24873738}]},
#             'symbols': [{'text': 'o', 'confidence': 0.9895801},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'f',
#               'confidence': 0.9899403}],
#             'confidence': 0.98976016},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5571895,
#                'y': 0.23484848},
#               {'x': 0.6127451, 'y': 0.23484848},
#               {'x': 0.6127451, 'y': 0.24873738},
#               {'x': 0.5571895, 'y': 0.24873738}]},
#             'symbols': [{'text': 'p', 'confidence': 0.9937872},
#              {'text': 'r', 'confidence': 0.99626446},
#              {'text': 'i', 'confidence': 0.99623555},
#              {'text': 'v', 'confidence': 0.996132},
#              {'text': 'a', 'confidence': 0.9960003},
#              {'text': 'c', 'confidence': 0.99533504},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'y',
#               'confidence': 0.9943485}],
#             'confidence': 0.9954433},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.622549,
#                'y': 0.23484848},
#               {'x': 0.65522873, 'y': 0.23484848},
#               {'x': 0.65522873, 'y': 0.24873738},
#               {'x': 0.622549, 'y': 0.24873738}]},
#             'symbols': [{'text': 'l', 'confidence': 0.9880446},
#              {'text': 'a', 'confidence': 0.9926204},
#              {'text': 'w', 'confidence': 0.9898486},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 's',
#               'confidence': 0.99318206}],
#             'confidence': 0.99092394},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6650327,
#                'y': 0.23484848},
#               {'x': 0.7254902, 'y': 0.23484848},
#               {'x': 0.7254902, 'y': 0.24873738},
#               {'x': 0.6650327, 'y': 0.24873738}]},
#             'symbols': [{'text': 't', 'confidence': 0.9847738},
#              {'text': 'y', 'confidence': 0.9929505},
#              {'text': 'p', 'confidence': 0.98957306},
#              {'text': 'i', 'confidence': 0.9944648},
#              {'text': 'c', 'confidence': 0.9961247},
#              {'text': 'a', 'confidence': 0.99558127},
#              {'text': 'l', 'confidence': 0.99643266},
#              {'text': 'l', 'confidence': 0.99549824},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'y',
#               'confidence': 0.9931625}],
#             'confidence': 0.9931735},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.7369281,
#                'y': 0.23484848},
#               {'x': 0.77287585, 'y': 0.23484848},
#               {'x': 0.77287585, 'y': 0.24873738},
#               {'x': 0.7369281, 'y': 0.24873738}]},
#             'symbols': [{'text': 't', 'confidence': 0.9942855},
#              {'text': 'u', 'confidence': 0.9954644},
#              {'text': 'r', 'confidence': 0.99435496},
#              {'text': 'n', 'confidence': 0.9953594},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 's',
#               'confidence': 0.9954168}],
#             'confidence': 0.9949762},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.78267974,
#                'y': 0.23484848},
#               {'x': 0.8022876, 'y': 0.23484848},
#               {'x': 0.8022876, 'y': 0.24873738},
#               {'x': 0.78267974, 'y': 0.24873738}]},
#             'symbols': [{'text': 'o', 'confidence': 0.99358094},
#              {'property': {'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'text': 'n',
#               'confidence': 0.99364084}],
#             'confidence': 0.99361086},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.19607843,
#                'y': 0.25126263},
#               {'x': 0.25653595, 'y': 0.25126263},
#               {'x': 0.25653595, 'y': 0.2638889},
#               {'x': 0.19607843, 'y': 0.2638889}]},
#             'symbols': [{'text': 'w', 'confidence': 0.97191477},
#              {'text': 'h', 'confidence': 0.9912765},
#              {'text': 'e', 'confidence': 0.99621826},
#              {'text': 't', 'confidence': 0.99507296},
#              {'text': 'h', 'confidence': 0.9940765},
#              {'text': 'e', 'confidence': 0.99313635},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'r',
#               'confidence': 0.99303466}],
#             'confidence': 0.9906757},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.25980392,
#                'y': 0.25126263},
#               {'x': 0.2859477, 'y': 0.25126263},
#               {'x': 0.2859477, 'y': 0.2638889},
#               {'x': 0.25980392, 'y': 0.2638889}]},
#             'symbols': [{'text': 'P', 'confidence': 0.9752},
#              {'text': 'I', 'confidence': 0.98148525},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'I',
#               'confidence': 0.9482505}],
#             'confidence': 0.9683119},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.28921568,
#                'y': 0.25126263},
#               {'x': 0.30228758, 'y': 0.25126263},
#               {'x': 0.30228758, 'y': 0.2638889},
#               {'x': 0.28921568, 'y': 0.2638889}]},
#             'symbols': [{'text': 'i', 'confidence': 0.9904722},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 's',
#               'confidence': 0.9937286}],
#             'confidence': 0.99210036},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.30555555,
#                'y': 0.25126263},
#               {'x': 0.36928105, 'y': 0.25126263},
#               {'x': 0.36928105, 'y': 0.2638889},
#               {'x': 0.30555555, 'y': 0.2638889}]},
#             'symbols': [{'text': 'i', 'confidence': 0.99498135},
#              {'text': 'n', 'confidence': 0.99601674},
#              {'text': 'v', 'confidence': 0.9939025},
#              {'text': 'o', 'confidence': 0.99541295},
#              {'text': 'l', 'confidence': 0.99251264},
#              {'text': 'v', 'confidence': 0.98985887},
#              {'text': 'e', 'confidence': 0.9867443},
#              {'text': 'd', 'confidence': 0.9865247}],
#             'confidence': 0.99199426},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.36928105,
#                'y': 0.25126263},
#               {'x': 0.37254903, 'y': 0.25126263},
#               {'x': 0.37254903, 'y': 0.2638889},
#               {'x': 0.36928105, 'y': 0.2638889}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': '.',
#               'confidence': 0.9798735}],
#             'confidence': 0.9798735},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.37908497,
#                'y': 0.25126263},
#               {'x': 0.40686274, 'y': 0.25126263},
#               {'x': 0.40686274, 'y': 0.2638889},
#               {'x': 0.37908497, 'y': 0.2638889}]},
#             'symbols': [{'text': 'T', 'confidence': 0.9853962},
#              {'text': 'h', 'confidence': 0.9926964},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.98814267}],
#             'confidence': 0.9887451},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.4117647,
#                'y': 0.25126263},
#               {'x': 0.44771242, 'y': 0.25126263},
#               {'x': 0.44771242, 'y': 0.2638889},
#               {'x': 0.4117647, 'y': 0.2638889}]},
#             'symbols': [{'text': 'b', 'confidence': 0.9930912},
#              {'text': 'a', 'confidence': 0.99526304},
#              {'text': 's', 'confidence': 0.99406356},
#              {'text': 'i', 'confidence': 0.99526185},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'c',
#               'confidence': 0.99271405}],
#             'confidence': 0.99407876},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.45424837,
#                'y': 0.25126263},
#               {'x': 0.53594774, 'y': 0.25126263},
#               {'x': 0.53594774, 'y': 0.2638889},
#               {'x': 0.45424837, 'y': 0.2638889}]},
#             'symbols': [{'text': 'a', 'confidence': 0.9941677},
#              {'text': 's', 'confidence': 0.9867073},
#              {'text': 's', 'confidence': 0.9684494},
#              {'text': 'u', 'confidence': 0.9310256},
#              {'text': 'm', 'confidence': 0.9444666},
#              {'text': 'p', 'confidence': 0.976742},
#              {'text': 't', 'confidence': 0.987653},
#              {'text': 'i', 'confidence': 0.9958929},
#              {'text': 'o', 'confidence': 0.99302995},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'n',
#               'confidence': 0.9889209}],
#             'confidence': 0.97670555},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5424837,
#                'y': 0.25126263},
#               {'x': 0.59313726, 'y': 0.25126263},
#               {'x': 0.59313726, 'y': 0.2638889},
#               {'x': 0.5424837, 'y': 0.2638889}]},
#             'symbols': [{'text': 'b', 'confidence': 0.9903755},
#              {'text': 'e', 'confidence': 0.99540204},
#              {'text': 'h', 'confidence': 0.9947726},
#              {'text': 'i', 'confidence': 0.99618083},
#              {'text': 'n', 'confidence': 0.99468553},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'd',
#               'confidence': 0.9913671}],
#             'confidence': 0.9937973},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5980392,
#                'y': 0.25126263},
#               {'x': 0.61928105, 'y': 0.25126263},
#               {'x': 0.61928105, 'y': 0.2638889},
#               {'x': 0.5980392, 'y': 0.2638889}]},
#             'symbols': [{'text': 't', 'confidence': 0.99119693},
#              {'text': 'h', 'confidence': 0.9928316},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.9930896}],
#             'confidence': 0.9923727},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.624183,
#                'y': 0.25126263},
#               {'x': 0.6993464, 'y': 0.25126263},
#               {'x': 0.6993464, 'y': 0.2638889},
#               {'x': 0.624183, 'y': 0.2638889}]},
#             'symbols': [{'text': 'a', 'confidence': 0.992862},
#              {'text': 'p', 'confidence': 0.973837},
#              {'text': 'p', 'confidence': 0.96904397},
#              {'text': 'l', 'confidence': 0.96943206},
#              {'text': 'i', 'confidence': 0.98809046},
#              {'text': 'c', 'confidence': 0.99362665},
#              {'text': 'a', 'confidence': 0.9954756},
#              {'text': 'b', 'confidence': 0.9905704},
#              {'text': 'l', 'confidence': 0.9885267},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.9834491}],
#             'confidence': 0.9844914},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.7058824,
#                'y': 0.25126263},
#               {'x': 0.7369281, 'y': 0.25126263},
#               {'x': 0.7369281, 'y': 0.2638889},
#               {'x': 0.7058824, 'y': 0.2638889}]},
#             'symbols': [{'text': 'l', 'confidence': 0.9894985},
#              {'text': 'a', 'confidence': 0.992834},
#              {'text': 'w', 'confidence': 0.99207515},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 's',
#               'confidence': 0.9915452}],
#             'confidence': 0.9914882},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.74183005,
#                'y': 0.25126263},
#               {'x': 0.753268, 'y': 0.25126263},
#               {'x': 0.753268, 'y': 0.2638889},
#               {'x': 0.74183005, 'y': 0.2638889}]},
#             'symbols': [{'text': 'i', 'confidence': 0.99523515},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 's',
#               'confidence': 0.9956053}],
#             'confidence': 0.9954202},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.75816995,
#                'y': 0.25126263},
#               {'x': 0.7875817, 'y': 0.25126263},
#               {'x': 0.7875817, 'y': 0.2638889},
#               {'x': 0.75816995, 'y': 0.2638889}]},
#             'symbols': [{'text': 't', 'confidence': 0.99534005},
#              {'text': 'h', 'confidence': 0.9966574},
#              {'text': 'a', 'confidence': 0.99571747},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 't',
# ...
#              {'text': 's', 'confidence': 0.99265575},
#              {'text': '.', 'confidence': 0.9883053},
#              {'text': 'a', 'confidence': 0.9926202},
#              {'text': 's', 'confidence': 0.9925247},
#              {'text': 'p', 'confidence': 0.9849241},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'x',
#               'confidence': 0.9620637}],
#             'confidence': 0.9868571},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.58006537,
#                'y': 0.89141417},
#               {'x': 0.5849673, 'y': 0.89141417},
#               {'x': 0.5849673, 'y': 0.905303},
#               {'x': 0.58006537, 'y': 0.905303}]},
#             'symbols': [{'text': '(', 'confidence': 0.99351007}],
#             'confidence': 0.99351007},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5849673,
#                'y': 0.89141417},
#               {'x': 0.65849674, 'y': 0.89141417},
#               {'x': 0.65849674, 'y': 0.905303},
#               {'x': 0.5849673, 'y': 0.905303}]},
#             'symbols': [{'text': 'i', 'confidence': 0.99743277},
#              {'text': 'n', 'confidence': 0.9948341},
#              {'text': 'd', 'confidence': 0.9873665},
#              {'text': 'i', 'confidence': 0.9866192},
#              {'text': 'c', 'confidence': 0.98539466},
#              {'text': 'a', 'confidence': 0.99413824},
#              {'text': 't', 'confidence': 0.99160767},
#              {'text': 'i', 'confidence': 0.99334574},
#              {'text': 'n', 'confidence': 0.9929849},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'g',
#               'confidence': 0.9925183}],
#             'confidence': 0.99162424},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6633987,
#                'y': 0.89141417},
#               {'x': 0.6928105, 'y': 0.89141417},
#               {'x': 0.6928105, 'y': 0.905303},
#               {'x': 0.6633987, 'y': 0.905303}]},
#             'symbols': [{'text': 't', 'confidence': 0.9737757},
#              {'text': 'h', 'confidence': 0.9932743},
#              {'text': 'a', 'confidence': 0.991031},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 't',
#               'confidence': 0.99210584}],
#             'confidence': 0.9875467},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6977124,
#                'y': 0.89141417},
#               {'x': 0.75816995, 'y': 0.89141417},
#               {'x': 0.75816995, 'y': 0.905303},
#               {'x': 0.6977124, 'y': 0.905303}]},
#             'symbols': [{'text': 'I', 'confidence': 0.98888934},
#              {'text': 'n', 'confidence': 0.99226725},
#              {'text': 't', 'confidence': 0.9912174},
#              {'text': 'e', 'confidence': 0.9948595},
#              {'text': 'r', 'confidence': 0.9954621},
#              {'text': 'n', 'confidence': 0.9963755},
#              {'text': 'e', 'confidence': 0.99449754},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 't',
#               'confidence': 0.9890132}],
#             'confidence': 0.9928227},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.7630719,
#                'y': 0.89141417},
#               {'x': 0.8006536, 'y': 0.89141417},
#               {'x': 0.8006536, 'y': 0.905303},
#               {'x': 0.7630719, 'y': 0.905303}]},
#             'symbols': [{'text': 'u', 'confidence': 0.9922832},
#              {'text': 's', 'confidence': 0.9947882},
#              {'text': 'e', 'confidence': 0.99582595},
#              {'text': 'r', 'confidence': 0.9966385},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 's',
#               'confidence': 0.9928817}],
#             'confidence': 0.99448353},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.8039216,
#                'y': 0.89141417},
#               {'x': 0.83006537, 'y': 0.89141417},
#               {'x': 0.83006537, 'y': 0.905303},
#               {'x': 0.8039216, 'y': 0.905303}]},
#             'symbols': [{'text': 's', 'confidence': 0.98428375},
#              {'text': 'u', 'confidence': 0.9831219},
#              {'property': {'detectedBreak': {'type': 'HYPHEN'}},
#               'text': 'p',
#               'confidence': 0.97065014}],
#             'confidence': 0.97935194},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.1633987,
#                'y': 0.9078283},
#               {'x': 0.19444445, 'y': 0.9078283},
#               {'x': 0.19444445, 'y': 0.92045456},
#               {'x': 0.1633987, 'y': 0.92045456}]},
#             'symbols': [{'text': 'p', 'confidence': 0.98333466},
#              {'text': 'o', 'confidence': 0.9906572},
#              {'text': 'r', 'confidence': 0.9933904},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 't',
#               'confidence': 0.99086267}],
#             'confidence': 0.9895612},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.2009804,
#                'y': 0.9078283},
#               {'x': 0.25816995, 'y': 0.9078283},
#               {'x': 0.25816995, 'y': 0.92045456},
#               {'x': 0.2009804, 'y': 0.92045456}]},
#             'symbols': [{'text': 'l', 'confidence': 0.98946255},
#              {'text': 'i', 'confidence': 0.9952768},
#              {'text': 'm', 'confidence': 0.9952612},
#              {'text': 'i', 'confidence': 0.9959009},
#              {'text': 't', 'confidence': 0.99459},
#              {'text': 'i', 'confidence': 0.99521303},
#              {'text': 'n', 'confidence': 0.99366826},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'g',
#               'confidence': 0.99489594}],
#             'confidence': 0.99428356},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.2630719,
#                'y': 0.9078283},
#               {'x': 0.32352942, 'y': 0.9078283},
#               {'x': 0.32352942, 'y': 0.92045456},
#               {'x': 0.2630719, 'y': 0.92045456}]},
#             'symbols': [{'text': 't', 'confidence': 0.99496025},
#              {'text': 'r', 'confidence': 0.99365675},
#              {'text': 'a', 'confidence': 0.99510837},
#              {'text': 'c', 'confidence': 0.9904778},
#              {'text': 'k', 'confidence': 0.9926951},
#              {'text': 'i', 'confidence': 0.99098253},
#              {'text': 'n', 'confidence': 0.98988533},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'g',
#               'confidence': 0.9898932}],
#             'confidence': 0.9922074},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.33006537,
#                'y': 0.9078283},
#               {'x': 0.39869282, 'y': 0.9078283},
#               {'x': 0.39869282, 'y': 0.92045456},
#               {'x': 0.33006537, 'y': 0.92045456}]},
#             'symbols': [{'text': 'm', 'confidence': 0.993588},
#              {'text': 'e', 'confidence': 0.99639463},
#              {'text': 'a', 'confidence': 0.99405915},
#              {'text': 's', 'confidence': 0.99015284},
#              {'text': 'u', 'confidence': 0.98414916},
#              {'text': 'r', 'confidence': 0.9864484},
#              {'text': 'e', 'confidence': 0.9954305},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 's',
#               'confidence': 0.99469584}],
#             'confidence': 0.9918648},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.40522876,
#                'y': 0.9078283},
#               {'x': 0.43300653, 'y': 0.9078283},
#               {'x': 0.43300653, 'y': 0.92045456},
#               {'x': 0.40522876, 'y': 0.92045456}]},
#             'symbols': [{'text': 't', 'confidence': 0.9909937},
#              {'text': 'h', 'confidence': 0.9970279},
#              {'text': 'a', 'confidence': 0.99538046},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 't',
#               'confidence': 0.99563396}],
#             'confidence': 0.99475896},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.43954247,
#                'y': 0.9078283},
#               {'x': 0.47058824, 'y': 0.9078283},
#               {'x': 0.47058824, 'y': 0.92045456},
#               {'x': 0.43954247, 'y': 0.92045456}]},
#             'symbols': [{'text': 'm', 'confidence': 0.99521},
#              {'text': 'a', 'confidence': 0.9956113},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'y',
#               'confidence': 0.99261695}],
#             'confidence': 0.9944794},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.47712418,
#                'y': 0.9078283},
#               {'x': 0.53594774, 'y': 0.9078283},
#               {'x': 0.53594774, 'y': 0.92045456},
#               {'x': 0.47712418, 'y': 0.92045456}]},
#             'symbols': [{'text': 'i', 'confidence': 0.9912592},
#              {'text': 'm', 'confidence': 0.9911137},
#              {'text': 'p', 'confidence': 0.97626776},
#              {'text': 'i', 'confidence': 0.9762976},
#              {'text': 'n', 'confidence': 0.991963},
#              {'text': 'g', 'confidence': 0.9947306},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.9949258}],
#             'confidence': 0.98807967},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5424837,
#                'y': 0.9078283},
#               {'x': 0.5604575, 'y': 0.9078283},
#               {'x': 0.5604575, 'y': 0.92045456},
#               {'x': 0.5424837, 'y': 0.92045456}]},
#             'symbols': [{'text': 'o', 'confidence': 0.9937823},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'n',
#               'confidence': 0.9943893}],
#             'confidence': 0.9940858},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5669935,
#                'y': 0.9078283},
#               {'x': 0.60294116, 'y': 0.9078283},
#               {'x': 0.60294116, 'y': 0.92045456},
#               {'x': 0.5669935, 'y': 0.92045456}]},
#             'symbols': [{'text': 't', 'confidence': 0.9907057},
#              {'text': 'h', 'confidence': 0.9942791},
#              {'text': 'e', 'confidence': 0.9960438},
#              {'text': 'i', 'confidence': 0.99197906},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'r',
#               'confidence': 0.9930351}],
#             'confidence': 0.9932085},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.60784316,
#                'y': 0.9078283},
#               {'x': 0.6617647, 'y': 0.9078283},
#               {'x': 0.6617647, 'y': 0.92045456},
#               {'x': 0.60784316, 'y': 0.92045456}]},
#             'symbols': [{'text': 'p', 'confidence': 0.9932517},
#              {'text': 'r', 'confidence': 0.9964977},
#              {'text': 'i', 'confidence': 0.99631494},
#              {'text': 'v', 'confidence': 0.9955185},
#              {'text': 'a', 'confidence': 0.99533945},
#              {'text': 'c', 'confidence': 0.9943472},
#              {'text': 'y', 'confidence': 0.9913563}],
#             'confidence': 0.99466085},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6617647,
#                'y': 0.9078283},
#               {'x': 0.6683006, 'y': 0.9078283},
#               {'x': 0.6683006, 'y': 0.92045456},
#               {'x': 0.6617647, 'y': 0.92045456}]},
#             'symbols': [{'text': ')', 'confidence': 0.9897342}],
#             'confidence': 0.9897342},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6683006,
#                'y': 0.9078283},
#               {'x': 0.67156863, 'y': 0.9078283},
#               {'x': 0.67156863, 'y': 0.92045456},
#               {'x': 0.6683006, 'y': 0.92045456}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': '.',
#               'confidence': 0.97457373}],
#             'confidence': 0.97457373}],
#           'confidence': 0.9869129}],
#         'blockType': 'TEXT',
#         'confidence': 0.9868949}],
#       'confidence': 0.9793541}],
#     'text': 'December 2011]\nTHE PII PROBLEM\n3. The Specific-Types Approach\n1831\nII. THE PROBLEMS WITH PII …\n1836\nA. The Anonymity Myth and the IP Address.\n1836\nB. The Re-Identification of Data: Goodbye Non-PII? .. 1841\nC. The Problem of Changing Technology and\nInformation-Sharing Practices..\nD. The Ability To Identify Depends on Context.\nIII. BEHAVIORAL MARKETING AND THE SURPRISING\nIRRELEVANCE OF PII\nA. From Mass Marketing to Behavioral Marketing\n1. Modern One-to-One Marketing\n2. Marketing, Legal Enforcement, and the Question\nof Adults\' PII…..\nB. Food Marketing to Youth\n1. Digital Marketing and the "Net Generation".\n2.\nMarketing, Legal Enforcement, and the Question\nof Children\'s PII…\nC. Reductionism, Expansionism, and PII 2.0\n1. Reductionism in the United States\n2. Expansionism in the European Union\n3. The Benefits of PII 2.0.....\nD. PII 2.0 and Fair Information Practices (FIPs)\nE. Possible Objections\nF. Applying the New Concept\n1815\n1862\nIV. PII 2.0\n1865\nA. Should Privacy Law Abandon the Concept of PII? . 1865\nB. A Standard for PII\n1870\n1872\n1873\n1873\n1877\n1879\n1. Behavioral Marketing to Adults\n2. Food Marketing to Youth\nCONCLUSION\nAPPENDIX.\n1845\n1847\n1848\n1849\n1850\n1854\n1859\n1860\n1883\n1886\n1887\n1891\n1893\n1894\nINTRODUCTION\nInformation privacy law has reached a turning point. The current\ndebate about the topic is vigorous, and polling data reveal that Ameri-\ncans are extremely concerned about privacy, both on and off the\nInternet.¹ Moreover, the Executive Branch, independent agencies,\n1 See Online Privacy: What Does It Mean to Parents and Kids?, COMMONSENSE MEDIA\n(2010), http://www.commonsensemedia.org/sites/default/files/privacypoll.pdf (detailing\nconcerns of adults and youth regarding online privacy); U.S. Internet Users Ready To Limit\nOnline Tracking for Ads, GALLUP (Dec. 21, 2010), http://www.gallup.com/poll/145337/\nInternet-Users-Ready-Limit-Online-Tracking-Ads.aspx (indicating that Internet users sup-\nport limiting tracking measures that may impinge on their privacy).'},
#    'context': {'uri': 'gs://pdf_extraction_iwm/input/pdf_test.pdf',
#     'pageNumber': 2}}]}
