# %% [markdown]
# <a href="https://colab.research.google.com/github/olonok69/LLM_Notebooks/blob/main/ml_tricks/colab/VsCode_Colab_connect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Connect VSCODE
# https://developers.cloudflare.com/cloudflare-one/connections/connect-networks/downloads/
#
# https://medium.com/analytics-vidhya/colab-vs-code-github-jupyter-perfect-for-deep-learning-2b257ae94d01#:~:text=Run%20Jupyter%20notebook%20from%20inside%20Colab%20that%20will%20be%20hosted https://developers.cloudflare.com/cloudflare-one/connections/connect-networks/downloads/
#
#
# ### ssh config file
# ```
# Host *.trycloudflare.com
#  HostName %h
#  User root
#  Port 22
#  ProxyCommand <PUT_THE_CLOUDFLARE_FILE_PATH_HERE> access ssh --hostname %h
#
#  ```

# %%
# !pip install colab_ssh --upgrade
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
launch_ssh_cloudflared(password="mypassword")
# Out:
# ...
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# </style>
# <details class="choice-section">
# 	<summary style="cursor:pointer">
# ...
