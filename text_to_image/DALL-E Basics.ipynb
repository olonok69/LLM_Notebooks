# %%
import openai

# %%
from dotenv import dotenv_values

# %%
config = dotenv_values(".env")

# %%
openai.api_key = config["KEY_OPENAI"]

# %%
# '128x128' is not one of ['256x256', '512x512', '1024x1024', '1024x1792', '1792x1024'] - 'size'

# %%
res = openai.Image.create(
    prompt="a buddy playing the fool on the beach, digital art, van gogh",
    size="512x512",
    n=5
)
res["data"]
# Out:
# [<OpenAIObject at 0x25aeb7e46b0> JSON: {
#    "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-s4X3ERCyzNiPfKBpaMl0nFyj/user-OhmDl4rcyRy0TdwBD2ePrEpd/img-HeONCJ1z3GZvUCJ93ctZflLy.png?st=2024-02-11T16%3A38%3A33Z&se=2024-02-11T18%3A38%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-11T17%3A27%3A37Z&ske=2024-02-12T17%3A27%3A37Z&sks=b&skv=2021-08-06&sig=AsE8bqyS%2BGh7PUI4rLDIysjXnpDj5c/5P%2BsLB40SQnw%3D"
#  },
#  <OpenAIObject at 0x25aed67e330> JSON: {
# ...

# %% [markdown]
# Rate limit exceeded for images per minute in organization org-s4X3ERCyzNiPfKBpaMl0nFyj. Limit: 5/1min. Current: 7/1min. Please visit https://platform.openai.com/docs/guides/rate-limits to learn how to increase your rate limit.

# %%
res = openai.Image.create(
    prompt="an eye retina with ckd",
    size="256x256",
    n=2
)
res["data"]
# Out:
# [<OpenAIObject at 0x25aed640b30> JSON: {
#    "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-s4X3ERCyzNiPfKBpaMl0nFyj/user-OhmDl4rcyRy0TdwBD2ePrEpd/img-b4kDEYcZ4XRoB3GOHID8jFBW.png?st=2024-02-11T16%3A41%3A09Z&se=2024-02-11T18%3A41%3A09Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-11T17%3A17%3A28Z&ske=2024-02-12T17%3A17%3A28Z&sks=b&skv=2021-08-06&sig=vGzx4zV35PPA14v%2B4%2B5RhUPTtOevrB7n%2BbOaQbgpXK8%3D"
#  },
#  <OpenAIObject at 0x25aed67dfd0> JSON: {
# ...

# %%
res = openai.Image.create(
    prompt="an eye retina with DR",
    size="1024x1024",
    n=2
)
res["data"]
# Out:
# [<OpenAIObject at 0x25aed67ee10> JSON: {
#    "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-s4X3ERCyzNiPfKBpaMl0nFyj/user-OhmDl4rcyRy0TdwBD2ePrEpd/img-zMy3WcapaNtO85RJdeTUH2fw.png?st=2024-02-11T16%3A43%3A37Z&se=2024-02-11T18%3A43%3A37Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-11T16%3A58%3A15Z&ske=2024-02-12T16%3A58%3A15Z&sks=b&skv=2021-08-06&sig=hufcAqDth5jILxER0vB6uun0hhUniS/iBKJ1OA2dUqk%3D"
#  },
#  <OpenAIObject at 0x25aed67ddf0> JSON: {
# ...

# %%
res = openai.Image.create(
    prompt="a skull under the sun in Valencia",
    size="1024x1024",
    n=2
)
res["data"]
# Out:
# [<OpenAIObject at 0x25aed67e7b0> JSON: {
#    "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-s4X3ERCyzNiPfKBpaMl0nFyj/user-OhmDl4rcyRy0TdwBD2ePrEpd/img-GW3OOvU4iAchHlAUd5mnTVjw.png?st=2024-02-11T16%3A47%3A12Z&se=2024-02-11T18%3A47%3A12Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-11T17%3A27%3A34Z&ske=2024-02-12T17%3A27%3A34Z&sks=b&skv=2021-08-06&sig=GR0d299Vb%2BT%2B6IVqpu6IqE1o63isUzk28UJgtCbhCVI%3D"
#  },
#  <OpenAIObject at 0x25aed67f1d0> JSON: {
# ...

# %%
res = openai.Image.create(
    prompt="a skull under the sun in Maracaibo, digital art style Picasso",
    size="256x256",
    n=1,
    response_format ="b64_json"
    
)
res["data"]
# Out:
# [<OpenAIObject at 0x25aed67e630> JSON: {
#    "b64_json": "..."
#  }]

# %%
import base64
from IPython.core.display import Image

# %%
Image(base64.b64decode(res["data"][0]['b64_json']))
