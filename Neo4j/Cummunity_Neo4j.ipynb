# %% [markdown]
# # Neo4J GDS
#
# https://neo4j.com/docs/graph-data-science/current/algorithms/community/
#
# ## Community
# Community detection algorithms are used to evaluate how groups of nodes are clustered or partitioned, as well as their tendency to strengthen or break apart. The Neo4j GDS library includes the following community detection algorithms, grouped by quality tier:eaker-Listener Label Propagation

# %% [markdown]
# ## Production-quality
#
# - Conductance metric
# <br>
# - K-Core Decomposition
# <br>
# - K-1 Coloring
# <br>
# - K-Means Clustering
# <br>
# - Label Propagation
# <br>
# - Leiden
# <br>
# - Local Clustering Coefficient
# <br>
# - Louvain
# <br>
# - Modularity metric
# <br>
# - Modularity Optimization
# <br>
# - Strongly Connected Components
# <br>
# - Triangle Count
# <br>
# - Weakly Connected Components
# <br>
# ## Alpha
#
# - Approximate Maximum k-cut
# <br>
# - Speaker-Listener Label Propagation

# %%
from langchain.graphs import Neo4jGraph

graph = Neo4jGraph(
    url="bolt://18.234.164.187:7687",
    username="neo4j",
    password="energies-hope-fuses"
)

r = graph.query("""MATCH (n:Airport {city:"Los Angeles"}) RETURN n""")
print(r)
# Out:
# [{'n': {'altitude': 127, 'longest': 12091, 'city': 'Los Angeles', 'descr': 'Los Angeles International Airport', 'iata': 'LAX', 'icao': 'KLAX', 'location': POINT(-118.4079971 33.94250107), 'pagerank_weight': 8.19355807544669, 'id': '13', 'pagerank': 8.193558075446687, 'runways': 4, 'region_airports': 1, 'country_airports': 1}}]

# %% [markdown]
# # Conductance metric
# https://neo4j.com/docs/graph-data-science/current/algorithms/conductance//<br>
# Conductance is a metric that allows you to evaluate the quality of a community detection. Relationships of nodes in a community C connect to nodes either within C or outside C. The conductance is the ratio between relationships that point outside C and the total number of relationships of C. The lower the conductance, the more "well-knit" a community is.
#
# It was shown by Yang and Leskovec in the paper "Defining and Evaluating Network Communities based on Ground-truth" that conductance is a very good metric for evaluating actual communities of real world graphs.
#
# The algorithm runs in time linear to the number of relationships in the graph.it.

# %%
# create a new Relation named  HAS_CONTINENT_ROUTE
r = graph.query("""MATCH (p:Airport)-[:HAS_ROUTE]->(c:Airport) 
MATCH (p:Airport)-[:ON_CONTINENT]->(b:Continent) 
MATCH (c:Airport)-[:ON_CONTINENT]->(d:Continent) 
where b.name <> d.name
with  p,c,b,d, p.region_airports as region_airports, p.country_airports as country_airports, p.runways as runways ,c.region_airports as cregion_airports, c.country_airports as ccountry_airports, c.runways as crunways
merge (p)-[:HAS_CONTINENT_ROUTE {weight : ((region_airports* runways)/country_airports) / ((cregion_airports* crunways)/ccountry_airports)}]->(c) 
return p,c,b,d limit 25 """)
print(len(r))
# Out:
# 3503

# %%
# create Projection Num Airports

# %%
# Call gds.graph.drop("Graph_Airports")

# %%
r = graph.query("""CALL gds.graph.project(
    'Conductance',
    'Airport',
    {
        HAS_CONTINENT_ROUTE: {
            orientation: 'UNDIRECTED'
        }
    },
    {
        nodeProperties: 'country_airports',
        relationshipProperties: 'weight'
    }
)""")
print(r)
# Out:
# [{'nodeProjection': {'Airport': {'label': 'Airport', 'properties': {'country_airports': {'property': 'country_airports', 'defaultValue': None}}}}, 'relationshipProjection': {'HAS_CONTINENT_ROUTE': {'aggregation': 'DEFAULT', 'orientation': 'UNDIRECTED', 'indexInverse': False, 'properties': {'weight': {'aggregation': 'DEFAULT', 'property': 'weight', 'defaultValue': None}}, 'type': 'HAS_CONTINENT_ROUTE'}}, 'graphName': 'Conductance', 'nodeCount': 3503, 'relationshipCount': 16560, 'projectMillis': 388}]

# %%
len(r)
# Out:
# 1

# %%
r[-1]
# Out:
# {'nodeProjection': {'Airport': {'label': 'Airport', 'properties': {}}},
#  'relationshipProjection': {'HAS_ROUTE_WEIGHT': {'aggregation': 'DEFAULT',
#    'orientation': 'NATURAL',
#    'indexInverse': False,
#    'properties': {'weight': {'aggregation': 'DEFAULT',
#      'property': 'weight',
#      'defaultValue': None}},
#    'type': 'HAS_ROUTE_WEIGHT'}},
#  'graphName': 'Graph_Airports',
#  'nodeCount': 3503,
#  'relationshipCount': 46389,
#  'projectMillis': 31}

# %%
# We now run the Louvain algorithm to create a division of the nodes into communities that we can then evalutate.

# %%
r = graph.query("""CALL gds.louvain.mutate('Conductance', { mutateProperty: 'community', relationshipWeightProperty: 'weight' })
YIELD communityCount""")
print(r)
# Out:
# [{'communityCount': 2731}]

# %% [markdown]
# # Run the algorithm in stream mode
#
# Since we now have a community detection, we can evaluate how good it is under the conductance metric. Note that we in this case we use the feature of relationships being weighted by a relationship property.

# %%
# unweighted
r = graph.query("""CALL gds.graph.nodeProperty.stream('Conductance', 'community')
YIELD nodeId, propertyValue
RETURN gds.util.asNode(nodeId).descr AS name, propertyValue AS community
ORDER BY community ASC
""")
print(r[:50])
# Out:
# [{'name': 'Ronald Reagan Washington National Airport', 'community': 6}, {'name': 'New York La Guardia', 'community': 13}, {'name': 'Palm Beach International Airport', 'community': 18}, {'name': 'Long Beach Airport', 'community': 26}, {'name': 'Orange County/Santa Ana, John Wayne', 'community': 27}, {'name': 'Westchester County', 'community': 31}, {'name': 'San Antonio', 'community': 32}, {'name': 'The Eastern Iowa Airport', 'community': 35}, {'name': 'Houston Hobby', 'community': 37}, {'name': 'El Paso International Airport', 'community': 38}, {'name': 'Tucson International Airport', 'community': 42}, {'name': 'Santa Fe', 'community': 43}, {'name': 'Newark, Liberty', 'community': 51}, {'name': 'Dublin International Airport', 'community': 51}, {'name': 'Brussels Airport', 'community': 51}, {'name': 'Munich International Airport', 'community': 51}, {'name': 'Southwest Florida International Airport', 'community': 51}, {'name': 'Manchester Airport', 'community': 51}, {'name': 'Cologne Bonn Airport', 'community': 51}, {'name': 'Gothenburg-Landvetter Airport', 'community': 51}, {'name': 'Shannon Airport', 'community': 51}, {'name': 'Stockholm-Arlanda Airport', 'community': 51}, {'name': 'London Stansted Airport', 'community': 51}, {'name': 'East Midlands Airport', 'community': 51}, {'name': 'Edinburgh Airport', 'community': 51}, {'name': 'Glasgow International Airport', 'community': 51}, {'name': 'Liverpool John Lennon Airport', 'community': 51}, {'name': 'Mombasa Moi International Airport', 'community': 51}, {'name': 'Larnaca International Airport', 'community': 51}, {'name': 'Hamburg Airport', 'community': 51}, {'name': 'Stuttgart Airport', 'community': 51}, {'name': 'Verona Villafranca Airport', 'community': 51}, {'name': 'Copenhagen Kastrup Airport', 'community': 51}, {'name': 'Luxembourg-Findel International Airport', 'community': 51}, {'name': 'Dusseldorf International Airport', 'community': 51}, {'name': 'London Luton Airport', 'community': 51}, {'name': 'Tobago-Crown Point Airport', 'community': 51}, {'name': 'Montego Bay, Sangster International Airport', 'community': 51}, {'name': 'Providence, Theodore Francis Green State Airport', 'community': 51}, {'name': 'Leeds Bradford Airport', 'community': 51}, {'name': 'Antalya International Airport', 'community': 51}, {'name': 'Birmingham International Airport', 'community': 51}, {'name': 'Salzburg Airport', 'community': 51}, {'name': 'Trondheim Airport, Værnes', 'community': 51}, {'name': 'Billund Airport', 'community': 51}, {'name': 'Dresden Airport', 'community': 51}, {'name': 'Bremen Airport', 'community': 51}, {'name': 'Erfurt Airport', 'community': 51}, {'name': 'Belfast International Airport', 'community': 51}, {'name': 'Aalborg Airport', 'community': 51}]

# %%
# unweighted
r = graph.query("""CALL gds.conductance.stream('Conductance', { communityProperty: 'community', relationshipWeightProperty: 'weight' })
YIELD community, conductance
RETURN  community, conductance
ORDER BY conductance DESC
""")

print(r[:5])
# Out:
# [{'community': 214, 'conductance': 0.6001809136137495}, {'community': 160, 'conductance': 0.5393586005830904}, {'community': 51, 'conductance': 0.4486486486486487}, {'community': 335, 'conductance': 0.44703965236284626}, {'community': 1763, 'conductance': 0.4326846174353506}]

# %%
for x in r:
    if x.get("community") == 214:
        print(x.get("name"))
# Out:
# Warsaw Chopin Airport
# Malta International Airport
# Sofia Airport
# Belgrade Nikola Tesla Airport
# Cairo International Airport
# Addis Ababa Bole International Airport
# Kuwait International Airport
# Bahrain International Airport
# Abu Dhabi International Airport
# Bologna Guglielmo Marconi Airport
# Tunis Carthage International Airport
# Freeport, Grand Bahama International Airport
# King Abdulaziz International Airport
# Muscat International Airport
# Luxor International Airport
# Riyadh, King Khaled International Airport
# Malaga Airport
# Modlin Airport
# Podgorica Airport
# Berbera Airport
# Borg El Arab International Airport
# Port Sudan New International Airport
# Juba International Airport
# Khartoum International Airport
# Julius Nyerere International Airport
# Skopje Alexander the Great Airport
# Ostrava Leos Janáček Airport
# Kopitnari Airport
# Saniat Rmel Airport
# Aden Adde International Airport
# Assiut International Airport
# Sohag International Airport
# Aswan International Airport
# Asmara International Airport
# John Paul II International Airport Kraków-Balice Airport
# Thessaloniki Macedonia International Airport
# Chicago O'Hare International Airport
# Philadelphia International Airport
# Dubai International Airport
# Vienna International Airport
# Geneva-Cointrin International Airport
# Canberra International Airport
# Venice Marco Polo Airport
# Doha, Hamad International Airport
# Milan, Malpensa International Airport
# Athens, Eleftherios Venizelos International Airport
# Budapest Ferenc Liszt International Airport
# Cape Town International Airport
# Nairobi, Jomo Kenyatta International Airport
# Hodeidah International Airport
# Ta'izz International Airport
# Abha Regional Airport
# Prince Mohammad Bin Abdulaziz Airport
# Tabuk Airport
# Mukalla International Airport
# Sarajevo International Airport
# Falcone–Borsellino Airport
# Ljubljana Jože Pučnik Airport
# Casa De Campo International Airport
# Ovda International Airport
# Aqaba King Hussein International Airport
# Al Ain International Airport
# Maputo Airport
# Benina International Airport
# Uytash Airport
# Phu Quoc Airport
# Berlin Brandenburg International Airport
# Dubrovnik Airport
# Queen Alia International Airport
# Alama Iqbal International Airport
# Entebbe International Airport
# Henri Coanda International Airport
# Tripoli International Airport
# Ras Al Khaimah International Airport
# Al Alamein International Airport
# Ramon International Airport
# Aden International Airport
# Sana'a International Airport
# Vilo Acuña International Airport

# %%
# Call gds.graph.drop("Conductance")

# %% [markdown]
# ### K-Core Decomposition
# https://neo4j.com/docs/graph-data-science/current/algorithms/k-core/
#
# The K-core decomposition constitutes a process of separates the nodes in a graph into groups based on the degree sequence and topology of the graph.
#
# The term i-core refers to a maximal subgraph of the original graph such that each node in this subgraph has degree at least i. The maximality ensures that it is not possible to find another subgraph with more nodes where this degree property holds.
#
# The nodes in the subgraph denoted by i-core also belong to the subgraph denoted by j-core for any j<i. The converse however is not true. Each node u is associated with a core value which denotes the largest value i such that u belongs to the i-core. The largest core value is called the degeneracy of the graph.
#
# Standard algorithms for K-Core Decomposition iteratively remove the node of lowest degree until the graph becomes empty. When a node is removed from the graph, all of its relationships are removed, and the degree of its neighbors is reduced by one. With this approach, the different core groups are discovered one-by-one.n

# %%
r = graph.query("""CALL gds.graph.project(
  'Kcore',
  'Airport',
  {
    HAS_ROUTE_WEIGHT: {
      orientation: 'UNDIRECTED'
    }
  }
)
""")

print(r[:25])
# Out:
# [{'nodeProjection': {'Airport': {'label': 'Airport', 'properties': {}}}, 'relationshipProjection': {'HAS_ROUTE_WEIGHT': {'aggregation': 'DEFAULT', 'orientation': 'UNDIRECTED', 'indexInverse': False, 'properties': {}, 'type': 'HAS_ROUTE_WEIGHT'}}, 'graphName': 'Kcore', 'nodeCount': 3503, 'relationshipCount': 92778, 'projectMillis': 26}]

# %% [markdown]
# # Memory Estimation
# If the results of the algorithm are as expected, the next step can be to write them back to the Neo4j database

# %%
r = graph.query("""CALL gds.kcore.write.estimate('Kcore', { writeProperty: 'coreValue' })
YIELD nodeCount, relationshipCount, bytesMin, bytesMax, requiredMemory
""")

print(r[:25])
# Out:
# [{'nodeCount': 3503, 'relationshipCount': 92778, 'bytesMin': 144120, 'bytesMax': 144120, 'requiredMemory': '140 KiB'}]

# %% [markdown]
# # Write the results
# If the results of the algorithm are as expected, the next step can be to write them back to the Neo4j database

# %%
r = graph.query("""CALL gds.kcore.stream('Kcore')
YIELD nodeId, coreValue
RETURN gds.util.asNode(nodeId).descr AS name, coreValue
ORDER BY coreValue DESC
""")

print(r[:20])
# Out:
# [{'name': 'London Heathrow', 'coreValue': 82}, {'name': 'London Gatwick', 'coreValue': 82}, {'name': 'Paris Charles de Gaulle', 'coreValue': 82}, {'name': 'Frankfurt am Main', 'coreValue': 82}, {'name': 'Helsinki Ventaa', 'coreValue': 82}, {'name': 'Dubai International Airport', 'coreValue': 82}, {'name': 'Dublin International Airport', 'coreValue': 82}, {'name': 'Leonardo da Vinci-Fiumicino International Airport', 'coreValue': 82}, {'name': 'Amsterdam Airport Schiphol', 'coreValue': 82}, {'name': 'Prague, Ruzyne International Airport', 'coreValue': 82}, {'name': 'Barcelona International Airport', 'coreValue': 82}, {'name': 'Adolfo Suarez Barajas Airport International Airport', 'coreValue': 82}, {'name': 'Vienna International Airport', 'coreValue': 82}, {'name': 'Zurich-Kloten Airport', 'coreValue': 82}, {'name': 'Geneva-Cointrin International Airport', 'coreValue': 82}, {'name': 'Brussels Airport', 'coreValue': 82}, {'name': 'Munich International Airport', 'coreValue': 82}, {'name': 'Manchester Airport', 'coreValue': 82}, {'name': 'Cologne Bonn Airport', 'coreValue': 82}, {'name': 'Venice Marco Polo Airport', 'coreValue': 82}]

# %%
cv=[]
for x in r:
    if x.get("coreValue") not in cv:
        print(x.get("coreValue"), x.get("name"))
        cv.append(x.get("coreValue"))
# Out:
# 82 London Heathrow
# 80 Brussels South Charleroi Airport
# 79 Liverpool John Lennon Airport
# 77 Vilnius International Airport
# 74 Venice, Treviso-Sant Angelo Airport
# 73 Newcastle Airport
# 72 Hartsfield - Jackson Atlanta International Airport
# 71 Modlin Airport
# 70 Columbus, Port Columbus International Airport
# 69 Rotterdam Airport
# 68 Katowice International Airport
# 67 Adnan Menderes International Airport
# 66 Niederrhein Airport
# 65 Zagreb Airport
# 64 Jose Marti International Airport
# 63 King Abdulaziz International Airport
# 62 Hurghada International Airport
# 61 Oaklahoma City, Will Rogers World Airport
# 60 Puerto Rico, Luis Munoz International Airport
# 58 Milas Bodrum International Airport
# 57 Enfidha - Hammamet International Airport
# 56 Don Miguel Hidalgo Y Costilla International Airport
# 55 Ljubljana Jože Pučnik Airport
# 54 Santiago de Compostela Airport
# 53 Krasnodar International Airport
# 52 Al Maktoum International Airport
# 51 Jersey Airport
# 50 Lanzhou Zhongchuan Airport
# 49 Iaşi Airport
# 48 Mactan Cebu International Airport
# 47 Timişoara Traian Vuia Airport
# 46 Dhaka / Hazrat Shahjalal International Airport
# 45 Jinnah International Airport
# 44 Prince Mohammad Bin Abdulaziz Airport
# 43 Trondheim Airport, Værnes
# 42 Sarasota Bradenton International Airport
# 41 Münster Osnabrück Airport
# 40 King Fahd International Airport
# 39 Monastir Habib Bourguiba International Airport
# 38 Kurumoch International Airport
# 37 Jerez Airport
# 36 Vladivostok International Airport
# 35 João Paulo II Airport
# 34 Piedmont Triad International Airport
# 33 Providenciales Airport
# 32 Norwich International Airport
# 31 Friedrichshafen Airport
# 30 Malmö Sturup Airport
# 29 Federico Garcia Lorca Airport
# 28 Toussaint Louverture International Airport
# 27 Volgograd International Airport
# 26 Federico Fellini International Airport
# 25 Mashhad International Airport
# 24 Douala International Airport
# 23 Trabzon International Airport
# 22 Debrecen International Airport
# 21 Nantong Airport
# 20 Northwest Florida Beaches International Airport
# 19 Tuzla International Airport
# 18 Jardines Del Rey Airport
# 17 General Guadalupe Victoria International Airport
# 16 Gimpo International Airport
# 15 Oradea International Airport
# 14 Johan Adolf Pengel International Airport
# 13 Ayers Rock Connellan Airport
# 12 George Town, Exuma International Airport
# 11 Lappeenranta Airport
# 10 Molde Airport
# 9 Gheshm Airport
# 8 Uytash Airport
# 7 Xilinhot Airport
# 6 Can Tho International Airport
# 5 Izumo Airport
# 4 Guyuan Liupanshan Airport
# 3 Eday Airport
# 2 Port Lions Airport
# 1 Turukhansk Airport
# 0 Red Devil Airport

# %% [markdown]
#  # Delete Projection

# %%
r = graph.query(""" Call gds.graph.drop("Kcore")
""")

print(r)
# Out:
# [{'graphName': 'Kcore', 'database': 'neo4j', 'databaseLocation': 'local', 'memoryUsage': '', 'sizeInBytes': -1, 'nodeCount': 3503, 'relationshipCount': 92778, 'configuration': {'relationshipProjection': {'HAS_ROUTE_WEIGHT': {'aggregation': 'DEFAULT', 'orientation': 'UNDIRECTED', 'indexInverse': False, 'properties': {}, 'type': 'HAS_ROUTE_WEIGHT'}}, 'readConcurrency': 4, 'relationshipProperties': {}, 'nodeProperties': {}, 'jobId': 'e7907772-bb86-4de8-a2aa-21b2298652f3', 'nodeProjection': {'Airport': {'label': 'Airport', 'properties': {}}}, 'logProgress': True, 'creationTime': neo4j.time.DateTime(2024, 4, 4, 14, 44, 4, 40694529, tzinfo=<UTC>), 'validateRelationships': False, 'sudo': False}, 'density': 0.007562906429391597, 'creationTime': neo4j.time.DateTime(2024, 4, 4, 14, 44, 4, 40694529, tzinfo=<UTC>), 'modificationTime': neo4j.time.DateTime(2024, 4, 4, 14, 44, 4, 67689109, tzinfo=<UTC>), 'schema': {'graphProperties': {}, 'nodes': {'Airport': {}}, 'relationships': {'HAS_ROUTE_WEIGHT': {}}}, 'schemaWithOrientation': {'graphProperties': {}, 'nodes': {'Airport': {}}, 'relationships': {'HAS_ROUTE_WEIGHT': {'direction': 'UNDIRECTED', 'properties': {}}}}}]

# %% [markdown]
# # K-1 Coloring
#
# https://neo4j.com/docs/graph-data-science/current/algorithms/k1coloring/
#
# The K-1 Coloring algorithm assigns a color to every node in the graph, trying to optimize for two objectives:
#
# To make sure that every neighbor of a given node has a different color than the node itself.
#
# To use as few colors as possible.
#
# Note that the graph coloring problem is proven to be NP-complete, which makes it intractable on anything but trivial graph sizes. For that reason the implemented algorithm is a greedy algorithm. Thus it is neither guaranteed that the result is an optimal solution, using as few colors as theoretically possible, nor does it always produce a correct result where no two neighboring nodes have different colors. However the precision of the latter can be controlled by the number of iterations this algorithm runs.

# %%
 # MATCH (n:Country)-[:ON_CONTINENT]->(c:Continent) RETURN n,c LIMIT 50
r = graph.query("""CALL gds.graph.project(
    'K1-COLORING',
    'Airport',
    {
        HAS_ROUTE : {
            orientation: 'UNDIRECTED'
        }
    }
)""")
print(r)
# Out:
# [{'nodeProjection': {'Airport': {'label': 'Airport', 'properties': {}}}, 'relationshipProjection': {'HAS_ROUTE': {'aggregation': 'DEFAULT', 'orientation': 'UNDIRECTED', 'indexInverse': False, 'properties': {}, 'type': 'HAS_ROUTE'}}, 'graphName': 'K1-COLORING', 'nodeCount': 3503, 'relationshipCount': 185556, 'projectMillis': 85}]

# %%
r = graph.query("""CALL gds.k1coloring.stream('K1-COLORING')
YIELD nodeId, color
RETURN gds.util.asNode(nodeId).descr AS name, color
ORDER BY name""")
print(r[:20])
# Out:
# [{'name': 'A Coruna Airport', 'color': 0}, {'name': 'Aalborg Airport', 'color': 0}, {'name': 'Aarhus Airport', 'color': 6}, {'name': 'Aasiaat Airport', 'color': 0}, {'name': 'Aba Tenna Dejazmach Yilma International Airport', 'color': 0}, {'name': 'Abadan Airport', 'color': 0}, {'name': 'Abakan Airport', 'color': 0}, {'name': 'Abbotsford Airport', 'color': 5}, {'name': 'Abdul Rachman Saleh Airport', 'color': 0}, {'name': 'Abeche Airport', 'color': 0}, {'name': 'Abeid Amani Karume International Airport', 'color': 0}, {'name': 'Abel Santamaria Airport', 'color': 3}, {'name': 'Aberdeen Dyce Airport', 'color': 6}, {'name': 'Aberdeen Regional Airport', 'color': 0}, {'name': 'Abha Regional Airport', 'color': 3}, {'name': 'Abilene Regional Airport', 'color': 0}, {'name': 'Abraham González International Airport', 'color': 3}, {'name': 'Abraham Lincoln Capital Airport', 'color': 0}, {'name': 'Abu Dhabi International Airport', 'color': 14}, {'name': 'Abu Simbel Airport', 'color': 1}]

# %%
r = graph.query("""CALL gds.k1coloring.stats('K1-COLORING')
YIELD nodeCount, colorCount, ranIterations, didConverge""")
print(r)
# Out:
# [{'nodeCount': 3503, 'colorCount': 37, 'ranIterations': 2, 'didConverge': True}]

# %%
r = graph.query("""CALL gds.k1coloring.write('K1-COLORING', {writeProperty: 'color'})
YIELD nodeCount, colorCount, ranIterations, didConverge""")
print(r)
# Out:
# [{'nodeCount': 3503, 'colorCount': 38, 'ranIterations': 2, 'didConverge': True}]

# %%
# MATCH (n:Airport)-[:HAS_ROUTE]->(c:Airport) where n.color=9 RETURN n, c LIMIT 5

# %%
r = graph.query("""CALL gds.ephemeral.database.create(
  'gdsdb',
  'K1-COLORING')
""")

print(r)
# Out:
# [{'dbName': 'gdsdb', 'graphName': 'K1-COLORING', 'createMillis': 2768}]

# %%
r = graph.query(""" Call gds.graph.drop("K1-COLORING")
""")

print(r)
# Out:
# [{'graphName': 'K1-COLORING', 'database': 'neo4j', 'databaseLocation': 'local', 'memoryUsage': '', 'sizeInBytes': -1, 'nodeCount': 3503, 'relationshipCount': 185556, 'configuration': {'relationshipProjection': {'HAS_ROUTE': {'aggregation': 'DEFAULT', 'orientation': 'UNDIRECTED', 'indexInverse': False, 'properties': {}, 'type': 'HAS_ROUTE'}}, 'readConcurrency': 4, 'relationshipProperties': {}, 'nodeProperties': {}, 'jobId': '76b4af55-26c2-484b-bb3a-b087c69453c6', 'nodeProjection': {'Airport': {'label': 'Airport', 'properties': {}}}, 'logProgress': True, 'creationTime': neo4j.time.DateTime(2024, 4, 4, 15, 24, 28, 964720748, tzinfo=<UTC>), 'validateRelationships': False, 'sudo': False}, 'density': 0.015125812858783194, 'creationTime': neo4j.time.DateTime(2024, 4, 4, 15, 24, 28, 964720748, tzinfo=<UTC>), 'modificationTime': neo4j.time.DateTime(2024, 4, 4, 15, 24, 29, 51058699, tzinfo=<UTC>), 'schema': {'graphProperties': {}, 'nodes': {'Airport': {}}, 'relationships': {'HAS_ROUTE': {}}}, 'schemaWithOrientation': {'graphProperties': {}, 'nodes': {'Airport': {}}, 'relationships': {'HAS_ROUTE': {'direction': 'UNDIRECTED', 'properties': {}}}}}]

# %% [markdown]
# # K-Means Clustering
# https://neo4j.com/docs/graph-data-science/current/algorithms/kmeans/
#
# K-Means clustering is an unsupervised learning algorithm that is used to solve clustering problems. It follows a simple procedure of classifying a given data set into a number of clusters, defined by the parameter k. The Neo4j GDS Library conducts clustering based on node properties, with a float array node property being passed as input via the nodeProperty parameter. Nodes in the graph are then positioned as points in a d-dimensional space (where d is the length of the array property).

# %%
# create coordinates
r = graph.query("""MATCH (m:Airport)
with  m, m.location as location
set m.coordinates  =  [location.x, location.y]
return m limit 25""")
print(r[:5])
# Out:
# [{'m': {'altitude': 1026, 'longest': 12390, 'color': 0, 'city': 'Atlanta', 'coordinates': [-84.4281005859375, 33.6366996765137], 'descr': 'Hartsfield - Jackson Atlanta International Airport', 'iata': 'ATL', 'icao': 'KATL', 'location': POINT(-84.4281005859375 33.6366996765137), 'pagerank_weight': 10.38994835030296, 'id': '1', 'pagerank': 10.389948350302957, 'runways': 5, 'region_airports': 1, 'country_airports': 1}}, {'m': {'altitude': 151, 'longest': 12400, 'color': 0, 'city': 'Anchorage', 'coordinates': [-149.996002197266, 61.1744003295898], 'descr': 'Anchorage Ted Stevens', 'iata': 'ANC', 'icao': 'PANC', 'location': POINT(-149.996002197266 61.1744003295898), 'pagerank_weight': 2.651157253813937, 'id': '2', 'pagerank': 2.6511572538139374, 'runways': 3, 'region_airports': 1, 'country_airports': 1}}, {'m': {'altitude': 542, 'longest': 12250, 'color': 1, 'city': 'Austin', 'coordinates': [-97.6698989868164, 30.1944999694824], 'descr': 'Austin Bergstrom International Airport', 'iata': 'AUS', 'icao': 'KAUS', 'location': POINT(-97.6698989868164 30.1944999694824), 'pagerank_weight': 3.3970361709221706, 'id': '3', 'pagerank': 3.397036170922171, 'runways': 2, 'region_airports': 1, 'country_airports': 1}}, {'m': {'altitude': 599, 'longest': 11030, 'color': 2, 'city': 'Nashville', 'coordinates': [-86.6781997680664, 36.1245002746582], 'descr': 'Nashville International Airport', 'iata': 'BNA', 'icao': 'KBNA', 'location': POINT(-86.6781997680664 36.1245002746582), 'pagerank_weight': 2.913092915746176, 'id': '4', 'pagerank': 2.913092915746176, 'runways': 4, 'region_airports': 1, 'country_airports': 1}}, {'m': {'altitude': 19, 'longest': 10083, 'color': 3, 'city': 'Boston', 'coordinates': [-71.00520325, 42.36429977], 'descr': 'Boston Logan', 'iata': 'BOS', 'icao': 'KBOS', 'location': POINT(-71.00520325 42.36429977), 'pagerank_weight': 5.587850199484761, 'id': '5', 'pagerank': 5.587850199484761, 'runways': 6, 'region_airports': 1, 'country_airports': 1}}]

# %%
r = graph.query("""CALL gds.graph.project(
    'Airports',
    {
      Airport: {
        properties: 'coordinates'
      }
    },
    '*'
)""")
print(r)
# Out:
# [{'nodeProjection': {'Airport': {'label': 'Airport', 'properties': {'coordinates': {'property': 'coordinates', 'defaultValue': None}}}}, 'relationshipProjection': {'__ALL__': {'aggregation': 'DEFAULT', 'orientation': 'NATURAL', 'indexInverse': False, 'properties': {}, 'type': '*'}}, 'graphName': 'Airports', 'nodeCount': 3503, 'relationshipCount': 147447, 'projectMillis': 340}]

# %%
r = graph.query("""CALL gds.kmeans.write.estimate('Airports', {
  writeProperty: 'kmeans',
  nodeProperty: 'coordinates'
})
YIELD nodeCount, bytesMin, bytesMax, requiredMemory""")
print(r)
# Out:
# [{'nodeCount': 3503, 'bytesMin': 103888, 'bytesMax': 124880, 'requiredMemory': '[101 KiB ... 121 KiB]'}]

# %%
r = graph.query("""CALL gds.kmeans.stream('Airports', {
  nodeProperty: 'coordinates',
  k: 30,
  randomSeed: 42
})
YIELD nodeId, communityId
RETURN gds.util.asNode(nodeId).descr AS name, communityId
ORDER BY communityId, name ASC""")
print(r[:25])
# Out:
# [{'name': 'Abakan Airport', 'communityId': 0}, {'name': 'Aksu Airport', 'communityId': 0}, {'name': 'Alashankou Bole (Bortala) airport', 'communityId': 0}, {'name': 'Almaty Airport', 'communityId': 0}, {'name': 'Altai Airport', 'communityId': 0}, {'name': 'Altay Air Base', 'communityId': 0}, {'name': 'Astana International Airport', 'communityId': 0}, {'name': 'Barnaul Airport', 'communityId': 0}, {'name': 'Bayankhongor Airport', 'communityId': 0}, {'name': 'Bogashevo Airport', 'communityId': 0}, {'name': 'Bratsk Airport', 'communityId': 0}, {'name': 'Chinggis Khaan International Airport', 'communityId': 0}, {'name': 'Dalanzadgad Airport', 'communityId': 0}, {'name': 'Donoi Airport', 'communityId': 0}, {'name': 'Dunhuang Airport', 'communityId': 0}, {'name': 'Fuyun Kroktokay Airport', 'communityId': 0}, {'name': 'Gorno-Altaysk Airport', 'communityId': 0}, {'name': 'Hami Airport', 'communityId': 0}, {'name': 'Igarka Airport', 'communityId': 0}, {'name': 'Irkutsk Airport', 'communityId': 0}, {'name': 'Kanas Airport', 'communityId': 0}, {'name': 'Karamay Airport', 'communityId': 0}, {'name': 'Kemerovo Airport', 'communityId': 0}, {'name': 'Khovd Airport', 'communityId': 0}, {'name': 'Kirensk Airport', 'communityId': 0}]

# %%
cv=[]
for x in r:
    if x.get("communityId") not in cv:
        print(x.get("communityId"), x.get("name"))
        cv.append(x.get("communityId"))
# Out:
# 0 Abakan Airport
# 1 Abu Dhabi International Airport
# 2 Auckland International Airport
# 3 Aktobe Airport
# 4 Aba Tenna Dejazmach Yilma International Airport
# 5 Alta Airport
# 6 Aberdeen Dyce Airport
# 7 Afonso Pena Airport
# 8 Agatti Airport
# 9 Anqing Airport
# 10 Abadan Airport
# 11 Adnan Menderes International Airport
# 12 Akita Airport
# 13 Antonio B. Won Pat International Airport
# 14 A Coruna Airport
# 15 Al Massira Airport
# 16 Aalborg Airport
# 17 Abel Santamaria Airport
# 18 Arad International Airport
# 19 Ahe Airport
# 20 Ajaccio-Napoléon Bonaparte Airport
# 21 Buon Ma Thuot Airport
# 22 Abeid Amani Karume International Airport
# 23 Adelaide International Airport
# 24 Abdul Rachman Saleh Airport
# 25 Aasiaat Airport
# 26 Aneityum Airport
# 27 Abbotsford Airport
# 28 Abeche Airport
# 29 Agartala Airport

# %%
r = graph.query("""Call gds.graph.drop("Airports")""")
print(r)
# Out:
# [{'graphName': 'Airports', 'database': 'neo4j', 'databaseLocation': 'local', 'memoryUsage': '', 'sizeInBytes': -1, 'nodeCount': 3503, 'relationshipCount': 147447, 'configuration': {'relationshipProjection': {'__ALL__': {'aggregation': 'DEFAULT', 'orientation': 'NATURAL', 'indexInverse': False, 'properties': {}, 'type': '*'}}, 'readConcurrency': 4, 'relationshipProperties': {}, 'nodeProperties': {}, 'jobId': '97e82383-f66f-495b-9db3-7e8d1cc2479e', 'nodeProjection': {'Airport': {'label': 'Airport', 'properties': {'coordinates': {'property': 'coordinates', 'defaultValue': None}}}}, 'logProgress': True, 'creationTime': neo4j.time.DateTime(2024, 4, 4, 15, 38, 4, 918719575, tzinfo=<UTC>), 'validateRelationships': False, 'sudo': False}, 'density': 0.012019313461106112, 'creationTime': neo4j.time.DateTime(2024, 4, 4, 15, 38, 4, 918719575, tzinfo=<UTC>), 'modificationTime': neo4j.time.DateTime(2024, 4, 4, 15, 38, 5, 260820016, tzinfo=<UTC>), 'schema': {'graphProperties': {}, 'nodes': {'Airport': {'coordinates': 'List of Float (DefaultValue(null), PERSISTENT)'}}, 'relationships': {'__ALL__': {}}}, 'schemaWithOrientation': {'graphProperties': {}, 'nodes': {'Airport': {'coordinates': 'List of Float (DefaultValue(null), PERSISTENT)'}}, 'relationships': {'__ALL__': {'direction': 'DIRECTED', 'properties': {}}}}}]

# %% [markdown]
# # Label Propagation
# https://neo4j.com/docs/graph-data-science/current/algorithms/label-propagation/
#
# The Label Propagation algorithm (LPA) is a fast algorithm for finding communities in a graph. It detects these communities using network structure alone as its guide, and doesn’t require a pre-defined objective function or prior information about the communities.
#
# LPA works by propagating labels throughout the network and forming communities based on this process of label propagation.
#
# The intuition behind the algorithm is that a single label can quickly become dominant in a densely connected group of nodes, but will have trouble crossing a sparsely connected region. Labels will get trapped inside a densely connected group of nodes, and those nodes that end up with the same label when the algorithms finish can be considered part of the same community.

# %%
r = graph.query("""CALL gds.graph.project(
    'LP',
    'Airport',
    'HAS_ROUTE_WEIGHT',
    {
        nodeProperties: ['coordinates', 'altitude', 'runways'],
        relationshipProperties: 'weight'
    }
)""")
print(r)
# Out:
# [{'nodeProjection': {'Airport': {'label': 'Airport', 'properties': {'runways': {'property': 'runways', 'defaultValue': None}, 'altitude': {'property': 'altitude', 'defaultValue': None}, 'coordinates': {'property': 'coordinates', 'defaultValue': None}}}}, 'relationshipProjection': {'HAS_ROUTE_WEIGHT': {'aggregation': 'DEFAULT', 'orientation': 'NATURAL', 'indexInverse': False, 'properties': {'weight': {'aggregation': 'DEFAULT', 'property': 'weight', 'defaultValue': None}}, 'type': 'HAS_ROUTE_WEIGHT'}}, 'graphName': 'LP', 'nodeCount': 3503, 'relationshipCount': 46389, 'projectMillis': 255}]

# %%
r = graph.query("""CALL gds.labelPropagation.write.estimate('LP', { writeProperty: 'community' })
YIELD nodeCount, relationshipCount, bytesMin, bytesMax, requiredMemory""")
print(r)
# Out:
# [{'nodeCount': 3503, 'relationshipCount': 46389, 'bytesMin': 30040, 'bytesMax': 553816, 'requiredMemory': '[29 KiB ... 540 KiB]'}]

# %%
# In the stats execution mode, the algorithm returns a single row containing a summary of the algorithm result.
r = graph.query("""CALL gds.labelPropagation.stream('LP')
YIELD nodeId, communityId AS Community
RETURN gds.util.asNode(nodeId).descr AS Name, Community
ORDER BY Community, Name""")
print(r[:25])
# Out:
# [{'Name': 'A Coruna Airport', 'Community': 8629}, {'Name': 'Aalborg Airport', 'Community': 8629}, {'Name': 'Aarhus Airport', 'Community': 8629}, {'Name': 'Aba Tenna Dejazmach Yilma International Airport', 'Community': 8629}, {'Name': 'Abbotsford Airport', 'Community': 8629}, {'Name': 'Abeid Amani Karume International Airport', 'Community': 8629}, {'Name': 'Abel Santamaria Airport', 'Community': 8629}, {'Name': 'Aberdeen Dyce Airport', 'Community': 8629}, {'Name': 'Aberdeen Regional Airport', 'Community': 8629}, {'Name': 'Abha Regional Airport', 'Community': 8629}, {'Name': 'Abilene Regional Airport', 'Community': 8629}, {'Name': 'Abraham González International Airport', 'Community': 8629}, {'Name': 'Abraham Lincoln Capital Airport', 'Community': 8629}, {'Name': 'Abu Dhabi International Airport', 'Community': 8629}, {'Name': 'Achmad Yani Airport', 'Community': 8629}, {'Name': 'Adak Airport', 'Community': 8629}, {'Name': 'Adana Airport', 'Community': 8629}, {'Name': 'Addis Ababa Bole International Airport', 'Community': 8629}, {'Name': 'Adelaide International Airport', 'Community': 8629}, {'Name': 'Aden Adde International Airport', 'Community': 8629}, {'Name': 'Aden International Airport', 'Community': 8629}, {'Name': 'Adi Sumarmo Wiryokusumo Airport', 'Community': 8629}, {'Name': 'Adi Sutjipto International Airport', 'Community': 8629}, {'Name': 'Adirondack Regional Airport', 'Community': 8629}, {'Name': 'Adnan Menderes International Airport', 'Community': 8629}]

# %%
cv=[]
for x in r:
    if x.get("Community") not in cv:
        print(x.get("Community"), x.get("Name"))
        cv.append(x.get("Community"))
# Out:
# 8629 A Coruna Airport
# 8634 Atmautluak Airport
# 8826 Berlin, Tegel International Airport *Closed*
# 9099 Berlin-Schönefeld International Airport *Closed*
# 9568 New Castle Airport
# 9634 Toowoomba Airport
# 10850 Tikehau Airport
# 10851 Fakarava Airport
# 10852 Manihi Airport
# 10853 Arutua Airport
# 10854 Mataiva Airport
# 10855 Ahe Airport
# 10856 Aratika Nord Airport
# 10857 Takaroa Airport
# 10858 Nuku Hiva Airport
# 10859 Hiva Oa-Atuona Airport
# 10860 Bora Bora Airport
# 10861 Rangiroa Airport
# 10862 Huahine-Fare Airport
# 10863 Moorea Airport
# 10864 Hao Airport
# 10865 Maupiti Airport
# 10866 Raiatea Airport
# 10867 Sola Airport
# 10868 Siwo Airport
# 10869 Craig Cove Airport
# 10870 Longana Airport
# 10871 Sara Airport
# 10872 Tavie Airport
# 10873 Lamap Airport
# 10874 Lamen Bay Airport
# 10875 Maewo-Naone Airport
# 10876 Lonorore Airport
# 10877 Norsup Airport
# 10878 Gaua Island Airport
# 10879 Tongoa Airport
# 10880 Valesdir Airport
# 10881 Walaha Airport
# 10882 Southwest Bay Airport
# 10883 Dillon's Bay Airport
# 10884 Ipota Airport
# 10885 Tanna Airport
# 10886 Korla Airport
# 10887 Mazar I Sharif Airport
# 10888 Al Ahsa Airport
# 10889 Al Baha Airport
# 10890 Bisha Airport
# 10891 Dawadmi Domestic Airport
# 10892 Jizan Regional Airport
# 10893 Guriat Domestic Airport
# 10894 Nejran Airport
# 10895 Qaisumah Domestic Airport
# 10896 Rafha Domestic Airport
# 10897 Arar Domestic Airport
# 10898 Sharurah Airport
# 10899 Al-Jawf Domestic Airport
# 10900 Turaif Domestic Airport
# 10901 Wadi al-Dawasir Airport
# 10902 Al Wajh Domestic Airport
# 10903 Yushu Batang Airport
# 10904 Abadan Airport
# 10905 Mahshahr Airport
# 10906 Sirri Island Airport
# 10907 Shahid Ashrafi Esfahani Airport
# 10908 Sardar-e-Jangal Airport
# 10909 Hamadan Airport
# 10910 Mehrabad International Airport
# 10911 Kerman Airport
# 10912 Birjand Airport
# 10913 Gorgan Airport
# 10914 Now Shahr Airport
# 10915 Ramsar Airport
# 10916 Dasht-e Naz Airport
# 10917 Ardabil Airport
# 10918 Urmia Airport
# 10919 Shahid Sadooghi Airport
# 10920 Zabol Airport
# 10921 Aqaba King Hussein International Airport
# 10922 Al Ain International Airport
# 10923 Fujairah International Airport
# 10924 Khasab Air Base
# 10925 Bahawalpur Airport
# 10926 Chitral Airport
# 10927 Dera Ghazi Khan Airport
# 10928 Dera Ismael Khan Airport
# 10929 Faisalabad International Airport
# 10930 Gwadar International Airport
# 10931 Gilgit Airport
# 10932 Moenjodaro Airport
# 10933 Panjgur Airport
# 10934 Quetta International Airport
# 10935 Shaikh Zaid Airport
# 10936 Skardu Airport
# 10937 Sukkur Airport
# 10938 Turbat International Airport
# 10939 Port Lions Airport
# 10940 Ataq Airport
# 10941 Al Ghaidah International Airport
# 10942 Hodeidah International Airport
# 10943 Socotra International Airport
# 10944 Sayun International Airport
# 10945 Ta'izz International Airport
# 10946 Barter Island LRRS Airport
# 10947 Buckland Airport
# 10948 Bettles Airport
# 10949 Central Airport
# 10950 Chalkyitsik Airport
# 10951 Chefornak Airport
# 10952 Deering Airport
# 10953 Marshall Don Hunter Sr Airport
# 10954 Kongiganak Airport
# 10955 Eek Airport
# 10956 Emmonak Airport
# 10957 Ambler Airport
# 10958 Edward G. Pitka Sr Airport
# 10959 Golovin Airport
# 10960 Gambell Airport
# 10961 Gustavus Airport
# 10962 Skagway Airport
# 10963 Holy Cross Airport
# 10964 Haines Airport
# 10965 Hooper Bay Airport
# 10966 Shageluk Airport
# 10967 Bob Baker Memorial Airport
# 10968 Wales Airport
# 10969 False Pass Airport
# 10970 Akhiok Airport
# 10971 Kipnuk Airport
# 10972 Koyuk Alfred Adams Airport
# 10973 Anaktuvuk Pass Airport
# 10974 Klawock Airport
# 10975 Larsen Bay Airport
# 10976 Kalskag Airport
# 10977 St Michael Airport
# 10978 Manley Hot Springs Airport
# 10979 Mountain Village Airport
# 10980 Napakiak Airport
# 10981 Hoonah Airport
# 10982 Toksook Bay Airport
# 10983 Petersburg James A Johnson Airport
# 10984 Pilot Point Airport
# 10985 Point Hope Airport
# 10986 Quinhagak Airport
# 10987 Nuiqsut Airport
# 10988 Ruby Airport
# 10989 Savoonga Airport
# 10990 Shishmaref Airport
# 10991 Sitka Rocky Gutierrez Airport
# 10992 Selawik Airport
# 10993 Ralph M Calhoun Memorial Airport
# 10994 Tin City Long Range Radar Station Airport
# 10995 Teller Airport
# 10996 Atqasuk Edward Burnell Sr Memorial Airport
# 10997 Chevak Airport
# 10998 King Cove Airport
# 10999 Kivalina Airport
# 11000 Beaver Airport
# 11001 Wrangell Airport
# 11002 Wainwright Airport
# 11003 White Mountain Airport
# 11004 Noatak Airport
# 11005 Yakutat Airport
# 11006 Allakaket Airport
# 11007 Elim Airport
# 11008 Kasigluk Airport
# 11009 Kotlik Airport
# 11010 Brevig Mission Airport
# 11011 Kwethluk Airport
# 11012 Robert (Bob) Curtis Memorial Airport
# 11013 Shaktoolik Airport
# 11014 South Naknek Nr 2 Airport
# 11015 Fort Yukon Airport
# 11016 Tufi Airport
# 11017 Rota International Airport
# 11018 Chaoyang Airport
# 11019 Hana Airport
# 11020 Waimea Kohala Airport
# 11021 Bucholz Army Air Field
# 11022 Point Lay LRRS Airport
# 11023 Chuuk International Airport
# 11024 Yap International Airport
# 11025 Kinmen Airport
# 11026 Taitung Airport
# 11027 Makung Airport
# 11028 Hualien Airport
# 11029 Matsumoto Airport
# 11030 Hyakuri Airport
# 11031 Iki Airport
# 11032 Tsushima Airport
# 11033 Fukue Airport
# 11034 Nagoya Airport
# 11035 Mt. Fuji Shizuoka Airport
# 11036 Fukushima Airport
# 11037 Hanamaki Airport
# 11038 Gwangju Airport
# 11039 Kunsan Air Base
# 11040 Yeosu Airport
# 11041 Wonju Airport
# 11042 Yangyang International Airport
# 11043 Sacheon Air Base
# 11044 Ulsan Airport
# 11045 Pohang Airport
# 11046 Rampart Airport
# 11047 Kumejima Airport
# 11048 Laoag International Airport
# 11049 Legazpi City International Airport
# 11050 Awang Airport
# 11051 Bancasi Airport
# 11052 Dipolog Airport
# 11053 Camiguin Airport
# 11054 Cagayan De Oro Airport
# 11055 Labo Airport
# 11056 Pagadian Airport
# 11057 General Santos International Airport
# 11058 Surigao Airport
# 11059 Zamboanga International Airport
# 11060 Siargao Airport
# 11061 San Jose Airport
# 11062 Naga Airport
# 11063 Basco Airport
# 11064 Tuguegarao Airport
# 11065 Virac Airport
# 11066 Cauayan Airport
# 11067 Daniel Z. Romualdez Airport
# 11068 Bacolod-Silay City International Airport
# 11069 Calbayog Airport
# 11070 Sibulan Airport
# 11071 Malay, Godofredo P. Ramos Airport
# 11072 Catarman National Airport
# 11073 Moises R. Espinosa Airport
# 11074 Puerto Princesa Airport
# 11075 Roxas Airport
# 11076 Tagbilaran Airport
# 11077 Francisco B. Reyes Airport
# 11078 Nogliki Airport
# 11079 Grozny North Airport
# 11080 Velikiy Ustyug Airport
# 11081 General Urquiza Airport
# 11082 Sauce Viejo Airport
# 11083 Suboficial Ay Santiago Germano Airport
# 11084 Catamarca Airport
# 11085 Vicecomodoro Angel D. La Paz Aragonés Airport
# 11086 Las Termas Airport
# 11087 Capitan V A Almonacid Airport
# 11088 Teniente Benjamin Matienzo Airport
# 11089 Domingo Faustino Sarmiento Airport
# 11090 Brigadier Mayor D Cesar Raul Ojeda Airport
# 11091 Resistencia International Airport
# 11092 Formosa Airport
# 11093 Libertador Gral D Jose De San Martin Airport
# 11094 Martin Miguel De Guemes International Airport
# 11095 Gobernador Horacio Guzman International Airport
# 11096 General E. Mosconi Airport
# 11097 Brigadier Antonio Parodi Airport
# 11098 Gobernador Castello Airport
# 11099 El Tehuelche Airport
# 11100 Hermes Quijada International Airport
# 11101 Piloto Civil N. Fernández Airport
# 11102 Comandante Espora Airport
# 11103 Ástor Piazzola International Airport
# 11104 Presidente Peron Airport
# 11105 Santa Rosa Airport
# 11106 Aviador C. Campos Airport
# 11107 Araraquara Airport
# 11108 Alta Floresta Airport
# 11109 Araxá Airport
# 11110 Atlas Brasil Cantanhede Airport
# 11111 Cabo Frio Airport
# 11112 Caçador Airport
# 11113 Chapecó Airport
# 11114 Carajás Airport
# 11115 Diomício Freitas Airport
# 11116 Caldas Novas Airport
# 11117 Bartolomeu Lisandro Airport
# 11118 Corumbá International Airport
# 11119 Hugo Cantergiani Regional Airport
# 11120 Bonito Airport
# 11121 Presidente Prudente Airport
# 11122 Fernando de Noronha Airport
# 11123 Tancredo Thomas de Faria Airport
# 11124 Governador Valadares Airport
# 11125 Altamira Airport
# 11126 Prefeito Renato Moreira Airport
# 11127 Presidente João Suassuna Airport
# 11128 Chapada Diamantina Airport
# 11129 Bom Jesus da Lapa Airport
# 11130 João Correa da Rocha Airport
# 11131 Monte Dourado Airport
# 11132 Macaé Airport
# 11133 Mário Ribeiro Airport
# 11134 Marília Airport
# 11135 Alberto Alcolumbre Airport
# 11136 Prefeito Doutor João Silva Filho Airport
# 11137 Brigadeiro Lysias Rodrigues Airport
# 11138 Pelotas Airport
# 11139 Senador Nilo Coelho Airport
# 11140 Governador Jorge Teixeira de Oliveira Airport
# 11141 Plácido de Castro Airport
# 11142 Professor Urbano Ernesto Stumpf Airport
# 11143 Santa Maria Airport
# 11144 Maestro Wilson Fonseca Airport
# 11145 Tefé Airport
# 11146 Tabatinga Airport
# 11147 Paulo Afonso Airport
# 11148 Vilhena Airport
# 11149 Zona da Mata Regional Airport
# 11150 Mocopulli Airport
# 11151 Anshan Air Base
# 11152 Francisco De Orellana Airport
# 11153 Mariscal Lamar Airport
# 11154 Seymour Airport
# 11155 Cotopaxi International Airport
# 11156 Coronel E Carvajal Airport
# 11157 Eloy Alfaro International Airport
# 11158 Nueva Loja Airport
# 11159 Coronel Artilleria Victor Larrea Airport
# 11160 San Cristóbal Airport
# 11161 Camilo Ponce Enriquez Airport
# 11162 General Rivadeneira Airport
# 11163 Teniente Coronel Luis a Mantilla Airport
# 11164 Bauru - Arealva Airport
# 11165 Tres De Mayo Airport
# 11166 Palonegro Airport
# 11167 Gerardo Tobar López Airport
# 11168 Camilo Daza International Airport
# 11169 La Florida Airport
# 11170 Las Brujas Airport
# 11171 Yariguíes Airport
# 11172 Gustavo Artunduaga Paredes Airport
# 11173 Juan Casiano Airport
# 11174 Perales Airport
# 11175 San Luis Airport
# 11176 Antonio Roldan Betancourt Airport
# 11177 Alfredo Vásquez Cobo International Airport
# 11178 Enrique Olaya Herrera Airport
# 11179 Los Garzones Airport
# 11180 Fabio Alberto Leon Bentley Airport
# 11181 La Nubia Airport
# 11182 Benito Salas Airport
# 11183 German Olano Airport
# 11184 Obando Airport
# 11185 Matecaña International Airport
# 11186 Guillermo León Valencia Airport
# 11187 Antonio Narino Airport
# 11188 Almirante Padilla Airport
# 11189 Jorge E. Gonzalez Torres Airport
# 11190 Simón Bolívar International Airport
# 11191 Gustavo Rojas Pinilla International Airport
# 11192 Eduardo Falla Solano Airport
# 11193 Gustavo Vargas Airport
# 11194 Santiago Perez Airport
# 11195 El Caraño Airport
# 11196 Alfonso López Pumarejo Airport
# 11197 Vanguardia Airport
# 11198 El Yopal Airport
# 11199 Capitán Aníbal Arab Airport
# 11200 El Trompillo Airport
# 11201 Capitan Nicolas Rojas Airport
# 11202 Juana Azurduy De Padilla Airport
# 11203 Capitan Oriel Lea Plaza Airport
# 11204 Teniente Av. Jorge Henrich Arauz Airport
# 11205 Uyuni Airport
# 11206 Barreiras Airport
# 11207 Patos de Minas Airport
# 11208 Breves Airport
# 11209 Erechim Airport
# 11210 Santa Terezinha Airport
# 11211 Cacoal Airport
# 11212 Santa Rosa Airport
# 11213 Capitan Corbeta CA Curbelo International Airport
# 11214 Barinas Airport
# 11215 Barquisimeto International Airport
# 11216 José Leonardo Chirinos Airport
# 11217 Cumaná (Antonio José de Sucre) Airport
# 11218 Josefa Camejo International Airport
# 11219 La Fria Airport
# 11220 Alberto Carnevalli Airport
# 11221 Del Caribe Santiago Mariño International Airport
# 11222 Maturín Airport
# 11223 Oro Negro Airport
# 11224 Cacique Aramare Airport
# 11225 General Bartolome Salom International Airport
# 11226 General Manuel Carlos Piar International Airport
# 11227 Stevens Village Airport
# 11228 Juan Vicente Gomez International Airport
# 11229 Mayor Buenaventura Vivas International Airport
# 11230 San Tome Airport
# 11231 Arturo Michelena International Airport
# 11232 Juan Pablo Pérez Alfonso Airport
# 11233 Dr. Antonio Nicolás Briceño Airport
# 11234 Barcelos Airport
# 11235 Araguaína Airport
# 11236 Ji-Paraná Airport
# 11237 Coari Airport
# 11238 General Leite de Castro Airport
# 11239 Parintins Airport
# 11240 Rondonópolis Airport
# 11241 Presidente João Batista Figueiredo Airport
# 11242 Sheldon Point Airport
# 11243 Ogle Airport
# 11244 Takotna Airport
# 11245 L'Espérance Airport
# 11246 George F. L. Charles Airport
# 11247 Tuluksak Airport
# 11248 F. D. Roosevelt Airport
# 11249 Juancho E. Yrausquin Airport
# 11250 Bingöl Çeltiksuyu Airport
# 11251 Iğdır Airport
# 11252 E. T. Joshua Airport
# 11253 Kokshetau Airport
# 11254 Petropavlosk South Airport
# 11255 Taraz Airport
# 11256 Osh Airport
# 11257 Shymkent Airport
# 11258 Jinzhou Airport
# 11259 Sary-Arka Airport
# 11260 Kzyl-Orda Southwest Airport
# 11261 Uralsk Airport
# 11262 Ust-Kamennogorsk Airport
# 11263 Pavlodar Airport
# 11264 Aktau Airport
# 11265 Aktobe Airport
# 11266 Kostanay West Airport
# 11267 Ganja Airport
# 11268 Lankaran International Airport
# 11269 Nakhchivan Airport
# 11270 Gabala International Airport
# 11271 Gyumri Shirak Airport
# 11272 Lensk Airport
# 11273 Polyarny Airport
# 11274 Mirny Airport
# 11275 Chokurdakh Airport
# 11276 Cherskiy Airport
# 11277 Tiksi Airport
# 11278 Kopitnari Airport
# 11279 Batumi International Airport
# 11280 Ignatyevo Airport
# 11281 Ugolny Airport
# 11282 Sokol Airport
# 11283 Pevek Airport
# 11284 Yelizovo Airport
# 11285 Burevestnik Airport
# 11286 Okha Airport
# 11287 Shakhtyorsk Airport
# 11288 Mendeleyevo Airport
# 11289 Chita-Kadala Airport
# 11290 Bratsk Airport
# 11291 Bodaybo Airport
# 11292 Kirensk Airport
# 11293 Ust-Kut Airport
# 11294 Zaporizhzhia International Airport
# 11295 Belbek Airport
# 11296 Simferopol International Airport
# 11297 Ivano-Frankivsk International Airport
# 11298 Uzhhorod International Airport
# 11299 Vinnytsia/Gavyryshivka Airport
# 11300 Talagi Airport
# 11301 Majeed Bin Abdulaziz Airport
# 11302 Kirovsk-Apatity Airport
# 11303 Murmansk Airport
# 11304 Petrozavodsk Airport
# 11305 Khrabrovo Airport
# 11306 Abakan Airport
# 11307 Barnaul Airport
# 11308 Gorno-Altaysk Airport
# 11309 Kemerovo Airport
# 11310 Kyzyl Airport
# 11311 Omsk Central Airport
# 11312 Bogashevo Airport
# 11313 Spichenkovo Airport
# 11314 Igarka Airport
# 11315 Norilsk-Alykel Airport
# 11316 Turukhansk Airport
# 11317 Anapa Airport
# 11318 Gelendzhik Airport
# 11319 Uytash Airport
# 11320 Beslan Airport
# 11321 Stavropol Shpakovskoye Airport
# 11322 Taganrog Yuzhny Airport
# 11323 Sochi International Airport
# 11324 Astrakhan Airport
# 11325 Elista Airport
# 11326 Magnitogorsk International Airport
# 11327 Salekhard Airport
# 11328 Khanty Mansiysk Airport
# 11329 Nyagan Airport
# 11330 Sovetskiy Airport
# 11331 Uray Airport
# 11332 Beloyarskiy Airport
# 11333 Izhevsk Airport
# 11334 Pobedilovo Airport
# 11335 Nadym Airport
# 11336 Novy Urengoy Airport
# 11337 Nizhnevartovsk Airport
# 11338 Kogalym International Airport
# 11339 Noyabrsk Airport
# 11340 Surgut Airport
# 11341 Roshchino International Airport
# 11342 Kurgan Airport
# 11343 Kulob Airport
# 11344 Khudzhand Airport
# 11345 Qurghonteppa International Airport
# 11346 Andizhan Airport
# 11347 Fergana International Airport
# 11348 Namangan Airport
# 11349 Nukus Airport
# 11350 Navoi Airport
# 11351 Bukhara Airport
# 11352 Karshi Khanabad Airport
# 11353 Samarkand Airport
# 11354 Termez Airport
# 11355 Tunoshna Airport
# 11356 Belgorod International Airport
# 11357 Kursk East Airport
# 11358 Donskoye Airport
# 11359 Ukhta Airport
# 11360 Vorkuta Airport
# 11361 Syktyvkar Airport
# 11362 Bugulma Airport
# 11363 Kazan International Airport
# 11364 Begishevo Airport
# 11365 Cheboksary Airport
# 11366 Ulyanovsk Baratayevka Airport
# 11367 Orenburg Central Airport
# 11368 Orsk Airport
# 11369 Penza Airport
# 11370 Saransk Airport
# 11371 Yining Airport
# 11372 Belgaum Airport
# 11373 Koggala Airport
# 11374 Sigiriya Air Force Base
# 11375 Mattala Rajapaksa International Airport
# 11376 Sihanoukville International Airport
# 11377 Agartala Airport
# 11378 Shillong Airport
# 11379 Imphal Airport
# 11380 Silchar Airport
# 11381 Lengpui Airport
# 11382 Dimapur Airport
# 11383 Barisal Airport
# 11384 Cox's Bazar Airport
# 11385 Jessore Airport
# 11386 Saidpur Airport
# 11387 Ban Huoeisay Airport
# 11388 Luang Phabang International Airport
# 11389 Luang Namtha Airport
# 11390 Oudomsay Airport
# 11391 Pakse International Airport
# 11392 Savannakhet Airport
# 11393 Xieng Khouang Airport
# 11394 Dong Hoi Airport
# 11395 Bharatpur Airport
# 11396 Bhairahawa Airport
# 11397 Bhadrapur Airport
# 11398 Dhangarhi Airport
# 11399 Janakpur Airport
# 11400 Nepalgunj Airport
# 11401 Pokhara Airport
# 11402 Tumling Tar Airport
# 11403 Biratnagar Airport
# 11404 Agatti Airport
# 11405 Vijayawada Airport
# 11406 Madurai Airport
# 11407 Mysore Airport
# 11408 Vir Savarkar International Airport
# 11409 Rajahmundry Airport
# 11410 Tirupati Airport
# 11411 Paro Airport
# 11412 Fuvahmulah Airport
# 11413 Gan International Airport
# 11414 Hanimaadhoo Airport
# 11415 Kadhdhoo Airport
# 11416 Kooddoo Airport
# 11417 Kaadedhdhoo Airport
# 11418 Trat Airport
# 11419 U-Tapao International Airport
# 11420 Mae Hong Son Airport
# 11421 Pai Airport
# 11422 Lampang Airport
# 11423 Nan Airport
# 11424 Phrae Airport
# 11425 Chiang Rai International Airport
# 11426 Mae Sot Airport
# 11427 Sukhothai Airport
# 11428 Phitsanulok Airport
# 11429 Surat Thani Airport
# 11430 Narathiwat Airport
# 11431 Chumphon Airport
# 11432 Nakhon Si Thammarat Airport
# 11433 Ürümqi Diwopu International Airport
# 11434 Ranong Airport
# 11435 Trang Airport
# 11436 Udon Thani Airport
# 11437 Sakon Nakhon Airport
# 11438 Khon Kaen Airport
# 11439 Loei Airport
# 11440 Buri Ram Airport
# 11441 Ubon Ratchathani Airport
# 11442 Roi Et Airport
# 11443 Nakhon Phanom Airport
# 11444 Buon Ma Thuot Airport
# 11445 Chu Lai International Airport
# 11446 Cat Bi International Airport
# 11447 Cà Mau Airport
# 11448 Cam Ranh Airport
# 11449 Co Ong Airport
# 11450 Can Tho International Airport
# 11451 Dien Bien Phu Airport
# 11452 Lien Khuong Airport
# 11453 Phu Bai Airport
# 11454 Phu Cat Airport
# 11455 Pleiku Airport
# 11456 Phu Quoc Airport
# 11457 Rach Gia Airport
# 11458 Dong Tac Airport
# 11459 Vinh Airport
# 11460 Bagan Airport
# 11461 Dawei Airport
# 11462 Naypyidaw Airport
# 11463 Heho Airport
# 11464 Kyaukpyu Airport
# 11465 Mandalay International Airport
# 11466 Myitkyina Airport
# 11467 Sittwe Airport
# 11468 Thandwe Airport
# 11469 Tachileik Airport
# 11470 Tampa Padang Airport
# 11471 Frans Kaisiepo Airport
# 11472 Moses Kilangin Airport
# 11473 Muhammad Salahuddin Airport
# 11474 Tambolaka Airport
# 11475 Waingapu Airport
# 11476 Sentani Airport
# 11477 Barau(Kalimaru) Airport
# 11478 Juwata Airport
# 11479 Jalaluddin Airport
# 11480 Naha Airport
# 11481 Kao Airport
# 11482 Mutiara Airport
# 11483 Melangguane Airport
# 11484 Kasiguncu Airport
# 11485 Sultan Khairun Babullah Airport
# 11486 Bubung Airport
# 11487 Iskandar Airport
# 11488 Stagen Airport
# 11489 Syamsudin Noor Airport
# 11490 Tjilik Riwut Airport
# 11491 Pattimura Airport, Ambon
# 11492 Abdul Rachman Saleh Airport
# 11493 Rendani Airport
# 11494 Sorong (Jefman) Airport
# 11495 Maumere(Wai Oti) Airport
# 11496 Komodo (Mutiara II) Airport
# 11497 El Tari Airport
# 11498 Betoambari Airport
# 11499 Wolter Monginsidi Airport
# 11500 Stebbins Airport
# 11501 Bintulu Airport
# 11502 Long Lellang Airport
# 11503 Long Seridan Airport
# 11504 Limbang Airport
# 11505 Mukah Airport
# 11506 Long Akah Airport
# 11507 Marudi Airport
# 11508 Sibu Airport
# 11509 Tanjung Manis Airport
# 11510 Lawas Airport
# 11511 Bario Airport
# 11512 Lahad Datu Airport
# 11513 Labuan Airport
# 11514 Sandakan Airport
# 11515 Kudat Airport
# 11516 Tawau Airport
# 11517 Mulu Airport
# 11518 Radin Inten II (Branti) Airport
# 11519 Hang Nadim International Airport
# 11520 Raja Haji Fisabilillah International Airport
# 11521 Kashgar Airport
# 11522 Buluh Tumbang (H A S Hanandjoeddin) Airport
# 11523 Supadio Airport
# 11524 Sultan Thaha Airport
# 11525 Pangkal Pinang (Depati Amir) Airport
# 11526 Padang Kemiling (Fatmawati Soekarno) Airport
# 11527 Minangkabau Airport
# 11528 Sultan Iskandar Muda International Airport
# 11529 Sultan Abdul Halim Airport
# 11530 Kerteh Airport
# 11531 Senai International Airport
# 11532 Aurukun Airport
# 11533 Bamaga Injinoo Airport
# 11534 Boulia Airport
# 11535 Weipa Airport
# 11536 Coober Pedy Airport
# 11537 Ceduna Airport
# 11538 Coen Airport
# 11539 Doomadgee Airport
# 11540 Flinders Island Airport
# 11541 Grafton Airport
# 11542 Groote Eylandt Airport
# 11543 Horn Island Airport
# 11544 Julia Creek Airport
# 11545 Kowanyama Airport
# 11546 Kingscote Airport
# 11547 Lockhart River Airport
# 11548 Maningrida Airport
# 11549 McArthur River Mine Airport
# 11550 Normanton Airport
# 11551 Olympic Dam Airport
# 11552 Port Augusta Airport
# 11553 Cocos (Keeling) Islands Airport
# 11554 Gove Airport
# 11555 Port Lincoln Airport
# 11556 Pormpuraaw Airport
# 11557 Quilpie Airport
# 11558 St George Airport
# 11559 Whyalla Airport
# 11560 Birch Creek Airport
# 11561 Handan Airport
# 11562 Shanhaiguan Airport
# 11563 Shijiazhuang Daguocun International Airport
# 11564 Zhijiang Airport
# 11565 Lingling Airport
# 11566 Changzhoudao Airport
# 11567 Enshi Airport
# 11568 Nanyang Airport
# 11569 Dunhuang Airport
# 11570 Golmud Airport
# 11571 Jiayuguan Airport
# 11572 Qingyang Airport
# 11573 Gannan Xiahe Airport
# 11574 Bayankhongor Airport
# 11575 Choibalsan Airport
# 11576 Donoi Airport
# 11577 Dalanzadgad Airport
# 11578 Khovd Airport
# 11579 Mörön Airport
# 11580 Ulaangom Airport
# 11581 Olgii Mongolei Airport
# 11582 Dali Airport
# 11583 Diqing Airport
# 11584 Xishuangbanna Gasa Airport
# 11585 Simao Airport
# 11586 Zhaotong Airport
# 11587 Quzhou Airport
# 11588 Longyan Guanzhishan Airport
# 11589 Ngari Gunsa Airport
# 11590 Anshun Huangguoshu Airport
# 11591 Qamdo Bangda Airport
# 11592 Jiuzhai Huanglong Airport
# 11593 Mianyang Airport
# 11594 Nanchong Airport
# 11595 Liping Airport
# 11596 Nyingchi Airport
# 11597 Tengchong Tuofeng Airport
# 11598 Tongren Fenghuang Airport
# 11599 Wanxian Airport
# 11600 Xichang Qingshan Airport
# 11601 Yibin Caiba Airport
# 11602 Xingyi Airport
# 11603 Zunyi Xinzhou Airport
# 11604 Aksu Airport
# 11605 Hami Airport
# 11606 Semipalatinsk Airport
# 11607 Taizhou Airport
# 11608 Santo Ângelo Airport
# 11609 Tatalina LRRS Airport
# 11610 Igiugig Airport
# 11611 Chuathbaluk Airport
# 11612 Cherif Al Idrissi Airport
# 11613 Red Devil Airport
# 11614 Luderitz Airport
# 11615 Aguenar – Hadj Bey Akhamok Airport
# 11616 Pickle Lake Airport
# 11617 Lansdowne House Airport
# 11618 Kédougou Airport
# 11619 Sleetmute Airport
# 11620 Nunapitchuk Airport
# 11621 Minto Al Wright Airport
# 11622 Circle City /New/ Airport
# 11623 Jumandy Airport
# 11624 Karluk Airport
# 11625 Totegegie Airport
# 11626 Makemo Airport
# 11627 Guanambi Airport
# 11628 Kaukura Airport
# 11629 Ugashik Bay Airport
# 11630 Mekoryuk Airport
# 11631 Tununak Airport
# 11632 Nightmute Airport
# 11633 Goodnews Airport
# 11634 Russian Mission Airport
# 11635 Pilot Station Airport
# 11636 Kauehi Airport
# 11637 Napaskiak Airport
# 11638 Egegik Airport
# 11639 Newtok Airport
# 11640 Port Heiden Airport
# 11641 Katiu Airport
# 11642 Coral Harbour Airport
# 11643 Reykjavik Airport
# 11644 Land's End Airport
# 11645 Northeast Florida Regional Airport
# 11646 Mingyueshan Airport
# 11647 Wenshan Puzhehei Airport
# 11648 Chulman Neryungri Airport
# 11649 Manzhouli Xijiao Airport
# 11650 Bayannur Tianjitai Airport
# 11651 Iwakuni Marine Corps Air Station
# 11652 Tuticorin Southwest Airport
# 11653 Semera Airport
# 11654 Minchumina Airport
# 11655 Zafer Airport
# 11656 Sinop Airport
# 11657 Mosul International Airport
# 11658 Tho Xuan Airport
# 11659 Libo Airport
# 11660 Daocheng Yading Airport
# 11661 Kangding Airport
# 11662 Los Colonizadores Airport
# 11663 Villa Garzón Airport
# 11664 Dharavandhoo Airport
# 11665 Oyo Ollombo International Airport
# 11666 Fort Albany Airport
# 11667 Hotan Airport
# 11668 Wamena Airport
# 11669 Myeik Airport
# 11670 Podkamennaya Tunguska Airport
# 11671 Sakkyryr Airport
# 11672 Ogden Hinckley Airport
# 11673 Jolo Airport
# 11674 Kawthoung Airport
# 11675 Kashechewan Airport
# 11676 Attawapiskat Airport
# 11677 Kulusuk Airport
# 11678 Ísafjörður Airport
# 11679 Egilsstaðir Airport
# 11680 Akureyri Airport
# 11681 Chesterfield Inlet Airport
# 11682 Repulse Bay Airport
# 11683 El Golea Airport
# 11684 Altai Airport
# 11685 Zhangjiakou Ningyuan Airport
# 11686 Cunnamulla Airport
# 11687 Thargomindah Airport
# 11688 Altay Air Base
# 11689 Abu Simbel Airport
# 11690 Araracuara Airport
# 11691 Sabzevar National Airport
# 11692 Akiak Airport
# 11693 Akulivik Airport
# 11694 Angoulême-Brie-Champniers Airport
# 11695 Anvik Airport
# 11696 Amboseli Airport
# 11697 Alakanuk Airport
# 11698 Aneityum Airport
# 11699 Aniwa Airport
# 11700 Bedourie Airport
# 11701 Bojnord Airport
# 11702 Båtsfjord Airport
# 11703 Bakalalan Airport
# 11704 Bukavu Kavumu Airport
# 11705 Bukoba Airport
# 11706 Bordj Badji Mokhtar Airport
# 11707 Alashankou Bole (Bortala) airport
# 11708 José Celestino Mutis Airport
# 11709 Batticaloa Airport
# 11710 Burketown Airport
# 11711 Berlevåg Airport
# 11712 Birdsville Airport
# 11713 Babo Airport
# 11714 Bam Airport
# 11715 Yacuiba Airport
# 11716 Canaima Airport
# 11717 Neerlerit Inaat Airport
# 11718 Solovki Airport
# 11719 Corozal Municipal Airport
# 11720 Cruzeiro do Sul Airport
# 11721 Dezful Airport
# 11722 Elcho Island Airport
# 11723 Ende (H Hasan Aroeboesman) Airport
# 11724 Eirunepé Airport
# 11725 Futuna Airport
# 11726 Pointe Vele Airport
# 11727 Gachsaran Airport
# 11728 Gode Airport
# 11729 La Laguna Airport
# 11730 Capitán de Av. Emilio Beltrán Airport
# 11731 Haifa International Airport
# 11732 Ilam Airport
# 11733 Tapuruquara Airport
# 11734 Itaituba Airport
# 11735 Ilulissat Airport
# 11736 Aasiaat Airport
# 11737 Paamiut Airport
# 11738 Sisimiut Airport
# 11739 Maniitsoq Airport
# 11740 Kaltag Airport
# 11741 Kuqa Airport
# 11742 Khoram Abad Airport
# 11743 Khoy Airport
# 11744 Kingfisher Lake Airport
# 11745 Karamay Airport
# 11746 Kitale Airport
# 11747 Ketapang(Rahadi Usman) Airport
# 11748 Kwigillingok Airport
# 11749 Manda Airstrip
# 11750 Long Banga Airport
# 11751 La Chorrera Airport
# 11752 Lokichoggio Airport
# 11753 La Macarena Airport
# 11754 La Pedrera Airport
# 11755 Caucaya Airport
# 11756 Losuia Airport
# 11757 Milingimbi Airport
# 11758 Mopah Airport
# 11759 Nikolai Airport
# 11760 Gemena Airport
# 11761 Mehamn Airport
# 11762 Tulita Airport
# 11763 Eastmain River Airport
# 11764 Delma Island
# 11765 La Romaine Airport
# 11766 Whale Cove Airport
# 11767 Qikiqtarjuaq Airport
# 11768 Postville Airport
# 11769 Rigolet Airport
# 11770 Quaqtaq Airport
# 11771 Peawanuck Airport
# 11772 Ogoki Post Airport
# 11773 Wemindji Airport
# 11774 Pond Inlet Airport
# 11775 Ivujivik Airport
# 11776 Yiershi Airport
# 11777 Chevery Airport
# 11778 Ulukhaktok Holman Airport
# 11779 Fort Good Hope Airport
# 11780 Wekweètì Airport
# 11781 Inuvik Mike Zubko Airport
# 11782 Yasouj Airport
# 11783 Arviat Airport
# 11784 Nain Airport
# 11785 Lourdes de Blanc Sablon Airport
# 11786 Baker Lake Airport
# 11787 Cat Lake Airport
# 11788 Kasabonika Airport
# 11789 Bearskin Lake Airport
# 11790 Windorah Airport
# 11791 Mananara Nord Airport
# 11792 Venetie Airport
# 11793 Ust-Tsylma Airport
# 11794 Usinsk Airport
# 11795 Rubem Berta Airport
# 11796 Ukunda Airstrip
# 11797 Samburu South Airport
# 11798 Ua Pou Airport
# 11799 Narsarsuaq Airport
# 11800 Ua Huka Airport
# 11801 China Bay Airport
# 11802 Tarko-Sale Airport
# 11803 Torres Airstrip
# 11804 Togiak Airport
# 11805 Trombetas Airport
# 11806 Takapoto Airport
# 11807 Tacheng Airport
# 11808 Santa Elena de Uairen Airport
# 11809 Salt Cay Airport
# 11810 São Gabriel da Cachoeira Airport
# 11811 Richmond Airport
# 11812 Zhob Airport
# 11813 El Embrujo Airport
# 11814 Punta Gorda Airport
# 11815 Persian Gulf International Airport
# 11816 Parsabade Moghan Airport
# 11817 Putao Airport
# 11818 Marcos A. Gelabert International Airport
# 11819 Orange Walk Airport
# 11820 Juan Mendoza Airport
# 11821 Mornington Island Airport
# 11822 Senadora Eunice Micheles Airport
# 11823 Oksibil Airport
# 11824 Ranai Airport
# 11825 Reyes Murillo Airport
# 11826 Naryan Mar Airport
# 11827 Kosrae International Airport
# 11828 Xinyuan Nalati Airport
# 11829 Nelson Lagoon Airport
# 11830 Nabire Airport
# 11831 Mota Lava Airport
# 11832 Muskrat Dam Airport
# 11833 Grayling Airport
# 11834 Kake Airport
# 11835 Upernavik Airport
# 11836 Qaarsut Airport
# 11837 Shire Inda Selassie Airport
# 11838 Sde Dov Airport
# 11839 Sanandaj Airport
# 11840 Capitán Av. Selin Zeitun Lopez Airport
# 11841 Tête-à-la-Baleine Airport
# 11842 Sachigo Lake Airport
# 11843 La Tabatière Airport
# 11844 St Augustin Airport
# 11845 Kegaska Airport
# 11846 Arctic Village Airport
# 11847 Fort Mcpherson Airport
# 11848 Salluit Airport
# 11849 Kangiqsujuaq (Wakeham Bay) Airport
# 11850 Tuktoyaktuk Airport
# 11851 Sachs Harbour (David Nasogaluak Jr. Saaryuaq) Airport
# 11852 Paulatuk (Nora Aliqatchialuk Ruben) Airport
# 11853 Natuashish Airport
# 11854 Makkovik Airport
# 11855 Hopedale Airport
# 11856 Big Trout Lake Airport
# 11857 Grise Fiord Airport
# 11858 Resolute Bay Airport
# 11859 Arctic Bay Airport
# 11860 Thule Air Base
# 11861 Qaanaaq Airport
# 11862 Old Harbor Airport
# 11863 Nis Constantine the Great Airport
# 11864 Pohnpei International Airport
# 11865 Zaisan (Zaysan) Airport
# 11866 Tucuruí Airport
# 11867 Wapekeka Airport
# 11868 Fort Severn Airport
# 11869 Sandy Lake Airport
# 11870 Deer Lake Airport
# 11871 Pikangikum Airport
# 11872 Keewaywin Airport
# 11873 Poplar Hill Airport
# 11874 North Spirit Lake Airport
# 11875 Dryden Regional Airport
# 11876 Round Lake (Weagamow Lake) Airport
# 11877 Tan Tan Airport
# 11878 Saumlaki/Olilit Airport
# 11879 Silver Creek Airport
# 11880 Independence Airport, Stann Creek
# 11881 Rio Grande Airport
# 11882 Shungnak Airport
# 11883 Kobuk Airport
# 11884 Scammon Bay Airport
# 11885 Stillwater Regional Airport
# 11886 Medan/Kualanamu International Airport
# 11887 Narrabri Airport
# 11888 Dumatumbun Airport
# 11889 Rar Gwamar Airport
# 11890 Ramenskoye Airport
# 11891 Jaime Gonzalez Airport
# 11892 Castellon De La Plana Airport
# 11893 Łódź Władysław Reymont Airport
# 11894 Halim Perdanakusuma International Airport
# 11895 Bacău Airport
# 11896 Camp Nifty Airport
# 11897 Smith Reynolds Airport
# 11898 Centennial Airport
# 11899 Concord Regional Airport
# 11900 Damascus International Airport
# 11901 Nalchik Airport
# 11902 Olsztyn-Mazury Airport
# 11903 Ovda International Airport
# 11904 Brisbane West Wellcamp Airport
# 11905 Panama Pacific International Airport
# 11906 Ormoc Airport
# 11907 Sydney Bankstown Airport
# 11908 Vero Beach Municipal Airport
# 11909 Friedman Memorial Airport
# 11910 Block Island State Airport
# 11911 Devils Lake Regional Airport
# 11912 Jamestown Regional Airport
# 11913 Hays Regional Airport
# 11914 Mason City Municipal Airport
# 11915 Leeward Point Field
# 11916 San Felipe International Airport
# 11917 Shikezi Huayuan Airport
# 11918 Qinhuangdao Beidaihe Airport
# 11919 Fuyuan Dongji Airport
# 11920 Teniente Julio Gallardo Airport
# 11921 Luliang Airport
# 11922 Weihai Airport
# 11923 Shiyan Wudangshan Airport
# 11924 Ulanqab Airport
# 11925 Tonghua Sanyuanpu Airport
# 11926 Turpan Jiaohe Airport
# 11927 Tianshui Maijishan Airport
# 11928 Sanming Shaxian Airport
# 11929 Shigatse Peace Airport
# 11930 Rizhao Shanzihe Airport
# 11931 Liupanshui Yuezhao Airport
# 11932 Clovis Municipal Airport
# 11933 Coventry Airport
# 11934 Samsun Çarşamba Airport
# 11935 Chernobayevka Airport
# 11936 Sirnak Airport
# 11937 Hakkari Selahaddin Eyyubi Airport
# 11938 Ordu Giresun Airport
# 11939 Fort Worth Alliance Airport
# 11940 Gogebic Iron County Airport
# 11941 Linfen Qiaoli Airport
# 11942 Kanas Airport
# 11943 Melbourne Essendon Airport
# 11944 Enontekio Airport
# 11945 Warrnambool Airport
# 11946 Portland Airport
# 11947 Chambéry-Savoie Airport
# 11948 Sierra Maestra Airport
# 11949 Telluride Regional Airport
# 11950 Lipetsk Airport
# 11951 Ulyanovsk East Airport
# 11952 Fort Dodge Regional Airport
# 11953 Huizhou Airport
# 11954 Hanzhong Airport
# 11955 Hengyang Airport
# 11956 Yingkou Lanqi Airport
# 11957 Mount Pleasant Airport
# 11958 Stanley Airport
# 11959 RAF Ascension Island
# 11960 RAF Brize Norton
# 11961 St. Helena Airport
# 11962 Ras Al Khaimah International Airport
# 11963 Kamishly Airport
# 11964 Grenoble Alpes-Isère Airport
# 11965 Fuyun Kroktokay Airport
# 11966 John A. Osborne Airport
# 11967 Thangool Airport
# 11968 Taldykorgan Airport
# 11969 Taroom Airport
# 11970 Chinchilla Airport
# 11971 Trepell Airport
# 11972 Kazi Nazrul Islam Airport
# 11973 Laughlin Bullhead International Airport
# 11974 Komsomolsk-on-Amur Airport
# 11975 Golog Maqin Airport
# 11976 Guyuan Liupanshan Airport
# 11977 Shennongjia Hongping Airport
# 11978 Huatugou Airport
# 11979 Hechi Jin Cheng Jiang Airport
# 11980 Suceava Stefan cel Mare Airport
# 11981 Vitoria/Foronda Airport
# 11982 Qiemo Yudu Airport
# 11983 Kaili Huangping Airport
# 11984 Delingha Airport
# 11985 Hongyuan Aba  Airport
# 11986 Chernivtsi International Airport
# 11987 Bryansk Airport
# 11988 Urdzhar Airport
# 11989 Ballera Airport
# 11990 Moomba Airport
# 11991 Vitebsk East Airport
# 11992 Marce, Angers - Loire Airport
# 11993 Vallee de Seine Airport
# 11994 Venustiano Carranza International Airport
# 11995 Sohar Airport
# 11996 Shetland Islands, Fair Isle Airport
# 11997 Tingwall Airport
# 11998 Foula Airport
# 11999 Papa Stour Airport
# 12000 Nordholz-Spieka
# 12001 Illawarra Regional Airport
# 12002 Ondangwa Airport
# 12003 Gaya Airport
# 12004 El Nido Airport
# 12005 Magas Airport
# 12006 El Palomar Airport
# 12007 Charlottetown Airport
# 12008 Maribor Airport
# 12009 Grabtsevo Airport
# 12010 Jask Airport
# 12011 Cascais Airport
# 12012 Vila Real Airport
# 12013 Viseu Airport
# 12014 Portimao Airport
# 12015 Braganca Airport
# 12016 Corrientes Airport
# 12017 Long Beach Airport
# 12018 Ohrid St. Paul the Apostle Airport
# 12019 Malacca Airport
# 12020 Châteauroux-Déols Marcel Dassault Airport
# 12021 Talakan Airport
# 12022 Grosseto Airport
# 12023 Hua Hin Airport
# 12024 Gomel Airport
# 12025 Crotone-Sant'Anna Airport
# 12026 Nikolayevsk-na-Amure Airport
# 12027 Murray Field
# 12028 Carnarvon Airport
# 12029 Shark Bay Airport
# 12030 Robe Airport
# 12031 Awassa Airport
# 12032 Jorhat Airport
# 12033 Bouaké Airport
# 12034 Silangit Airport
# 12035 Kigoma Airport
# 12036 Abeche Airport
# 12037 Sarh Airport
# 12038 Blaise Diagne International Airport
# 12039 Moundou Airport
# 12040 Faya-Largeau Airport
# 12041 Moulay Ali Cherif Airport
# 12042 Del Rio International Airport
# 12043 Bo'ao Airport
# 12044 Usharal Airport
# 12045 Capitan Montes Airport
# 12046 Kannurl International Airport
# 12047 Shumba Airport
# 12048 In Guezzam Airport
# 12049 Kalabo Airport
# 12050 Van Don International Airport
# 12051 Region of Murcia International Airport
# 12052 Snohomish County (Paine Field) Airport
# 12053 Tenzing-Hillary Airport
# 12054 Gasan Airport
# 12055 Shimojishima Airport
# 12056 Bendigo Airport
# 12057 Bouarfa Airport
# 12058 Tarama Airport
# 12059 Ataturk International Airport
# 12060 Uşak Airport
# 12061 Mitiga Airport
# 12062 Siirt Airport
# 12063 Seletar Airport
# 12064 Tureia Airport
# 12065 Mobile Downtown Airport
# 12066 Nukutavake Airport
# 12067 Al Alamein International Airport
# 12068 Garowe International Airport
# 12069 Kertajati International Airport
# 12070 Tamuin National Airport
# 12071 Beijing Daxing International Airport
# 12072 Bazhong Enyang Airport
# 12073 Chang'an
# 12074 Ramon International Airport
# 12075 Kengtung Airport
# 12076 Fortescue - Dave Forrest Aerodrome
# 12077 Kanti Airport
# 12078 Tindal Airport
# 12079 Nacala Airport
# 12080 Shangrao Sanqingshan Airport
# 12081 Barra do Garças Airport
# 12082 Canarana Airport
# 12083 Dodoma Airport
# 12084 Seronera Airport
# 12085 Jose Aponte de la Torre Airport
# 12086 Cheng Xian Airport
# 12087 Xinyang Minggang Airport
# 12088 Sanhe Airport
# 12089 Batagay Airport
# 12090 Deputatskij Airport
# 12091 Akure Airport
# 12092 Apataki Airport
# 12093 Barrow Island Airport
# 12094 Chelinda Malawi Airport
# 12095 Club Makokola Airport
# 12096 Santa Ana Airport
# 12097 Kaufana Airport
# 12098 Magan Airport
# 12099 Gruyere Airport
# 12100 Hornafjordur Airport
# 12101 Lifuka Island Airport
# 12102 Husavik Airport
# 12103 Likoma Island Airport
# 12104 Los Roques Airport
# 12105 Escuela Mariscal Sucre Airport
# 12106 Mata'aho Airport
# 12107 San Fernando De Apure Airport
# 12108 Ust-Maya Airport
# 12109 Vava'u International Airport
# 12110 Southern California Logistics Airport
# 12111 Mvuu Camp Airport
# 12112 Wa Airport
# 12113 Williston Basin International Airport
# 12114 Bursa Yenişehir Airport
# 12115 Mzuzu Airport
# 12116 Yogyakarta International Airport
# 12117 Nulato Airport
# 12118 Kalay Airport
# 12119 Khost Airport
# 12120 Saskylakh Airport
# 12121 Anaa Airport
# 12122 Kalaburagi International Airport
# 12123 Morava Airport
# 12124 Faaite Airport
# 12125 Raroia Airport
# 12126 Puka Puka Airport
# 12127 Napuka Island Airport
# 12128 Fangatau Airport
# 12129 Berlin Brandenburg International Airport

# %%
r = graph.query("""Call gds.graph.drop("LP")""")
print(r)
# Out:
# [{'graphName': 'LP', 'database': 'neo4j', 'databaseLocation': 'local', 'memoryUsage': '', 'sizeInBytes': -1, 'nodeCount': 3503, 'relationshipCount': 46389, 'configuration': {'relationshipProjection': {'HAS_ROUTE_WEIGHT': {'aggregation': 'DEFAULT', 'orientation': 'NATURAL', 'indexInverse': False, 'properties': {'weight': {'aggregation': 'DEFAULT', 'property': 'weight', 'defaultValue': None}}, 'type': 'HAS_ROUTE_WEIGHT'}}, 'readConcurrency': 4, 'relationshipProperties': {}, 'nodeProperties': {}, 'jobId': 'e83a75fa-a950-4dc0-ac89-2b4fb8153eb2', 'nodeProjection': {'Airport': {'label': 'Airport', 'properties': {'runways': {'property': 'runways', 'defaultValue': None}, 'altitude': {'property': 'altitude', 'defaultValue': None}, 'coordinates': {'property': 'coordinates', 'defaultValue': None}}}}, 'logProgress': True, 'creationTime': neo4j.time.DateTime(2024, 4, 4, 15, 47, 27, 298504429, tzinfo=<UTC>), 'validateRelationships': False, 'sudo': False}, 'density': 0.0037814532146957986, 'creationTime': neo4j.time.DateTime(2024, 4, 4, 15, 47, 27, 298504429, tzinfo=<UTC>), 'modificationTime': neo4j.time.DateTime(2024, 4, 4, 15, 47, 27, 555589628, tzinfo=<UTC>), 'schema': {'graphProperties': {}, 'nodes': {'Airport': {'runways': 'Integer (DefaultValue(-9223372036854775808), PERSISTENT)', 'altitude': 'Integer (DefaultValue(-9223372036854775808), PERSISTENT)', 'coordinates': 'List of Float (DefaultValue(null), PERSISTENT)'}}, 'relationships': {'HAS_ROUTE_WEIGHT': {'weight': 'Float (DefaultValue(NaN), PERSISTENT, Aggregation.NONE)'}}}, 'schemaWithOrientation': {'graphProperties': {}, 'nodes': {'Airport': {'runways': 'Integer (DefaultValue(-9223372036854775808), PERSISTENT)', 'altitude': 'Integer (DefaultValue(-9223372036854775808), PERSISTENT)', 'coordinates': 'List of Float (DefaultValue(null), PERSISTENT)'}}, 'relationships': {'HAS_ROUTE_WEIGHT': {'direction': 'DIRECTED', 'properties': {'weight': 'Float (DefaultValue(NaN), PERSISTENT, Aggregation.NONE)'}}}}}]

# %% [markdown]
# # Louvain
# https://neo4j.com/docs/graph-data-science/current/algorithms/louvain/
#
# The Louvain method is an algorithm to detect communities in large networks. It maximizes a modularity score for each community, where the modularity quantifies the quality of an assignment of nodes to communities. This means evaluating how much more densely connected the nodes within a community are, compared to how connected they would be in a random network.
#
# The Louvain algorithm is a hierarchical clustering algorithm, that recursively merges communities into a single node and executes the modularity clustering on the condensed graphs.ode.

# %%
r = graph.query("""CALL gds.graph.project(
    'Louvain',
    'Airport',
    {
        HAS_ROUTE_WEIGHT: {
            orientation: 'UNDIRECTED'
        }
    },
    {
        nodeProperties: 'altitude',
        relationshipProperties: 'weight'
    }
)""")
print(r)
# Out:
# [{'nodeProjection': {'Airport': {'label': 'Airport', 'properties': {'altitude': {'property': 'altitude', 'defaultValue': None}}}}, 'relationshipProjection': {'HAS_ROUTE_WEIGHT': {'aggregation': 'DEFAULT', 'orientation': 'UNDIRECTED', 'indexInverse': False, 'properties': {'weight': {'aggregation': 'DEFAULT', 'property': 'weight', 'defaultValue': None}}, 'type': 'HAS_ROUTE_WEIGHT'}}, 'graphName': 'Louvain', 'nodeCount': 3503, 'relationshipCount': 92778, 'projectMillis': 129}]

# %%
r = graph.query("""CALL gds.louvain.write.estimate('Louvain', { writeProperty: 'community' })
YIELD nodeCount, relationshipCount, bytesMin, bytesMax, requiredMemory""")
print(r[:25])
# Out:
# [{'nodeCount': 3503, 'relationshipCount': 92778, 'bytesMin': 229921, 'bytesMax': 2529048, 'requiredMemory': '[224 KiB ... 2469 KiB]'}]

# %%
r = graph.query("""CALL gds.louvain.stream('Louvain')
YIELD nodeId, communityId, intermediateCommunityIds
RETURN gds.util.asNode(nodeId).descr AS name, communityId
ORDER BY name ASC""")
print(r[:20])
# Out:
# [{'name': 'A Coruna Airport', 'communityId': 1312}, {'name': 'Aalborg Airport', 'communityId': 1312}, {'name': 'Aarhus Airport', 'communityId': 1312}, {'name': 'Aasiaat Airport', 'communityId': 1811}, {'name': 'Aba Tenna Dejazmach Yilma International Airport', 'communityId': 153}, {'name': 'Abadan Airport', 'communityId': 153}, {'name': 'Abakan Airport', 'communityId': 1956}, {'name': 'Abbotsford Airport', 'communityId': 1863}, {'name': 'Abdul Rachman Saleh Airport', 'communityId': 1487}, {'name': 'Abeche Airport', 'communityId': 153}, {'name': 'Abeid Amani Karume International Airport', 'communityId': 153}, {'name': 'Abel Santamaria Airport', 'communityId': 1863}, {'name': 'Aberdeen Dyce Airport', 'communityId': 1312}, {'name': 'Aberdeen Regional Airport', 'communityId': 1863}, {'name': 'Abha Regional Airport', 'communityId': 153}, {'name': 'Abilene Regional Airport', 'communityId': 1863}, {'name': 'Abraham González International Airport', 'communityId': 1863}, {'name': 'Abraham Lincoln Capital Airport', 'communityId': 1863}, {'name': 'Abu Dhabi International Airport', 'communityId': 153}, {'name': 'Abu Simbel Airport', 'communityId': 153}]

# %%
cv=[]
for x in r:
    if x.get("communityId") not in cv:
        print(x.get("communityId"), x.get("name"))
        cv.append(x.get("communityId"))
# Out:
# 1312 A Coruna Airport
# 1811 Aasiaat Airport
# 153 Aba Tenna Dejazmach Yilma International Airport
# 1956 Abakan Airport
# 1863 Abbotsford Airport
# 1487 Abdul Rachman Saleh Airport
# 65 Adelaide International Airport
# 1573 Afonso Pena Airport
# 1097 Akhiok Airport
# 3065 Akiak Airport
# 1862 Akulivik Airport
# 3070 Alakanuk Airport
# 3080 Alashankou Bole (Bortala) airport
# 1108 Allakaket Airport
# 3057 Altai Airport
# 3061 Altay Air Base
# 1112 Ambler Airport
# 3071 Aneityum Airport
# 1104 Aniak Airport
# 3072 Aniwa Airport
# 3068 Anvik Airport
# 3465 Apataki Airport
# 3063 Araracuara Airport
# 3219 Arctic Village Airport
# 3432 Ataturk International Airport
# 3049 Attawapiskat Airport
# 3404 Awassa Airport
# 3086 Babo Airport
# 3076 Bakalalan Airport
# 3087 Bam Airport
# 3454 Barra do Garças Airport
# 3462 Batagay Airport
# 3082 Batticaloa Airport
# 3445 Bazhong Enyang Airport
# 1881 Bearskin Lake Airport
# 3073 Bedourie Airport
# 1817 Belize City Municipal Airport
# 199 Berlin, Tegel International Airport *Closed*
# 472 Berlin-Schönefeld International Airport *Closed*
# 3085 Birdsville Airport
# 3283 Block Island State Airport
# 3074 Bojnord Airport
# 3388 Braganca Airport
# 2581 Breves Airport
# 3083 Burketown Airport
# 3487 Bursa Yenişehir Airport
# 3089 Canaima Airport
# 3455 Canarana Airport
# 3213 Capitán Av. Selin Zeitun Lopez Airport
# 3103 Capitán de Av. Emilio Beltrán Airport
# 3384 Cascais Airport
# 3128 Caucaya Airport
# 3271 Centennial Airport
# 3446 Chang'an
# 3467 Chelinda Malawi Airport
# 3459 Cheng Xian Airport
# 3174 China Bay Airport
# 2995 Circle City /New/ Airport
# 3468 Club Makokola Airport
# 1763 Corvo Airport
# 3306 Coventry Airport
# 2242 Craig Cove Airport
# 3093 Cruzeiro do Sul Airport
# 3059 Cunnamulla Airport
# 3463 Deputatskij Airport
# 3284 Devils Lake Regional Airport
# 3094 Dezful Airport
# 1102 Dillingham Airport
# 3456 Dodoma Airport
# 3261 Dumatumbun Airport
# 1929 Eday Airport
# 3011 Egegik Airport
# 3052 Egilsstaðir Airport
# 3097 Eirunepé Airport
# 3186 El Embrujo Airport
# 3095 Elcho Island Airport
# 3096 Ende (H Hasan Aroeboesman) Airport
# 3220 Fort Mcpherson Airport
# 3312 Fort Worth Alliance Airport
# 3371 Foula Airport
# 3098 Futuna Airport
# 3338 Fuyun Kroktokay Airport
# 791 Gabès Matmata International Airport
# 3100 Gachsaran Airport
# 3206 Grayling Airport
# 3230 Grise Fiord Airport
# 3472 Gruyere Airport
# 3000 Guanambi Airport
# 1101 Gustavus Airport
# 1966 Hemavan Airport
# 3228 Hopedale Airport
# 3473 Hornafjordur Airport
# 3040 Hotan Airport
# 3475 Husavik Airport
# 3105 Ilam Airport
# 3421 In Guezzam Airport
# 3107 Itaituba Airport
# 3148 Ivujivik Airport
# 3046 Jolo Airport
# 3081 José Celestino Mutis Airport
# 2996 Jumandy Airport
# 3113 Kaltag Airport
# 3336 Kamishly Airport
# 3315 Kanas Airport
# 3222 Kangiqsujuaq (Wakeham Bay) Airport
# 3450 Kanti Airport
# 2997 Karluk Airport
# 3048 Kashechewan Airport
# 3014 Katiu Airport
# 3001 Kaukura Airport
# 3047 Kawthoung Airport
# 3245 Keewaywin Airport
# 3448 Kengtung Airport
# 3120 Ketapang(Rahadi Usman) Airport
# 3115 Khoram Abad Airport
# 3116 Khoy Airport
# 3408 Kigoma Airport
# 3200 Kosrae International Airport
# 1110 Kotlik Airport
# 3114 Kuqa Airport
# 2991 Kédougou Airport
# 3124 La Chorrera Airport
# 3126 La Macarena Airport
# 3127 La Pedrera Airport
# 3216 La Tabatière Airport
# 3288 Leeward Point Field
# 3476 Likoma Island Airport
# 3123 Long Banga Airport
# 3471 Magan Airport
# 3227 Makkovik Airport
# 3479 Mata'aho Airport
# 3003 Mekoryuk Airport
# 3130 Milingimbi Airport
# 2994 Minto Al Wright Airport
# 3131 Mopah Airport
# 3194 Mornington Island Airport
# 3204 Mota Lava Airport
# 3400 Murray Field
# 3484 Mvuu Camp Airport
# 3042 Myeik Airport
# 3203 Nabire Airport
# 3010 Napaskiak Airport
# 3226 Natuashish Airport
# 3090 Neerlerit Inaat Airport
# 941 New Castle Airport
# 3012 Newtok Airport
# 3247 North Spirit Lake Airport
# 3490 Nulato Airport
# 2993 Nunapitchuk Airport
# 3196 Oksibil Airport
# 3372 Papa Stour Airport
# 3189 Parsabade Moghan Airport
# 3225 Paulatuk (Nora Aliqatchialuk Ruben) Airport
# 3144 Peawanuck Airport
# 3237 Pohnpei International Airport
# 3246 Poplar Hill Airport
# 3013 Port Heiden Airport
# 3387 Portimao Airport
# 3319 Portland Airport
# 3190 Putao Airport
# 3234 Qaanaaq Airport
# 3209 Qaarsut Airport
# 3355 Qiemo Yudu Airport
# 3332 RAF Ascension Island
# 3333 RAF Brize Norton
# 3197 Ranai Airport
# 3262 Rar Gwamar Airport
# 2986 Red Devil Airport
# 3231 Resolute Bay Airport
# 3198 Reyes Murillo Airport
# 3184 Richmond Airport
# 3254 Rio Grande Airport
# 3168 Rubem Berta Airport
# 3064 Sabzevar National Airport
# 3224 Sachs Harbour (David Nasogaluak Jr. Saaryuaq) Airport
# 3221 Salluit Airport
# 3289 San Felipe International Airport
# 3480 San Fernando De Apure Airport
# 3212 Sanandaj Airport
# 3461 Sanhe Airport
# 3469 Santa Ana Airport
# 3181 Santa Elena de Uairen Airport
# 3251 Saumlaki/Olilit Airport
# 3195 Senadora Eunice Micheles Airport
# 3457 Seronera Airport
# 3453 Shangrao Sanqingshan Airport
# 2992 Sleetmute Airport
# 3270 Smith Reynolds Airport
# 3091 Solovki Airport
# 3483 Southern California Logistics Airport
# 3217 St Augustin Airport
# 2931 St George Airport
# 3331 Stanley Airport
# 3280 Sydney Bankstown Airport
# 3183 São Gabriel da Cachoeira Airport
# 3180 Tacheng Airport
# 3179 Takapoto Airport
# 3106 Tapuruquara Airport
# 3175 Tarko-Sale Airport
# 2536 Teniente Coronel Luis a Mantilla Airport
# 3060 Thargomindah Airport
# 3233 Thule Air Base
# 3370 Tingwall Airport
# 3177 Togiak Airport
# 1007 Toowoomba Airport
# 3176 Torres Airstrip
# 2998 Totegegie Airport
# 3178 Trombetas Airport
# 3239 Tucuruí Airport
# 3223 Tuktoyaktuk Airport
# 3004 Tununak Airport
# 3214 Tête-à-la-Baleine Airport
# 3173 Ua Huka Airport
# 3171 Ua Pou Airport
# 3002 Ugashik Bay Airport
# 3208 Upernavik Airport
# 3167 Usinsk Airport
# 3481 Ust-Maya Airport
# 3166 Ust-Tsylma Airport
# 3165 Venetie Airport
# 3385 Vila Real Airport
# 3386 Viseu Airport
# 3364 Vitebsk East Airport
# 3041 Wamena Airport
# 3318 Warrnambool Airport
# 3163 Windorah Airport
# 3460 Xinyang Minggang Airport
# 3201 Xinyuan Nalati Airport
# 3088 Yacuiba Airport
# 3155 Yasouj Airport
# 3238 Zaisan (Zaysan) Airport
# 3185 Zhob Airport
# 3051 Ísafjörður Airport

# %%
r = graph.query("""Call gds.graph.drop("Louvain")""")
print(r)
# Out:
# [{'graphName': 'Louvain', 'database': 'neo4j', 'databaseLocation': 'local', 'memoryUsage': '', 'sizeInBytes': -1, 'nodeCount': 3503, 'relationshipCount': 92778, 'configuration': {'relationshipProjection': {'HAS_ROUTE_WEIGHT': {'aggregation': 'DEFAULT', 'orientation': 'UNDIRECTED', 'indexInverse': False, 'properties': {'weight': {'aggregation': 'DEFAULT', 'property': 'weight', 'defaultValue': None}}, 'type': 'HAS_ROUTE_WEIGHT'}}, 'readConcurrency': 4, 'relationshipProperties': {}, 'nodeProperties': {}, 'jobId': '7c1305df-6d88-44dd-984d-c83fffe5a79b', 'nodeProjection': {'Airport': {'label': 'Airport', 'properties': {'altitude': {'property': 'altitude', 'defaultValue': None}}}}, 'logProgress': True, 'creationTime': neo4j.time.DateTime(2024, 4, 4, 15, 53, 1, 651738470, tzinfo=<UTC>), 'validateRelationships': False, 'sudo': False}, 'density': 0.007562906429391597, 'creationTime': neo4j.time.DateTime(2024, 4, 4, 15, 53, 1, 651738470, tzinfo=<UTC>), 'modificationTime': neo4j.time.DateTime(2024, 4, 4, 15, 53, 1, 782599827, tzinfo=<UTC>), 'schema': {'graphProperties': {}, 'nodes': {'Airport': {'altitude': 'Integer (DefaultValue(-9223372036854775808), PERSISTENT)'}}, 'relationships': {'HAS_ROUTE_WEIGHT': {'weight': 'Float (DefaultValue(NaN), PERSISTENT, Aggregation.NONE)'}}}, 'schemaWithOrientation': {'graphProperties': {}, 'nodes': {'Airport': {'altitude': 'Integer (DefaultValue(-9223372036854775808), PERSISTENT)'}}, 'relationships': {'HAS_ROUTE_WEIGHT': {'direction': 'UNDIRECTED', 'properties': {'weight': 'Float (DefaultValue(NaN), PERSISTENT, Aggregation.NONE)'}}}}}]

# %% [markdown]
# # Local Clustering Coefficient
# https://neo4j.com/docs/graph-data-science/current/algorithms/local-clustering-coefficient/
# <br>
# The Local Clustering Coefficient algorithm computes the local clustering coefficient for each node in the graph. The local clustering coefficient Cn of a node n describes the likelihood that the neighbours of n are also connected

# %% [markdown]
# # Modularity metric
#
# https://neo4j.com/docs/graph-data-science/current/algorithms/modularity/
#
# Modularity is a metric that allows you to evaluate the quality of a community detection. Relationships of nodes in a community C connect to nodes either within C or outside C. Graphs with high modularity have dense connections between the nodes within communities but sparse connections between nodes in different communities.

# %% [markdown]
# # Modularity Optimization
# https://neo4j.com/docs/graph-data-science/current/algorithms/modularity-optimization/
#
# The Modularity Optimization algorithm tries to detect communities in the graph based on their modularity. Modularity is a measure of the structure of a graph, measuring the density of connections within a module or community. Graphs with a high modularity score will have many connections within a community but only few pointing outwards to other communities. The algorithm will explore for every node if its modularity score might increase if it changes its community to one of its neighboring nodes.

# %% [markdown]
# # Strongly Connected Components
# https://neo4j.com/docs/graph-data-science/current/algorithms/strongly-connected-components/
#
# The Strongly Connected Components (SCC) algorithm finds maximal sets of connected nodes in a directed graph. A set is considered a strongly connected component if there is a directed path between each pair of nodes within the set. It is often used early in a graph analysis process to help us get an idea of how our graph is structured.

# %% [markdown]
# # Triangle Count
# https://neo4j.com/docs/graph-data-science/current/algorithms/triangle-count/
#
# The Triangle Count algorithm counts the number of triangles for each node in the graph. A triangle is a set of three nodes where each node has a relationship to the other two. In graph theory terminology, this is sometimes referred to as a 3-clique. The Triangle Count algorithm in the GDS library only finds triangles in undirected graphs.

# %% [markdown]
# # Weakly Connected Components
# https://neo4j.com/docs/graph-data-science/current/algorithms/wcc/
#
# The Weakly Connected Components (WCC) algorithm finds sets of connected nodes in directed and undirected graphs. Two nodes are connected, if there exists a path between them. The set of all nodes that are connected with each other form a component. In contrast to Strongly Connected Components (SCC), the direction of relationships on the path between two nodes is not considered. For example, in a directed graph (a)→(b), a and b will be in the same component, even if there is no directed relationship (b)→(a).
